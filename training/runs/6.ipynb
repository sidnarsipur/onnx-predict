# %%
from sklearn.metrics import mean_squared_error
import pandas as pd

# %% [markdown]
# # Load and pre-process data

# %%
target_col = "log_average_ms"

node_cols = ["Abs", "Acos", "Add", "ai.onnx.ml::CategoryMapper", "And", "ArgMax", 
             "AveragePool", "BatchNormalization", "Cast", "Ceil", "Clip", 
             "com.microsoft::BiasGelu", "com.microsoft::DynamicQuantizeLSTM", 
             "com.microsoft::DynamicQuantizeMatMul", "com.microsoft::FastGelu", 
             "com.microsoft::FusedConv", "com.microsoft::FusedGemm", 
             "com.microsoft::FusedMatMul", "com.microsoft::MatMulIntegerToFloat", 
             "com.microsoft::QGemm", "com.microsoft::QLinearAdd", 
             "com.microsoft::QLinearAveragePool", "com.microsoft::QLinearConcat", 
             "com.microsoft::QLinearGlobalAveragePool", "com.microsoft::QLinearLeakyRelu", 
             "com.microsoft::QLinearMul", "com.microsoft::QLinearSigmoid", 
             "com.microsoft::QuickGelu", "com.microsoft::SkipLayerNormalization", 
             "Compress", "Concat", "Constant", "ConstantOfShape", "Conv", "ConvInteger", 
             "ConvTranspose", "Cos", "CumSum", "DequantizeLinear", "Div", "Dropout", 
             "DynamicQuantizeLinear", "Einsum", "Equal", "Erf", "Exp", "Expand", 
             "EyeLike", "Flatten", "Floor", "Gather", "GatherElements", "GatherND", 
             "Gelu", "Gemm", "GlobalAveragePool", "Greater", "GreaterOrEqual", "Hardmax", 
             "HardSigmoid", "HardSwish", "Identity", "If", "InstanceNormalization", 
             "LayerNormalization", "LeakyRelu", "Less", "LessOrEqual", "local::preprocess", 
             "Log", "LogSoftmax", "Loop", "LRN", "LSTM", "MatMul", "MatMulInteger", 
             "Max", "MaxPool", "Min", "Mod", "Mul", "Neg", "NonMaxSuppression", "NonZero", 
             "Not", "OneHot", "Or", "Pad", "Pow", "PRelu", "QLinearConv", "QLinearMatMul", 
             "QuantizeLinear", "Range", "Reciprocal", "ReduceMax", "ReduceMean", "ReduceMin", 
             "ReduceProd", "ReduceSum", "Relu", "Reshape", "Resize", "RoiAlign", "Round", 
             "Scan", "ScatterElements", "ScatterND", "Shape", "Sigmoid", 
             "SimplifiedLayerNormalization", "Sin", "Slice", "Softmax", "Split", "Sqrt", 
             "Squeeze", "Sub", "Sum", "Tanh", "Tile", "TopK", "Transpose", "Trilu", 
             "Unsqueeze", "Where", "Xor"]


# node_cols = ["Constant", "Reshape", "Add", "Conv",
#              "Mul", "Transpose", "Relu", "MatMul",
#              "Gemm", "Unsqueeze"]


# extra_cols = ["movement_frac_x_cores", "mb_per_core"]

model_feature_cols = node_cols + ["conv_flops", "matmul_flops",
                "elementwise_mb", "reduction_mb", "normalization_mb",
                "movement_mb", "memory_mb"]

hardware_feature_cols = ["l1d_cache_kb", "l1i_cache_kb", "l2_cache_kb", 
                         "base_clock_mhz", "num_cores", "memory_bandwith_gbs", 
                         "cpu_provider"]

metadata_cols = ["model", "cpu_provider",
                 "machine_type", "platform", "run_id"]

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load test, train, val sets

train_df = pd.read_csv("/content/drive/MyDrive/Data/train_set.csv")
val_df = pd.read_csv("/content/drive/MyDrive/Data/val_set.csv")
test_df = pd.read_csv("/content/drive/MyDrive/Data/test_set.csv")

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (100252, 154)
# val: (21483, 154)
# test: (21483, 154)

# %%
assert list(train_df.columns) == list(val_df.columns) == list(test_df.columns)

train_df.head()
# Out:
#                                                model input_dimensions  \
# 0                hardcorenas_d_Opset17_extended.onnx    x:1x3x224x224
# 1  vit_base_patch8_224_in21k_Opset17_disable_all....    x:1x3x224x224
# 2    tf_efficientnetv2_m_in21ft1k_Opset17_basic.onnx    x:1x3x384x384
# 3                    shufflenet_v2_x1_5_Opset16.onnx    x:1x3x224x224
# 4                 wide_resnet101_2_Opset16_timm.onnx    x:1x3x224x224
#
#   input_dtypes output_dimensions output_dtypes   conv_flops  matmul_flops  \
# 0    x:float32        668:1x1000   668:float32    472440512       2560000
# 1    x:float32      1089:1x21843  1089:float32    231211008  156097479168
# 2    x:float32       2466:1x1000  2466:float32  31470991360       2560000
# 3    x:float32       1137:1x1000  1137:float32    266034528       2048000
# 4    x:float32        971:1x1000   971:float32  45502005248       4096000
#
#    elementwise_mb  reduction_mb  normalization_mb  ...  base_clock_mhz  \
# 0       50.528229      5.204269          0.000000  ...        2300.000
# 1     1771.169711      0.000000        792.141724  ...        2450.000
# 2     1201.339462     67.736023          0.000000  ...        2449.998
# 3        8.246674      1.630875          0.000000  ...        2449.998
# 4      252.656250      4.218750          0.000000  ...        2300.000
#
#    memory_bandwith_gbs  cpu_provider  machine_type  platform  \
# 0                  717         intel     xeon_plat  bluehive
# 1                  205           amd          epyc    gcloud
# 2                  205           amd          epyc    gcloud
# 3                  205           amd          epyc    gcloud
# 4                  717         intel     xeon_plat  bluehive
#
#                                    repo_file   average_ms   stddev_ms  \
# 0                 hardcorenas_d_Opset17.onnx    14.069188    0.082284
# 1     vit_base_patch8_224_in21k_Opset17.onnx  1481.456045  150.199862
# 2  tf_efficientnetv2_m_in21ft1k_Opset17.onnx   301.127424   12.889699
# 3            shufflenet_v2_x1_5_Opset16.onnx     8.161246    0.036559
# 4         wide_resnet101_2_Opset16_timm.onnx    38.147223    0.068437
#
#         min_ms       max_ms
# 0    13.931521    14.247209
# 1  1094.324125  1632.506909
# 2   286.464729   324.336829
# 3     8.080030     8.197800
# 4    38.035275    38.292409
#
# [5 rows x 154 columns]

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

# %%
# pre-processing function

def preprocess(df: pd.DataFrame, train=False) -> pd.DataFrame:

  #drop rows with missing features
  df = df.dropna(subset=["average_ms"])

  #remove rows with high standard deviation (only for train)
  cv_limit = 0.1 # 10% cv limit
  df["cv"] = df["stddev_ms"] / df["average_ms"]

  # if train:
  df = df[df["cv"] <= cv_limit].copy()

  #add log_average_ms column
  df["log_average_ms"] = np.log(df["average_ms"])

  #remove decimals and round down
  for col in ["elementwise_mb", "reduction_mb", "normalization_mb", "movement_mb"]:
    df[col] = df[col].round(0)

  return df

# %%
train_df = preprocess(train_df, True)
test_df = preprocess(test_df, False)
val_df = preprocess(val_df, False)

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (95814, 156)
# val: (20494, 156)
# test: (20528, 156)

# %%
for col in model_feature_cols:
    train_df[col] = np.log1p(train_df[col])
    val_df[col] = np.log1p(val_df[col])
    test_df[col] = np.log1p(test_df[col])

# %% [markdown]
# # Data Setup

# %%
target_col = "log_average_ms"

# %%
cpu_provider_map = {
    "intel": 0.0,
    "amd": 1.0,
}

for df in [train_df, val_df, test_df]:
    df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

    if df["cpu_provider_binary"].isna().any():
        bad_values = df.loc[df["cpu_provider_binary"].isna(), "cpu_provider"].unique()
        raise ValueError(f"Unknown cpu_provider values: {bad_values}")

hardware_feature_cols.remove("cpu_provider")
hardware_feature_cols.append("cpu_provider_binary")
# Out:
# /tmp/ipykernel_3532/2739234318.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_3532/2739234318.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_3532/2739234318.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

# %%
X_model_train = train_df[model_feature_cols].astype("float32").to_numpy()
X_model_val = val_df[model_feature_cols].astype("float32").to_numpy()
X_model_test = test_df[model_feature_cols].astype("float32").to_numpy()

X_hw_train = train_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_val = val_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_test = test_df[hardware_feature_cols].astype("float32").to_numpy()

y_train = train_df[target_col].astype("float32").to_numpy()
y_val = val_df[target_col].astype("float32").to_numpy()
y_test = test_df[target_col].astype("float32").to_numpy()

# %%
model_scaler = StandardScaler()
hw_scaler = StandardScaler()

X_model_train = model_scaler.fit_transform(X_model_train).astype("float32")
X_model_val = model_scaler.transform(X_model_val).astype("float32")
X_model_test = model_scaler.transform(X_model_test).astype("float32")

X_hw_train = hw_scaler.fit_transform(X_hw_train).astype("float32")
X_hw_val = hw_scaler.transform(X_hw_val).astype("float32")
X_hw_test = hw_scaler.transform(X_hw_test).astype("float32")

# %% [markdown]
# # Model Setup

# %%
def rmse_log(y_true, y_pred):
  return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class TwoTowerLatencyDataset(Dataset):
    def __init__(self, X_model, X_hw, y):
        self.X_model = torch.from_numpy(X_model)
        self.X_hw = torch.from_numpy(X_hw)
        self.y = torch.from_numpy(y)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X_model[idx], self.X_hw[idx], self.y[idx]

# %%
batch_size = 1024

train_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_train, X_hw_train, y_train),
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
)

val_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_val, X_hw_val, y_val),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

test_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_test, X_hw_test, y_test),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout=0.10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.LayerNorm(dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim),
        )
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        return self.norm(x + self.net(x))


class TwoTowerLatencyMLP(nn.Module):
    def __init__(self, n_model_features: int, n_hw_features: int):
        super().__init__()

        emb_dim = 128

        self.model_in = nn.Sequential(
            nn.Linear(n_model_features, 256),
            nn.LayerNorm(256),
            nn.GELU(),
            nn.Dropout(0.10),
            nn.Linear(256, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        self.model_blocks = nn.Sequential(
            ResidualBlock(emb_dim, dropout=0.10),
            ResidualBlock(emb_dim, dropout=0.05),
        )

        self.hw_tower = nn.Sequential(
            nn.Linear(n_hw_features, 64),
            nn.LayerNorm(64),
            nn.GELU(),
            nn.Linear(64, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        # Hardware produces feature-wise scale and shift for model embedding
        self.hw_film = nn.Linear(emb_dim, emb_dim * 2)

        self.fusion = nn.Sequential(
            nn.Linear(emb_dim * 4, 256),
            nn.LayerNorm(256),
            nn.GELU(),
            nn.Dropout(0.10),

            nn.Linear(256, 128),
            nn.LayerNorm(128),
            nn.GELU(),
            nn.Dropout(0.05),

            nn.Linear(128, 1),
        )

    def forward(self, model_x, hw_x):
        model_emb = self.model_in(model_x)
        model_emb = self.model_blocks(model_emb)

        hw_emb = self.hw_tower(hw_x)

        gamma, beta = self.hw_film(hw_emb).chunk(2, dim=1)
        conditioned_model = model_emb * (1 + gamma) + beta

        interaction = conditioned_model * hw_emb
        diff = torch.abs(conditioned_model - hw_emb)

        fused = torch.cat(
            [conditioned_model, hw_emb, interaction, diff],
            dim=1,
        )

        return self.fusion(fused).squeeze(1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
print("model features:", X_model_train.shape[1])
print("hardware features:", X_hw_train.shape[1])
# Out:
# model features: 134
# hardware features: 7

# %%
model = TwoTowerLatencyMLP(
    n_model_features=len(model_feature_cols),
    n_hw_features=X_hw_train.shape[1],
).to(device)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    weight_decay=1e-4,
)

loss_fn = nn.SmoothL1Loss()  # Huber loss on log latency

# %% [markdown]
# # Model Training

# %%
from sklearn.metrics import mean_squared_error

# %%
def evaluate_mlp(model, loader):
    model.eval()

    preds = []
    targets = []

    with torch.no_grad():
        for model_x, hw_x, y in loader:
            model_x = model_x.to(device)
            hw_x = hw_x.to(device)
            y = y.to(device)

            pred = model(model_x, hw_x)

            preds.append(pred.cpu().numpy())
            targets.append(y.cpu().numpy())

    y_pred = np.concatenate(preds)
    y_true = np.concatenate(targets)

    rmse_log = np.sqrt(mean_squared_error(y_true, y_pred))

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    metrics = {
        "rmse_log": rmse_log,
        "rmse_ms": np.sqrt(mean_squared_error(true_ms, pred_ms)),
        "rmse_percent": np.sqrt(mean_squared_error(rel_err, np.zeros_like(rel_err))),
        "median_relative_error": np.median(rel_err),
        "p90_relative_error": np.percentile(rel_err, 90),
        "p95_relative_error": np.percentile(rel_err, 95),
        "within_10pct": np.mean(rel_err <= 0.10),
        "median_ratio_error": np.median(np.maximum(pred_ms / true_ms, true_ms / pred_ms)),
        "p90_ratio_error": np.percentile(np.maximum(pred_ms / true_ms, true_ms / pred_ms), 90),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
        "within_2x": np.mean(np.maximum(pred_ms / true_ms, true_ms / pred_ms) <= 2.0),
    }

    return metrics, y_true, y_pred

# %%
# best_val_rmse = float("inf")
# best_state = None

num_epochs = 2000

# history = []

for epoch in range(1000, num_epochs + 1):
    model.train()
    train_losses = []

    for model_x, hw_x, y in train_loader:
        model_x = model_x.to(device)
        hw_x = hw_x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        pred = model(model_x, hw_x)
        loss = loss_fn(pred, y)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        train_losses.append(loss.item())

    val_metrics, _, _ = evaluate_mlp(model, val_loader)
    val_rmse = val_metrics["rmse_log"]

    history.append({
        "epoch": epoch,
        "train_loss": np.mean(train_losses),
        **val_metrics,
    })

    if val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        best_state = {
            "model": model.state_dict(),
            "epoch": epoch,
            "val_rmse": val_rmse,
        }

    if epoch % 5 == 0 or epoch == 1:
        print(
            f"epoch {epoch:03d} | "
            f"train_loss={np.mean(train_losses):.5f} | "
            f"val_rmse_log={val_rmse:.5f} | "
            f"within_10={val_metrics['within_10pct']:.4f} | "
            f"best={best_val_rmse:.5f}"
        )
# Out:
# epoch 1000 | train_loss=0.01746 | val_rmse_log=0.20933 | within_10=0.7965 | best=0.19621
# epoch 1005 | train_loss=0.01634 | val_rmse_log=0.19819 | within_10=0.7903 | best=0.19621
# epoch 1010 | train_loss=0.01642 | val_rmse_log=0.19748 | within_10=0.8041 | best=0.19621
# epoch 1015 | train_loss=0.01654 | val_rmse_log=0.19850 | within_10=0.7919 | best=0.19621
# epoch 1020 | train_loss=0.01636 | val_rmse_log=0.19797 | within_10=0.8028 | best=0.19621
# epoch 1025 | train_loss=0.01633 | val_rmse_log=0.19794 | within_10=0.8082 | best=0.19621
# epoch 1030 | train_loss=0.01636 | val_rmse_log=0.19818 | within_10=0.8007 | best=0.19621
# epoch 1035 | train_loss=0.01634 | val_rmse_log=0.19776 | within_10=0.7990 | best=0.19621
# epoch 1040 | train_loss=0.01657 | val_rmse_log=0.20170 | within_10=0.7861 | best=0.19621
# epoch 1045 | train_loss=0.01627 | val_rmse_log=0.19745 | within_10=0.8070 | best=0.19621
# epoch 1050 | train_loss=0.01636 | val_rmse_log=0.19858 | within_10=0.7933 | best=0.19621
# epoch 1055 | train_loss=0.01639 | val_rmse_log=0.19807 | within_10=0.8035 | best=0.19621
# epoch 1060 | train_loss=0.01642 | val_rmse_log=0.19871 | within_10=0.7967 | best=0.19621
# epoch 1065 | train_loss=0.01633 | val_rmse_log=0.19817 | within_10=0.8104 | best=0.19621
# epoch 1070 | train_loss=0.01638 | val_rmse_log=0.19771 | within_10=0.8001 | best=0.19621
# epoch 1075 | train_loss=0.01637 | val_rmse_log=0.19776 | within_10=0.8048 | best=0.19621
# epoch 1080 | train_loss=0.01638 | val_rmse_log=0.19891 | within_10=0.7996 | best=0.19621
# epoch 1085 | train_loss=0.01632 | val_rmse_log=0.19795 | within_10=0.8027 | best=0.19621
# epoch 1090 | train_loss=0.01631 | val_rmse_log=0.19812 | within_10=0.7936 | best=0.19621
# epoch 1095 | train_loss=0.01631 | val_rmse_log=0.19777 | within_10=0.8098 | best=0.19621
# epoch 1100 | train_loss=0.01685 | val_rmse_log=0.19889 | within_10=0.7956 | best=0.19621
# epoch 1105 | train_loss=0.01744 | val_rmse_log=0.21124 | within_10=0.7906 | best=0.19621
# epoch 1110 | train_loss=0.01623 | val_rmse_log=0.19994 | within_10=0.7865 | best=0.19621
# epoch 1115 | train_loss=0.01643 | val_rmse_log=0.19890 | within_10=0.7966 | best=0.19621
# epoch 1120 | train_loss=0.01625 | val_rmse_log=0.19844 | within_10=0.8148 | best=0.19621
# epoch 1125 | train_loss=0.01637 | val_rmse_log=0.19806 | within_10=0.8090 | best=0.19621
# epoch 1130 | train_loss=0.01625 | val_rmse_log=0.19957 | within_10=0.7949 | best=0.19621
# epoch 1135 | train_loss=0.01622 | val_rmse_log=0.19899 | within_10=0.8005 | best=0.19621
# epoch 1140 | train_loss=0.01623 | val_rmse_log=0.19847 | within_10=0.8080 | best=0.19621
# epoch 1145 | train_loss=0.01632 | val_rmse_log=0.19751 | within_10=0.8055 | best=0.19621
# epoch 1150 | train_loss=0.01631 | val_rmse_log=0.19837 | within_10=0.7986 | best=0.19621
# epoch 1155 | train_loss=0.01626 | val_rmse_log=0.19895 | within_10=0.7901 | best=0.19621
# epoch 1160 | train_loss=0.01800 | val_rmse_log=0.19915 | within_10=0.7950 | best=0.19621
# epoch 1165 | train_loss=0.01629 | val_rmse_log=0.19757 | within_10=0.8067 | best=0.19621
# epoch 1170 | train_loss=0.01623 | val_rmse_log=0.19835 | within_10=0.8013 | best=0.19621
# epoch 1175 | train_loss=0.01618 | val_rmse_log=0.19728 | within_10=0.8029 | best=0.19621
# epoch 1180 | train_loss=0.01626 | val_rmse_log=0.19721 | within_10=0.8092 | best=0.19621
# epoch 1185 | train_loss=0.01619 | val_rmse_log=0.19731 | within_10=0.8057 | best=0.19621
# epoch 1190 | train_loss=0.01622 | val_rmse_log=0.19891 | within_10=0.7922 | best=0.19621
# epoch 1195 | train_loss=0.01632 | val_rmse_log=0.19895 | within_10=0.7973 | best=0.19621
# epoch 1200 | train_loss=0.01674 | val_rmse_log=0.19989 | within_10=0.7994 | best=0.19621
# epoch 1205 | train_loss=0.01619 | val_rmse_log=0.19869 | within_10=0.8054 | best=0.19621
# epoch 1210 | train_loss=0.01623 | val_rmse_log=0.19711 | within_10=0.8049 | best=0.19621
# epoch 1215 | train_loss=0.01641 | val_rmse_log=0.19834 | within_10=0.8015 | best=0.19621
# epoch 1220 | train_loss=0.01625 | val_rmse_log=0.19902 | within_10=0.7917 | best=0.19621
# epoch 1225 | train_loss=0.01617 | val_rmse_log=0.19795 | within_10=0.8074 | best=0.19621
# epoch 1230 | train_loss=0.01615 | val_rmse_log=0.19838 | within_10=0.8025 | best=0.19621
# epoch 1235 | train_loss=0.01630 | val_rmse_log=0.19779 | within_10=0.7981 | best=0.19621
# epoch 1240 | train_loss=0.01620 | val_rmse_log=0.19738 | within_10=0.8083 | best=0.19621
# epoch 1245 | train_loss=0.01617 | val_rmse_log=0.19829 | within_10=0.8066 | best=0.19621
# epoch 1250 | train_loss=0.01625 | val_rmse_log=0.19798 | within_10=0.8090 | best=0.19621
# epoch 1255 | train_loss=0.01619 | val_rmse_log=0.19761 | within_10=0.8039 | best=0.19621
# epoch 1260 | train_loss=0.01621 | val_rmse_log=0.19851 | within_10=0.8090 | best=0.19621
# epoch 1265 | train_loss=0.01624 | val_rmse_log=0.19761 | within_10=0.8132 | best=0.19621
# epoch 1270 | train_loss=0.01625 | val_rmse_log=0.21689 | within_10=0.7853 | best=0.19621
# epoch 1275 | train_loss=0.01611 | val_rmse_log=0.19784 | within_10=0.8060 | best=0.19621
# epoch 1280 | train_loss=0.01623 | val_rmse_log=0.19853 | within_10=0.8062 | best=0.19621
# epoch 1285 | train_loss=0.01619 | val_rmse_log=0.19828 | within_10=0.8103 | best=0.19621
# epoch 1290 | train_loss=0.01616 | val_rmse_log=0.19851 | within_10=0.8120 | best=0.19621
# epoch 1295 | train_loss=0.01614 | val_rmse_log=0.19810 | within_10=0.8061 | best=0.19621
# epoch 1300 | train_loss=0.01623 | val_rmse_log=0.19891 | within_10=0.7963 | best=0.19621
# epoch 1305 | train_loss=0.01616 | val_rmse_log=0.19858 | within_10=0.8029 | best=0.19621
# epoch 1310 | train_loss=0.01623 | val_rmse_log=0.19789 | within_10=0.8089 | best=0.19621
# epoch 1315 | train_loss=0.01604 | val_rmse_log=0.19837 | within_10=0.7971 | best=0.19621
# epoch 1320 | train_loss=0.01620 | val_rmse_log=0.19769 | within_10=0.8114 | best=0.19621
# epoch 1325 | train_loss=0.01608 | val_rmse_log=0.19868 | within_10=0.8070 | best=0.19621
# epoch 1330 | train_loss=0.01604 | val_rmse_log=0.19735 | within_10=0.8088 | best=0.19621
# epoch 1335 | train_loss=0.01630 | val_rmse_log=0.19927 | within_10=0.7941 | best=0.19621
# epoch 1340 | train_loss=0.01610 | val_rmse_log=0.19729 | within_10=0.8053 | best=0.19621
# epoch 1345 | train_loss=0.01619 | val_rmse_log=0.19846 | within_10=0.8028 | best=0.19621
# epoch 1350 | train_loss=0.01612 | val_rmse_log=0.19711 | within_10=0.8107 | best=0.19621
# epoch 1355 | train_loss=0.01643 | val_rmse_log=0.19797 | within_10=0.8047 | best=0.19621
# epoch 1360 | train_loss=0.01616 | val_rmse_log=0.19798 | within_10=0.8102 | best=0.19621
# epoch 1365 | train_loss=0.01614 | val_rmse_log=0.19801 | within_10=0.8077 | best=0.19621
# epoch 1370 | train_loss=0.01613 | val_rmse_log=0.19728 | within_10=0.8084 | best=0.19621
# epoch 1375 | train_loss=0.01610 | val_rmse_log=0.19763 | within_10=0.8081 | best=0.19621
# epoch 1380 | train_loss=0.01608 | val_rmse_log=0.19866 | within_10=0.8071 | best=0.19621
# epoch 1385 | train_loss=0.01607 | val_rmse_log=0.19955 | within_10=0.7955 | best=0.19621
# epoch 1390 | train_loss=0.01607 | val_rmse_log=0.19848 | within_10=0.8085 | best=0.19621
# epoch 1395 | train_loss=0.01606 | val_rmse_log=0.19954 | within_10=0.8071 | best=0.19621
# epoch 1400 | train_loss=0.01608 | val_rmse_log=0.19821 | within_10=0.8063 | best=0.19621
# epoch 1405 | train_loss=0.01618 | val_rmse_log=0.22073 | within_10=0.8000 | best=0.19621
# epoch 1410 | train_loss=0.01622 | val_rmse_log=0.19960 | within_10=0.7936 | best=0.19621
# epoch 1415 | train_loss=0.01606 | val_rmse_log=0.19901 | within_10=0.7912 | best=0.19621
# epoch 1420 | train_loss=0.01608 | val_rmse_log=0.19810 | within_10=0.8090 | best=0.19621
# epoch 1425 | train_loss=0.01606 | val_rmse_log=0.19961 | within_10=0.8073 | best=0.19621
# epoch 1430 | train_loss=0.01645 | val_rmse_log=0.19853 | within_10=0.8063 | best=0.19621
# epoch 1435 | train_loss=0.01609 | val_rmse_log=0.19921 | within_10=0.8078 | best=0.19621
# epoch 1440 | train_loss=0.01606 | val_rmse_log=0.19816 | within_10=0.8065 | best=0.19621
# epoch 1445 | train_loss=0.01609 | val_rmse_log=0.19883 | within_10=0.8131 | best=0.19621
# epoch 1450 | train_loss=0.01615 | val_rmse_log=0.19868 | within_10=0.8118 | best=0.19621
# epoch 1455 | train_loss=0.01612 | val_rmse_log=0.19902 | within_10=0.8028 | best=0.19621
# epoch 1460 | train_loss=0.01608 | val_rmse_log=0.19885 | within_10=0.8079 | best=0.19621
# epoch 1465 | train_loss=0.01603 | val_rmse_log=0.19810 | within_10=0.8058 | best=0.19621
# epoch 1470 | train_loss=0.01606 | val_rmse_log=0.20132 | within_10=0.7954 | best=0.19621
# epoch 1475 | train_loss=0.01606 | val_rmse_log=0.20067 | within_10=0.7955 | best=0.19621
# epoch 1480 | train_loss=0.01654 | val_rmse_log=0.19852 | within_10=0.8072 | best=0.19621
# epoch 1485 | train_loss=0.01609 | val_rmse_log=0.19831 | within_10=0.8006 | best=0.19621
# epoch 1490 | train_loss=0.01614 | val_rmse_log=0.20087 | within_10=0.8056 | best=0.19621
# epoch 1495 | train_loss=0.01615 | val_rmse_log=0.19973 | within_10=0.7955 | best=0.19621
# epoch 1500 | train_loss=0.01608 | val_rmse_log=0.19891 | within_10=0.8092 | best=0.19621
# epoch 1505 | train_loss=0.01605 | val_rmse_log=0.19943 | within_10=0.7904 | best=0.19621
# epoch 1510 | train_loss=0.01610 | val_rmse_log=0.19765 | within_10=0.8097 | best=0.19621
# epoch 1515 | train_loss=0.01610 | val_rmse_log=0.19828 | within_10=0.8072 | best=0.19621
# epoch 1520 | train_loss=0.01603 | val_rmse_log=0.19799 | within_10=0.8052 | best=0.19621
# epoch 1525 | train_loss=0.01689 | val_rmse_log=0.20045 | within_10=0.7768 | best=0.19621
# epoch 1530 | train_loss=0.01599 | val_rmse_log=0.19779 | within_10=0.8086 | best=0.19621
# epoch 1535 | train_loss=0.01622 | val_rmse_log=0.20054 | within_10=0.7972 | best=0.19621
# epoch 1540 | train_loss=0.01596 | val_rmse_log=0.19895 | within_10=0.8018 | best=0.19621
# epoch 1545 | train_loss=0.01609 | val_rmse_log=0.19920 | within_10=0.8019 | best=0.19621
# epoch 1550 | train_loss=0.01603 | val_rmse_log=0.19751 | within_10=0.8124 | best=0.19621
# epoch 1555 | train_loss=0.01604 | val_rmse_log=0.19942 | within_10=0.8015 | best=0.19621
# epoch 1560 | train_loss=0.01611 | val_rmse_log=0.19923 | within_10=0.8081 | best=0.19621
# epoch 1565 | train_loss=0.01605 | val_rmse_log=0.19853 | within_10=0.8084 | best=0.19621
# epoch 1570 | train_loss=0.01608 | val_rmse_log=0.19817 | within_10=0.8063 | best=0.19621
# epoch 1575 | train_loss=0.01608 | val_rmse_log=0.19943 | within_10=0.7893 | best=0.19621
# epoch 1580 | train_loss=0.01610 | val_rmse_log=0.19863 | within_10=0.8036 | best=0.19621
# epoch 1585 | train_loss=0.01610 | val_rmse_log=0.19901 | within_10=0.8040 | best=0.19621
# epoch 1590 | train_loss=0.01610 | val_rmse_log=0.19856 | within_10=0.8070 | best=0.19621
# epoch 1595 | train_loss=0.01594 | val_rmse_log=0.19835 | within_10=0.8108 | best=0.19621
# epoch 1600 | train_loss=0.01612 | val_rmse_log=0.19836 | within_10=0.8104 | best=0.19621
# epoch 1605 | train_loss=0.01604 | val_rmse_log=0.19802 | within_10=0.8029 | best=0.19621
# epoch 1610 | train_loss=0.01603 | val_rmse_log=0.19862 | within_10=0.8097 | best=0.19621
# epoch 1615 | train_loss=0.01593 | val_rmse_log=0.19876 | within_10=0.8022 | best=0.19621
# epoch 1620 | train_loss=0.01600 | val_rmse_log=0.19760 | within_10=0.8096 | best=0.19621
# epoch 1625 | train_loss=0.01603 | val_rmse_log=0.19817 | within_10=0.8079 | best=0.19621
# epoch 1630 | train_loss=0.01596 | val_rmse_log=0.19804 | within_10=0.8069 | best=0.19621
# epoch 1635 | train_loss=0.01600 | val_rmse_log=0.19956 | within_10=0.8004 | best=0.19621
# epoch 1640 | train_loss=0.01604 | val_rmse_log=0.19875 | within_10=0.8043 | best=0.19621
# epoch 1645 | train_loss=0.01602 | val_rmse_log=0.19825 | within_10=0.8100 | best=0.19621
# epoch 1650 | train_loss=0.01598 | val_rmse_log=0.19850 | within_10=0.8055 | best=0.19621
# epoch 1655 | train_loss=0.01597 | val_rmse_log=0.19815 | within_10=0.8095 | best=0.19621
# epoch 1660 | train_loss=0.01591 | val_rmse_log=0.19827 | within_10=0.8020 | best=0.19621
# epoch 1665 | train_loss=0.01596 | val_rmse_log=0.19731 | within_10=0.8109 | best=0.19621
# epoch 1670 | train_loss=0.01592 | val_rmse_log=0.19864 | within_10=0.8089 | best=0.19621
# epoch 1675 | train_loss=0.01593 | val_rmse_log=0.19865 | within_10=0.8078 | best=0.19621
# epoch 1680 | train_loss=0.01598 | val_rmse_log=0.19906 | within_10=0.8037 | best=0.19621
# epoch 1685 | train_loss=0.01598 | val_rmse_log=0.19914 | within_10=0.8000 | best=0.19621
# epoch 1690 | train_loss=0.01597 | val_rmse_log=0.19831 | within_10=0.8091 | best=0.19621
# epoch 1695 | train_loss=0.01592 | val_rmse_log=0.19913 | within_10=0.8009 | best=0.19621
# epoch 1700 | train_loss=0.01589 | val_rmse_log=0.19866 | within_10=0.8010 | best=0.19621
# epoch 1705 | train_loss=0.01630 | val_rmse_log=0.21189 | within_10=0.8046 | best=0.19621
# epoch 1710 | train_loss=0.01593 | val_rmse_log=0.19864 | within_10=0.8103 | best=0.19621
# epoch 1715 | train_loss=0.01600 | val_rmse_log=0.19858 | within_10=0.8011 | best=0.19621
# epoch 1720 | train_loss=0.01591 | val_rmse_log=0.19797 | within_10=0.7994 | best=0.19621
# epoch 1725 | train_loss=0.01602 | val_rmse_log=0.19752 | within_10=0.8069 | best=0.19621
# epoch 1730 | train_loss=0.01601 | val_rmse_log=0.19872 | within_10=0.7957 | best=0.19621
# epoch 1735 | train_loss=0.01593 | val_rmse_log=0.19722 | within_10=0.8097 | best=0.19621
# epoch 1740 | train_loss=0.01599 | val_rmse_log=0.21398 | within_10=0.7982 | best=0.19621
# epoch 1745 | train_loss=0.01591 | val_rmse_log=0.19831 | within_10=0.8065 | best=0.19621
# epoch 1750 | train_loss=0.01595 | val_rmse_log=0.19753 | within_10=0.8070 | best=0.19621
# epoch 1755 | train_loss=0.01602 | val_rmse_log=0.19884 | within_10=0.8058 | best=0.19621
# epoch 1760 | train_loss=0.01592 | val_rmse_log=0.19955 | within_10=0.7972 | best=0.19621
# epoch 1765 | train_loss=0.01589 | val_rmse_log=0.19793 | within_10=0.8074 | best=0.19621
# epoch 1770 | train_loss=0.01587 | val_rmse_log=0.19938 | within_10=0.8029 | best=0.19621
# epoch 1775 | train_loss=0.01581 | val_rmse_log=0.19806 | within_10=0.8088 | best=0.19621
# epoch 1780 | train_loss=0.01596 | val_rmse_log=0.19797 | within_10=0.8065 | best=0.19621
# epoch 1785 | train_loss=0.01598 | val_rmse_log=0.19849 | within_10=0.8084 | best=0.19621
# epoch 1790 | train_loss=0.01749 | val_rmse_log=0.20748 | within_10=0.8005 | best=0.19621
# epoch 1795 | train_loss=0.01593 | val_rmse_log=0.19952 | within_10=0.8044 | best=0.19621
# epoch 1800 | train_loss=0.01590 | val_rmse_log=0.19832 | within_10=0.8090 | best=0.19621
# epoch 1805 | train_loss=0.01586 | val_rmse_log=0.19734 | within_10=0.8076 | best=0.19621
# epoch 1810 | train_loss=0.01600 | val_rmse_log=0.19919 | within_10=0.8035 | best=0.19621
# epoch 1815 | train_loss=0.01591 | val_rmse_log=0.19821 | within_10=0.8067 | best=0.19621
# epoch 1820 | train_loss=0.01606 | val_rmse_log=0.20060 | within_10=0.8011 | best=0.19621
# epoch 1825 | train_loss=0.01596 | val_rmse_log=0.19792 | within_10=0.8074 | best=0.19621
# epoch 1830 | train_loss=0.01593 | val_rmse_log=0.19845 | within_10=0.8110 | best=0.19621
# epoch 1835 | train_loss=0.01590 | val_rmse_log=0.19888 | within_10=0.8027 | best=0.19621
# epoch 1840 | train_loss=0.01595 | val_rmse_log=0.19865 | within_10=0.8097 | best=0.19621
# epoch 1845 | train_loss=0.01595 | val_rmse_log=0.19779 | within_10=0.8082 | best=0.19621
# epoch 1850 | train_loss=0.01597 | val_rmse_log=0.20033 | within_10=0.8036 | best=0.19621
# epoch 1855 | train_loss=0.01599 | val_rmse_log=0.19869 | within_10=0.7982 | best=0.19621
# epoch 1860 | train_loss=0.01618 | val_rmse_log=0.19825 | within_10=0.8079 | best=0.19621
# epoch 1865 | train_loss=0.01594 | val_rmse_log=0.19782 | within_10=0.8127 | best=0.19621
# epoch 1870 | train_loss=0.01591 | val_rmse_log=0.19887 | within_10=0.8062 | best=0.19621
# epoch 1875 | train_loss=0.01604 | val_rmse_log=0.19838 | within_10=0.8072 | best=0.19621
# epoch 1880 | train_loss=0.01590 | val_rmse_log=0.19847 | within_10=0.8018 | best=0.19621
# epoch 1885 | train_loss=0.01598 | val_rmse_log=0.19805 | within_10=0.8024 | best=0.19621
# epoch 1890 | train_loss=0.01589 | val_rmse_log=0.19866 | within_10=0.8042 | best=0.19621
# epoch 1895 | train_loss=0.01601 | val_rmse_log=0.19744 | within_10=0.8116 | best=0.19621
# epoch 1900 | train_loss=0.01583 | val_rmse_log=0.19913 | within_10=0.8071 | best=0.19621
# epoch 1905 | train_loss=0.01578 | val_rmse_log=0.19872 | within_10=0.7993 | best=0.19621
# epoch 1910 | train_loss=0.01692 | val_rmse_log=0.19846 | within_10=0.7980 | best=0.19621
# epoch 1915 | train_loss=0.01580 | val_rmse_log=0.19793 | within_10=0.8039 | best=0.19621
# epoch 1920 | train_loss=0.01591 | val_rmse_log=0.19815 | within_10=0.8039 | best=0.19621
# epoch 1925 | train_loss=0.01591 | val_rmse_log=0.19788 | within_10=0.8124 | best=0.19621
# epoch 1930 | train_loss=0.01594 | val_rmse_log=0.19812 | within_10=0.8081 | best=0.19621
# epoch 1935 | train_loss=0.01594 | val_rmse_log=0.19885 | within_10=0.8043 | best=0.19621
# epoch 1940 | train_loss=0.01592 | val_rmse_log=0.19912 | within_10=0.8021 | best=0.19621
# epoch 1945 | train_loss=0.01608 | val_rmse_log=0.20079 | within_10=0.8015 | best=0.19621
# epoch 1950 | train_loss=0.01575 | val_rmse_log=0.19899 | within_10=0.8065 | best=0.19621
# epoch 1955 | train_loss=0.01597 | val_rmse_log=0.19774 | within_10=0.8121 | best=0.19621
# epoch 1960 | train_loss=0.01585 | val_rmse_log=0.19958 | within_10=0.8097 | best=0.19621
# epoch 1965 | train_loss=0.01582 | val_rmse_log=0.19990 | within_10=0.8047 | best=0.19621
# epoch 1970 | train_loss=0.01590 | val_rmse_log=0.20151 | within_10=0.7965 | best=0.19621
# epoch 1975 | train_loss=0.01597 | val_rmse_log=0.19873 | within_10=0.8006 | best=0.19621
# epoch 1980 | train_loss=0.01596 | val_rmse_log=0.19817 | within_10=0.8069 | best=0.19621
# epoch 1985 | train_loss=0.01593 | val_rmse_log=0.19905 | within_10=0.8061 | best=0.19621
# epoch 1990 | train_loss=0.01602 | val_rmse_log=0.19894 | within_10=0.8010 | best=0.19621
# epoch 1995 | train_loss=0.01574 | val_rmse_log=0.20208 | within_10=0.7801 | best=0.19621
# epoch 2000 | train_loss=0.01592 | val_rmse_log=0.19830 | within_10=0.8098 | best=0.19621

# %% [markdown]
# # Evaluation

# %%
import pandas as pd
import matplotlib.pyplot as plt

history_df = pd.DataFrame(history)

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(
    history_df["epoch"],
    history_df["train_loss"],
    label="Train loss",
    color="tab:blue",
)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Train loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()

ax2.plot(
    history_df["epoch"],
    history_df["within_10pct"],
    label="Within 10%",
    color="tab:orange",
)

ax2.set_ylabel("Within 10%", color="tab:orange")
ax2.tick_params(axis="y", labelcolor="tab:orange")
ax2.set_ylim(0, 1)

fig.suptitle("Training Loss and Within-10% Accuracy Over Time")
fig.tight_layout()
plt.show()

# %%
model.load_state_dict(best_state["model"])
print("Best epoch:", best_state["epoch"])
print("Best val RMSE:", best_state["val_rmse"])
# Out:
# Best epoch: 489
# Best val RMSE: 0.19621406374974873

# %%
val_metrics, val_true_log, val_pred_log = evaluate_mlp(model, val_loader)
test_metrics, test_true_log, test_pred_log = evaluate_mlp(model, test_loader)

pd.DataFrame([val_metrics, test_metrics], index=["val", "test"])
# Out:
#       rmse_log     rmse_ms  rmse_percent  median_relative_error  \
# val   0.198298  140.394867      0.326582               0.029584
# test  0.182711  107.552799      0.226258               0.028654
#
#       p90_relative_error  p95_relative_error  within_10pct  \
# val             0.192861            0.329999      0.809798
# test            0.191106            0.327739      0.816787
#
#       median_ratio_error  p90_ratio_error  within_25pct  within_50pct  \
# val             1.029934         1.215036      0.928955      0.973163
# test            1.028976         1.212967      0.929560      0.974279
#
#       within_2x
# val    0.986045
# test   0.986750

# %% [markdown]
# # Save Model

# %%
from pathlib import Path
import torch

model_dir = Path("/content/drive/MyDrive/Models")
model_dir.mkdir(parents=True, exist_ok=True)

save_path = model_dir / "6.pt"

# If using early stopping, load best weights before saving
if "best_state" in globals() and best_state is not None:
    model.load_state_dict(best_state["model"])

torch.save(
    {
        "model_state_dict": model.state_dict(),
        "n_model_features": X_model_train.shape[1],
        "n_hw_features": X_hw_train.shape[1],
        "model_feature_cols": model_feature_cols,
        "model_scaler": model_scaler,
        "hw_scaler": hw_scaler,
        "target_col": "log_average_ms",
        "best_val_rmse": best_val_rmse if "best_val_rmse" in globals() else None,
    },
    save_path,
)

print("Saved to:", save_path)
# Out:
# Saved to: /content/drive/MyDrive/Models/6.pt

# %% [markdown]
# # Analysis

# %%
test_results = test_df.copy()

test_results["pred_log_latency"] = test_pred_log
test_results["true_log_latency"] = test_true_log

test_results["pred_latency_ms"] = np.exp(test_results["pred_log_latency"])
test_results["true_latency_ms"] = np.exp(test_results["true_log_latency"])

test_results["relative_error"] = (
    np.abs(test_results["pred_latency_ms"] - test_results["true_latency_ms"])
    / test_results["true_latency_ms"]
)

# %%
def group_latency_metrics(g):
    y_true = g["true_log_latency"].to_numpy()
    y_pred = g["pred_log_latency"].to_numpy()

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    return pd.Series({
        "count": len(g),
        "rmse_log": np.sqrt(mean_squared_error(y_true, y_pred)),
        "within_10pct": np.mean(rel_err <= 0.10),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
    })

# %%
test_results["abs_log_error"] = np.abs(
    test_results["pred_log_latency"] - test_results["true_log_latency"]
)

test_results.groupby(["cpu_provider", "platform", "num_cores"])["relative_error"].agg(
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
    within_10pct=lambda x: (x <= 0.10).mean(),
    within_25pct=lambda x: (x <= 0.25).mean(),
).reset_index()
# Out:
#   cpu_provider  platform  num_cores  count    median       p90  within_10pct  \
# 0          amd    gcloud          1   2636  0.023210  0.092936      0.908574
# 1          amd    gcloud          2   4015  0.044060  0.177614      0.767123
# 2          amd    gcloud          4   2737  0.052551  0.254220      0.700767
# 3        intel  bluehive          1   1347  0.022236  0.166909      0.851522
# 4        intel  bluehive          2   2686  0.018175  0.154792      0.854803
# 5        intel  bluehive          4   3999  0.021426  0.257947      0.802201
# 6        intel  bluehive          8   2712  0.034885  0.478296      0.708333
# 7        intel    gcloud          6   1351  0.025511  0.209834      0.823094
#
#    within_25pct
# 0      0.979514
# 1      0.953176
# 2      0.896237
# 3      0.948775
# 4      0.934475
# 5      0.898225
# 6      0.807891
# 7      0.916358

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"])["cv"].agg(
    within_10pct=lambda x: (x <= 0.10).mean(),
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
).reset_index()
# Out:
#   cpu_provider  platform  num_cores  within_10pct  count    median       p90
# 0          amd    gcloud          1      0.994310   2636  0.008788  0.027356
# 1          amd    gcloud          2      0.937235   4015  0.031481  0.086614
# 2          amd    gcloud          4      0.910851   2737  0.038253  0.096363
# 3        intel  bluehive          1      1.000000   1347  0.002264  0.006687
# 4        intel  bluehive          2      1.000000   2686  0.004681  0.017785
# 5        intel  bluehive          4      0.980495   3999  0.004934  0.020884
# 6        intel  bluehive          8      0.865413   2712  0.004852  0.207891
# 7        intel    gcloud          6      0.999260   1351  0.007213  0.016820

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"]).apply(
    group_latency_metrics,
    include_groups=False
).reset_index()
# Out:
#   cpu_provider  platform  num_cores   count  rmse_log  within_10pct  \
# 0          amd    gcloud          1  2636.0  0.087102      0.908574
# 1          amd    gcloud          2  4015.0  0.142931      0.767123
# 2          amd    gcloud          4  2737.0  0.173881      0.700767
# 3        intel  bluehive          1  1347.0  0.201887      0.851522
# 4        intel  bluehive          2  2686.0  0.196294      0.854803
# 5        intel  bluehive          4  3999.0  0.227768      0.802201
# 6        intel  bluehive          8  2712.0  0.354221      0.708333
# 7        intel    gcloud          6  1351.0  0.206487      0.823094
#
#    within_25pct  within_50pct
# 0      0.979514      0.995068
# 1      0.953176      0.987049
# 2      0.896237      0.977713
# 3      0.948775      0.972532
# 4      0.934475      0.970588
# 5      0.898225      0.958490
# 6      0.807891      0.904867
# 7      0.916358      0.964471
