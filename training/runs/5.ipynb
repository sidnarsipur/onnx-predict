# %%
from sklearn.metrics import mean_squared_error
import pandas as pd

# %% [markdown]
# # Load and pre-process data

# %%
target_col = "log_average_ms"

node_cols = ["Abs", "Acos", "Add", "ai.onnx.ml::CategoryMapper", "And", "ArgMax", 
             "AveragePool", "BatchNormalization", "Cast", "Ceil", "Clip", 
             "com.microsoft::BiasGelu", "com.microsoft::DynamicQuantizeLSTM", 
             "com.microsoft::DynamicQuantizeMatMul", "com.microsoft::FastGelu", 
             "com.microsoft::FusedConv", "com.microsoft::FusedGemm", 
             "com.microsoft::FusedMatMul", "com.microsoft::MatMulIntegerToFloat", 
             "com.microsoft::QGemm", "com.microsoft::QLinearAdd", 
             "com.microsoft::QLinearAveragePool", "com.microsoft::QLinearConcat", 
             "com.microsoft::QLinearGlobalAveragePool", "com.microsoft::QLinearLeakyRelu", 
             "com.microsoft::QLinearMul", "com.microsoft::QLinearSigmoid", 
             "com.microsoft::QuickGelu", "com.microsoft::SkipLayerNormalization", 
             "Compress", "Concat", "Constant", "ConstantOfShape", "Conv", "ConvInteger", 
             "ConvTranspose", "Cos", "CumSum", "DequantizeLinear", "Div", "Dropout", 
             "DynamicQuantizeLinear", "Einsum", "Equal", "Erf", "Exp", "Expand", 
             "EyeLike", "Flatten", "Floor", "Gather", "GatherElements", "GatherND", 
             "Gelu", "Gemm", "GlobalAveragePool", "Greater", "GreaterOrEqual", "Hardmax", 
             "HardSigmoid", "HardSwish", "Identity", "If", "InstanceNormalization", 
             "LayerNormalization", "LeakyRelu", "Less", "LessOrEqual", "local::preprocess", 
             "Log", "LogSoftmax", "Loop", "LRN", "LSTM", "MatMul", "MatMulInteger", 
             "Max", "MaxPool", "Min", "Mod", "Mul", "Neg", "NonMaxSuppression", "NonZero", 
             "Not", "OneHot", "Or", "Pad", "Pow", "PRelu", "QLinearConv", "QLinearMatMul", 
             "QuantizeLinear", "Range", "Reciprocal", "ReduceMax", "ReduceMean", "ReduceMin", 
             "ReduceProd", "ReduceSum", "Relu", "Reshape", "Resize", "RoiAlign", "Round", 
             "Scan", "ScatterElements", "ScatterND", "Shape", "Sigmoid", 
             "SimplifiedLayerNormalization", "Sin", "Slice", "Softmax", "Split", "Sqrt", 
             "Squeeze", "Sub", "Sum", "Tanh", "Tile", "TopK", "Transpose", "Trilu", 
             "Unsqueeze", "Where", "Xor"]


# node_cols = ["Constant", "Reshape", "Add", "Conv",
#              "Mul", "Transpose", "Relu", "MatMul",
#              "Gemm", "Unsqueeze"]


# extra_cols = ["movement_frac_x_cores", "mb_per_core"]

model_feature_cols = node_cols + ["conv_flops", "matmul_flops",
                "elementwise_mb", "reduction_mb", "normalization_mb",
                "movement_mb", "memory_mb"]

hardware_feature_cols = ["l1d_cache_kb", "l1i_cache_kb", "l2_cache_kb", 
                         "base_clock_mhz", "num_cores", "memory_bandwith_gbs", 
                         "cpu_provider"]

metadata_cols = ["model", "cpu_provider",
                 "machine_type", "platform", "run_id"]

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load test, train, val sets

train_df = pd.read_csv("/content/drive/MyDrive/Data/train_set.csv")
val_df = pd.read_csv("/content/drive/MyDrive/Data/val_set.csv")
test_df = pd.read_csv("/content/drive/MyDrive/Data/test_set.csv")

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (100252, 154)
# val: (21483, 154)
# test: (21483, 154)

# %%
assert list(train_df.columns) == list(val_df.columns) == list(test_df.columns)

train_df.head()
# Out:
#                                                model input_dimensions  \
# 0                hardcorenas_d_Opset17_extended.onnx    x:1x3x224x224
# 1  vit_base_patch8_224_in21k_Opset17_disable_all....    x:1x3x224x224
# 2    tf_efficientnetv2_m_in21ft1k_Opset17_basic.onnx    x:1x3x384x384
# 3                    shufflenet_v2_x1_5_Opset16.onnx    x:1x3x224x224
# 4                 wide_resnet101_2_Opset16_timm.onnx    x:1x3x224x224
#
#   input_dtypes output_dimensions output_dtypes   conv_flops  matmul_flops  \
# 0    x:float32        668:1x1000   668:float32    472440512       2560000
# 1    x:float32      1089:1x21843  1089:float32    231211008  156097479168
# 2    x:float32       2466:1x1000  2466:float32  31470991360       2560000
# 3    x:float32       1137:1x1000  1137:float32    266034528       2048000
# 4    x:float32        971:1x1000   971:float32  45502005248       4096000
#
#    elementwise_mb  reduction_mb  normalization_mb  ...  base_clock_mhz  \
# 0       50.528229      5.204269          0.000000  ...        2300.000
# 1     1771.169711      0.000000        792.141724  ...        2450.000
# 2     1201.339462     67.736023          0.000000  ...        2449.998
# 3        8.246674      1.630875          0.000000  ...        2449.998
# 4      252.656250      4.218750          0.000000  ...        2300.000
#
#    memory_bandwith_gbs  cpu_provider  machine_type  platform  \
# 0                  717         intel     xeon_plat  bluehive
# 1                  205           amd          epyc    gcloud
# 2                  205           amd          epyc    gcloud
# 3                  205           amd          epyc    gcloud
# 4                  717         intel     xeon_plat  bluehive
#
#                                    repo_file   average_ms   stddev_ms  \
# 0                 hardcorenas_d_Opset17.onnx    14.069188    0.082284
# 1     vit_base_patch8_224_in21k_Opset17.onnx  1481.456045  150.199862
# 2  tf_efficientnetv2_m_in21ft1k_Opset17.onnx   301.127424   12.889699
# 3            shufflenet_v2_x1_5_Opset16.onnx     8.161246    0.036559
# 4         wide_resnet101_2_Opset16_timm.onnx    38.147223    0.068437
#
#         min_ms       max_ms
# 0    13.931521    14.247209
# 1  1094.324125  1632.506909
# 2   286.464729   324.336829
# 3     8.080030     8.197800
# 4    38.035275    38.292409
#
# [5 rows x 154 columns]

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

# %%
# pre-processing function

def preprocess(df: pd.DataFrame, train=False) -> pd.DataFrame:

  #drop rows with missing features
  df = df.dropna(subset=["average_ms"])

  #remove rows with high standard deviation (only for train)
  cv_limit = 0.1 # 10% cv limit
  df["cv"] = df["stddev_ms"] / df["average_ms"]

  if train:
    df = df[df["cv"] <= cv_limit].copy()

  #add log_average_ms column
  df["log_average_ms"] = np.log(df["average_ms"])

  #remove decimals and round down
  for col in ["elementwise_mb", "reduction_mb", "normalization_mb", "movement_mb"]:
    df[col] = df[col].round(0)

  return df

# %%
train_df = preprocess(train_df, True)
test_df = preprocess(test_df, False)
val_df = preprocess(val_df, False)

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (95814, 156)
# val: (21483, 156)
# test: (21483, 156)

# %%
for col in model_feature_cols:
    train_df[col] = np.log1p(train_df[col])
    val_df[col] = np.log1p(val_df[col])
    test_df[col] = np.log1p(test_df[col])

# %% [markdown]
# # Data Setup

# %%
target_col = "log_average_ms"

# %%
cpu_provider_map = {
    "intel": 0.0,
    "amd": 1.0,
}

for df in [train_df, val_df, test_df]:
    df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

    if df["cpu_provider_binary"].isna().any():
        bad_values = df.loc[df["cpu_provider_binary"].isna(), "cpu_provider"].unique()
        raise ValueError(f"Unknown cpu_provider values: {bad_values}")

hardware_feature_cols.remove("cpu_provider")
hardware_feature_cols.append("cpu_provider_binary")
# Out:
# /tmp/ipykernel_31305/2739234318.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_31305/2739234318.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_31305/2739234318.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

# %%
X_model_train = train_df[model_feature_cols].astype("float32").to_numpy()
X_model_val = val_df[model_feature_cols].astype("float32").to_numpy()
X_model_test = test_df[model_feature_cols].astype("float32").to_numpy()

X_hw_train = train_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_val = val_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_test = test_df[hardware_feature_cols].astype("float32").to_numpy()

y_train = train_df[target_col].astype("float32").to_numpy()
y_val = val_df[target_col].astype("float32").to_numpy()
y_test = test_df[target_col].astype("float32").to_numpy()

# %%
model_scaler = StandardScaler()
hw_scaler = StandardScaler()

X_model_train = model_scaler.fit_transform(X_model_train).astype("float32")
X_model_val = model_scaler.transform(X_model_val).astype("float32")
X_model_test = model_scaler.transform(X_model_test).astype("float32")

X_hw_train = hw_scaler.fit_transform(X_hw_train).astype("float32")
X_hw_val = hw_scaler.transform(X_hw_val).astype("float32")
X_hw_test = hw_scaler.transform(X_hw_test).astype("float32")

# %% [markdown]
# # Model Setup

# %%
def rmse_log(y_true, y_pred):
  return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class TwoTowerLatencyDataset(Dataset):
    def __init__(self, X_model, X_hw, y):
        self.X_model = torch.from_numpy(X_model)
        self.X_hw = torch.from_numpy(X_hw)
        self.y = torch.from_numpy(y)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X_model[idx], self.X_hw[idx], self.y[idx]

# %%
batch_size = 1024

train_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_train, X_hw_train, y_train),
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
)

val_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_val, X_hw_val, y_val),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

test_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_test, X_hw_test, y_test),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout=0.10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.LayerNorm(dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim),
        )
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        return self.norm(x + self.net(x))


class TwoTowerLatencyMLP(nn.Module):
    def __init__(self, n_model_features: int, n_hw_features: int):
        super().__init__()

        emb_dim = 128

        self.model_in = nn.Sequential(
            nn.Linear(n_model_features, 256),
            nn.LayerNorm(256),
            nn.GELU(),
            nn.Dropout(0.10),
            nn.Linear(256, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        self.model_blocks = nn.Sequential(
            ResidualBlock(emb_dim, dropout=0.10),
            ResidualBlock(emb_dim, dropout=0.05),
        )

        self.hw_tower = nn.Sequential(
            nn.Linear(n_hw_features, 64),
            nn.LayerNorm(64),
            nn.GELU(),
            nn.Linear(64, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        # Hardware produces feature-wise scale and shift for model embedding
        self.hw_film = nn.Linear(emb_dim, emb_dim * 2)

        self.fusion = nn.Sequential(
            nn.Linear(emb_dim * 4, 256),
            nn.LayerNorm(256),
            nn.GELU(),
            nn.Dropout(0.10),

            nn.Linear(256, 128),
            nn.LayerNorm(128),
            nn.GELU(),
            nn.Dropout(0.05),

            nn.Linear(128, 1),
        )

    def forward(self, model_x, hw_x):
        model_emb = self.model_in(model_x)
        model_emb = self.model_blocks(model_emb)

        hw_emb = self.hw_tower(hw_x)

        gamma, beta = self.hw_film(hw_emb).chunk(2, dim=1)
        conditioned_model = model_emb * (1 + gamma) + beta

        interaction = conditioned_model * hw_emb
        diff = torch.abs(conditioned_model - hw_emb)

        fused = torch.cat(
            [conditioned_model, hw_emb, interaction, diff],
            dim=1,
        )

        return self.fusion(fused).squeeze(1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
print("model features:", X_model_train.shape[1])
print("hardware features:", X_hw_train.shape[1])
# Out:
# model features: 134
# hardware features: 7

# %%
model = TwoTowerLatencyMLP(
    n_model_features=len(model_feature_cols),
    n_hw_features=X_hw_train.shape[1],
).to(device)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    weight_decay=1e-4,
)

loss_fn = nn.SmoothL1Loss()  # Huber loss on log latency

# %% [markdown]
# # Model Training

# %%
from sklearn.metrics import mean_squared_error

# %%
def evaluate_mlp(model, loader):
    model.eval()

    preds = []
    targets = []

    with torch.no_grad():
        for model_x, hw_x, y in loader:
            model_x = model_x.to(device)
            hw_x = hw_x.to(device)
            y = y.to(device)

            pred = model(model_x, hw_x)

            preds.append(pred.cpu().numpy())
            targets.append(y.cpu().numpy())

    y_pred = np.concatenate(preds)
    y_true = np.concatenate(targets)

    rmse_log = np.sqrt(mean_squared_error(y_true, y_pred))

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    metrics = {
        "rmse_log": rmse_log,
        "rmse_ms": np.sqrt(mean_squared_error(true_ms, pred_ms)),
        "rmse_percent": np.sqrt(mean_squared_error(rel_err, np.zeros_like(rel_err))),
        "median_relative_error": np.median(rel_err),
        "p90_relative_error": np.percentile(rel_err, 90),
        "p95_relative_error": np.percentile(rel_err, 95),
        "within_10pct": np.mean(rel_err <= 0.10),
        "median_ratio_error": np.median(np.maximum(pred_ms / true_ms, true_ms / pred_ms)),
        "p90_ratio_error": np.percentile(np.maximum(pred_ms / true_ms, true_ms / pred_ms), 90),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
        "within_2x": np.mean(np.maximum(pred_ms / true_ms, true_ms / pred_ms) <= 2.0),
    }

    return metrics, y_true, y_pred

# %%
best_val_rmse = float("inf")
best_state = None

num_epochs = 2000

history = []

for epoch in range(1, num_epochs + 1):
    model.train()
    train_losses = []

    for model_x, hw_x, y in train_loader:
        model_x = model_x.to(device)
        hw_x = hw_x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        pred = model(model_x, hw_x)
        loss = loss_fn(pred, y)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        train_losses.append(loss.item())

    val_metrics, _, _ = evaluate_mlp(model, val_loader)
    val_rmse = val_metrics["rmse_log"]

    history.append({
        "epoch": epoch,
        "train_loss": np.mean(train_losses),
        **val_metrics,
    })

    if val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        best_state = {
            "model": model.state_dict(),
            "epoch": epoch,
            "val_rmse": val_rmse,
        }

    if epoch % 5 == 0 or epoch == 1:
        print(
            f"epoch {epoch:03d} | "
            f"train_loss={np.mean(train_losses):.5f} | "
            f"val_rmse_log={val_rmse:.5f} | "
            f"within_10={val_metrics['within_10pct']:.4f} | "
            f"best={best_val_rmse:.5f}"
        )
# Out:
# epoch 001 | train_loss=0.41346 | val_rmse_log=0.49051 | within_10=0.2064 | best=0.49051
# epoch 005 | train_loss=0.06203 | val_rmse_log=0.31952 | within_10=0.3815 | best=0.31952
# epoch 010 | train_loss=0.04618 | val_rmse_log=0.27234 | within_10=0.4744 | best=0.27234
# epoch 015 | train_loss=0.04235 | val_rmse_log=0.26679 | within_10=0.4790 | best=0.26679
# epoch 020 | train_loss=0.03735 | val_rmse_log=0.26424 | within_10=0.5160 | best=0.26214
# epoch 025 | train_loss=0.03609 | val_rmse_log=0.26009 | within_10=0.4788 | best=0.25657
# epoch 030 | train_loss=0.03448 | val_rmse_log=0.25860 | within_10=0.5389 | best=0.24808
# epoch 035 | train_loss=0.03234 | val_rmse_log=0.24948 | within_10=0.5565 | best=0.24808
# epoch 040 | train_loss=0.03149 | val_rmse_log=0.24280 | within_10=0.5927 | best=0.24194
# epoch 045 | train_loss=0.03103 | val_rmse_log=0.24076 | within_10=0.5895 | best=0.24076
# epoch 050 | train_loss=0.02984 | val_rmse_log=0.26094 | within_10=0.5693 | best=0.23979
# epoch 055 | train_loss=0.02782 | val_rmse_log=0.23857 | within_10=0.6175 | best=0.23832
# epoch 060 | train_loss=0.02737 | val_rmse_log=0.23773 | within_10=0.6235 | best=0.23177
# epoch 065 | train_loss=0.02690 | val_rmse_log=0.23466 | within_10=0.6364 | best=0.23177
# epoch 070 | train_loss=0.02812 | val_rmse_log=0.24257 | within_10=0.5999 | best=0.23061
# epoch 075 | train_loss=0.02635 | val_rmse_log=0.23863 | within_10=0.5709 | best=0.23061
# epoch 080 | train_loss=0.02609 | val_rmse_log=0.23600 | within_10=0.6246 | best=0.23061
# epoch 085 | train_loss=0.02642 | val_rmse_log=0.23482 | within_10=0.5862 | best=0.23061
# epoch 090 | train_loss=0.02543 | val_rmse_log=0.23382 | within_10=0.5833 | best=0.23061
# epoch 095 | train_loss=0.02462 | val_rmse_log=0.23156 | within_10=0.6461 | best=0.22676
# epoch 100 | train_loss=0.02556 | val_rmse_log=0.23371 | within_10=0.6150 | best=0.22676
# epoch 105 | train_loss=0.02520 | val_rmse_log=0.23007 | within_10=0.6478 | best=0.22676
# epoch 110 | train_loss=0.02626 | val_rmse_log=0.23763 | within_10=0.6243 | best=0.22676
# epoch 115 | train_loss=0.02452 | val_rmse_log=0.22891 | within_10=0.6500 | best=0.22676
# epoch 120 | train_loss=0.02487 | val_rmse_log=0.23706 | within_10=0.5870 | best=0.22514
# epoch 125 | train_loss=0.02472 | val_rmse_log=0.23196 | within_10=0.6602 | best=0.22514
# epoch 130 | train_loss=0.02351 | val_rmse_log=0.23585 | within_10=0.6399 | best=0.22514
# epoch 135 | train_loss=0.02392 | val_rmse_log=0.23996 | within_10=0.5973 | best=0.22514
# epoch 140 | train_loss=0.02355 | val_rmse_log=0.23840 | within_10=0.6196 | best=0.22514
# epoch 145 | train_loss=0.02279 | val_rmse_log=0.23279 | within_10=0.6527 | best=0.22514
# epoch 150 | train_loss=0.02279 | val_rmse_log=0.22748 | within_10=0.6815 | best=0.22514
# epoch 155 | train_loss=0.02212 | val_rmse_log=0.22527 | within_10=0.6761 | best=0.22514
# epoch 160 | train_loss=0.02263 | val_rmse_log=0.22837 | within_10=0.6674 | best=0.22514
# epoch 165 | train_loss=0.02175 | val_rmse_log=0.22574 | within_10=0.7034 | best=0.22311
# epoch 170 | train_loss=0.02318 | val_rmse_log=0.22844 | within_10=0.6824 | best=0.22311
# epoch 175 | train_loss=0.02163 | val_rmse_log=0.22210 | within_10=0.6932 | best=0.22210
# epoch 180 | train_loss=0.02238 | val_rmse_log=0.22428 | within_10=0.6881 | best=0.22210
# epoch 185 | train_loss=0.02197 | val_rmse_log=0.23376 | within_10=0.6856 | best=0.22210
# epoch 190 | train_loss=0.02113 | val_rmse_log=0.22500 | within_10=0.7169 | best=0.22210
# epoch 195 | train_loss=0.02110 | val_rmse_log=0.22616 | within_10=0.7031 | best=0.22186
# epoch 200 | train_loss=0.02142 | val_rmse_log=0.22502 | within_10=0.7086 | best=0.22186
# epoch 205 | train_loss=0.02076 | val_rmse_log=0.22026 | within_10=0.7195 | best=0.22026
# epoch 210 | train_loss=0.02066 | val_rmse_log=0.22235 | within_10=0.7240 | best=0.22026
# epoch 215 | train_loss=0.02066 | val_rmse_log=0.22269 | within_10=0.7129 | best=0.22026
# epoch 220 | train_loss=0.02108 | val_rmse_log=0.24472 | within_10=0.6530 | best=0.22026
# epoch 225 | train_loss=0.02110 | val_rmse_log=0.22561 | within_10=0.7238 | best=0.22026
# epoch 230 | train_loss=0.02090 | val_rmse_log=0.22372 | within_10=0.7162 | best=0.22026
# epoch 235 | train_loss=0.02026 | val_rmse_log=0.22360 | within_10=0.7199 | best=0.22026
# epoch 240 | train_loss=0.02063 | val_rmse_log=0.22331 | within_10=0.7079 | best=0.22026
# epoch 245 | train_loss=0.02041 | val_rmse_log=0.22132 | within_10=0.7245 | best=0.22026
# epoch 250 | train_loss=0.01998 | val_rmse_log=0.22204 | within_10=0.7214 | best=0.22026
# epoch 255 | train_loss=0.01962 | val_rmse_log=0.22091 | within_10=0.7251 | best=0.21984
# epoch 260 | train_loss=0.02067 | val_rmse_log=0.22501 | within_10=0.6866 | best=0.21984
# epoch 265 | train_loss=0.02012 | val_rmse_log=0.22264 | within_10=0.7164 | best=0.21984
# epoch 270 | train_loss=0.02007 | val_rmse_log=0.22825 | within_10=0.7047 | best=0.21984
# epoch 275 | train_loss=0.01955 | val_rmse_log=0.22338 | within_10=0.7235 | best=0.21984
# epoch 280 | train_loss=0.01953 | val_rmse_log=0.22226 | within_10=0.7000 | best=0.21984
# epoch 285 | train_loss=0.01974 | val_rmse_log=0.23101 | within_10=0.6827 | best=0.21984
# epoch 290 | train_loss=0.02027 | val_rmse_log=0.22027 | within_10=0.7386 | best=0.21984
# epoch 295 | train_loss=0.01927 | val_rmse_log=0.22191 | within_10=0.7385 | best=0.21984
# epoch 300 | train_loss=0.01931 | val_rmse_log=0.22140 | within_10=0.7316 | best=0.21984
# epoch 305 | train_loss=0.01985 | val_rmse_log=0.22069 | within_10=0.7422 | best=0.21984
# epoch 310 | train_loss=0.01931 | val_rmse_log=0.22251 | within_10=0.7405 | best=0.21984
# epoch 315 | train_loss=0.01916 | val_rmse_log=0.22111 | within_10=0.7425 | best=0.21984
# epoch 320 | train_loss=0.01899 | val_rmse_log=0.21953 | within_10=0.7542 | best=0.21953
# epoch 325 | train_loss=0.01943 | val_rmse_log=0.22042 | within_10=0.7517 | best=0.21953
# epoch 330 | train_loss=0.01887 | val_rmse_log=0.22448 | within_10=0.7100 | best=0.21953
# epoch 335 | train_loss=0.01890 | val_rmse_log=0.21897 | within_10=0.7525 | best=0.21897
# epoch 340 | train_loss=0.01864 | val_rmse_log=0.22063 | within_10=0.7478 | best=0.21897
# epoch 345 | train_loss=0.02004 | val_rmse_log=0.22005 | within_10=0.7551 | best=0.21897
# epoch 350 | train_loss=0.01866 | val_rmse_log=0.22295 | within_10=0.7412 | best=0.21897
# epoch 355 | train_loss=0.01869 | val_rmse_log=0.22119 | within_10=0.7350 | best=0.21897
# epoch 360 | train_loss=0.01845 | val_rmse_log=0.22243 | within_10=0.7422 | best=0.21897
# epoch 365 | train_loss=0.01863 | val_rmse_log=0.21992 | within_10=0.7531 | best=0.21897
# epoch 370 | train_loss=0.01846 | val_rmse_log=0.22277 | within_10=0.7390 | best=0.21897
# epoch 375 | train_loss=0.01840 | val_rmse_log=0.22146 | within_10=0.7400 | best=0.21897
# epoch 380 | train_loss=0.01944 | val_rmse_log=0.23949 | within_10=0.5932 | best=0.21897
# epoch 385 | train_loss=0.01824 | val_rmse_log=0.21931 | within_10=0.7560 | best=0.21897
# epoch 390 | train_loss=0.01868 | val_rmse_log=0.23026 | within_10=0.7378 | best=0.21897
# epoch 395 | train_loss=0.01809 | val_rmse_log=0.22184 | within_10=0.7432 | best=0.21897
# epoch 400 | train_loss=0.01916 | val_rmse_log=0.22370 | within_10=0.7345 | best=0.21897
# epoch 405 | train_loss=0.01816 | val_rmse_log=0.22011 | within_10=0.7603 | best=0.21897
# epoch 410 | train_loss=0.01991 | val_rmse_log=0.22275 | within_10=0.7421 | best=0.21897
# epoch 415 | train_loss=0.01822 | val_rmse_log=0.22093 | within_10=0.7547 | best=0.21897
# epoch 420 | train_loss=0.01806 | val_rmse_log=0.22066 | within_10=0.7598 | best=0.21897
# epoch 425 | train_loss=0.01810 | val_rmse_log=0.22547 | within_10=0.7366 | best=0.21897
# epoch 430 | train_loss=0.01951 | val_rmse_log=0.22106 | within_10=0.7572 | best=0.21897
# epoch 435 | train_loss=0.01798 | val_rmse_log=0.21917 | within_10=0.7655 | best=0.21897
# epoch 440 | train_loss=0.01784 | val_rmse_log=0.21936 | within_10=0.7704 | best=0.21897
# epoch 445 | train_loss=0.01794 | val_rmse_log=0.22007 | within_10=0.7544 | best=0.21897
# epoch 450 | train_loss=0.01955 | val_rmse_log=0.22288 | within_10=0.7440 | best=0.21897
# epoch 455 | train_loss=0.01849 | val_rmse_log=0.22165 | within_10=0.7525 | best=0.21897
# epoch 460 | train_loss=0.01773 | val_rmse_log=0.22117 | within_10=0.7601 | best=0.21897
# epoch 465 | train_loss=0.01814 | val_rmse_log=0.22090 | within_10=0.7556 | best=0.21897
# epoch 470 | train_loss=0.01784 | val_rmse_log=0.21872 | within_10=0.7709 | best=0.21872
# epoch 475 | train_loss=0.01778 | val_rmse_log=0.22223 | within_10=0.7592 | best=0.21872
# epoch 480 | train_loss=0.01774 | val_rmse_log=0.22064 | within_10=0.7592 | best=0.21872
# epoch 485 | train_loss=0.01862 | val_rmse_log=0.22331 | within_10=0.7529 | best=0.21872
# epoch 490 | train_loss=0.01757 | val_rmse_log=0.21938 | within_10=0.7651 | best=0.21872
# epoch 495 | train_loss=0.01868 | val_rmse_log=0.23362 | within_10=0.7336 | best=0.21872
# epoch 500 | train_loss=0.01748 | val_rmse_log=0.22009 | within_10=0.7659 | best=0.21872
# epoch 505 | train_loss=0.01753 | val_rmse_log=0.21991 | within_10=0.7676 | best=0.21872
# epoch 510 | train_loss=0.01751 | val_rmse_log=0.21919 | within_10=0.7703 | best=0.21872
# epoch 515 | train_loss=0.01760 | val_rmse_log=0.22073 | within_10=0.7586 | best=0.21872
# epoch 520 | train_loss=0.01782 | val_rmse_log=0.22178 | within_10=0.7511 | best=0.21872
# epoch 525 | train_loss=0.01749 | val_rmse_log=0.21930 | within_10=0.7640 | best=0.21852
# epoch 530 | train_loss=0.01740 | val_rmse_log=0.22087 | within_10=0.7566 | best=0.21742
# epoch 535 | train_loss=0.01929 | val_rmse_log=0.22290 | within_10=0.7479 | best=0.21742
# epoch 540 | train_loss=0.01760 | val_rmse_log=0.22083 | within_10=0.7574 | best=0.21742
# epoch 545 | train_loss=0.01731 | val_rmse_log=0.22241 | within_10=0.7510 | best=0.21742
# epoch 550 | train_loss=0.01750 | val_rmse_log=0.22258 | within_10=0.7531 | best=0.21742
# epoch 555 | train_loss=0.01737 | val_rmse_log=0.21919 | within_10=0.7666 | best=0.21742
# epoch 560 | train_loss=0.01903 | val_rmse_log=0.22346 | within_10=0.7485 | best=0.21742
# epoch 565 | train_loss=0.01745 | val_rmse_log=0.22212 | within_10=0.7654 | best=0.21742
# epoch 570 | train_loss=0.01718 | val_rmse_log=0.22050 | within_10=0.7515 | best=0.21742
# epoch 575 | train_loss=0.01716 | val_rmse_log=0.22012 | within_10=0.7528 | best=0.21742
# epoch 580 | train_loss=0.01715 | val_rmse_log=0.22343 | within_10=0.7532 | best=0.21742
# epoch 585 | train_loss=0.01719 | val_rmse_log=0.22138 | within_10=0.7645 | best=0.21742
# epoch 590 | train_loss=0.01715 | val_rmse_log=0.22141 | within_10=0.7595 | best=0.21742
# epoch 595 | train_loss=0.01723 | val_rmse_log=0.21971 | within_10=0.7653 | best=0.21742
# epoch 600 | train_loss=0.01722 | val_rmse_log=0.21978 | within_10=0.7654 | best=0.21742
# epoch 605 | train_loss=0.01737 | val_rmse_log=0.22287 | within_10=0.7622 | best=0.21742
# epoch 610 | train_loss=0.01722 | val_rmse_log=0.21955 | within_10=0.7744 | best=0.21742
# epoch 615 | train_loss=0.01704 | val_rmse_log=0.21952 | within_10=0.7665 | best=0.21742
# epoch 620 | train_loss=0.01733 | val_rmse_log=0.22357 | within_10=0.7618 | best=0.21742
# epoch 625 | train_loss=0.01699 | val_rmse_log=0.21948 | within_10=0.7776 | best=0.21742
# epoch 630 | train_loss=0.01698 | val_rmse_log=0.21979 | within_10=0.7728 | best=0.21742
# epoch 635 | train_loss=0.01760 | val_rmse_log=0.22153 | within_10=0.7588 | best=0.21742
# epoch 640 | train_loss=0.01721 | val_rmse_log=0.21960 | within_10=0.7800 | best=0.21742
# epoch 645 | train_loss=0.01711 | val_rmse_log=0.23387 | within_10=0.7640 | best=0.21742
# epoch 650 | train_loss=0.01689 | val_rmse_log=0.22191 | within_10=0.7619 | best=0.21742
# epoch 655 | train_loss=0.01694 | val_rmse_log=0.21912 | within_10=0.7740 | best=0.21742
# epoch 660 | train_loss=0.01683 | val_rmse_log=0.22025 | within_10=0.7785 | best=0.21742
# epoch 665 | train_loss=0.01688 | val_rmse_log=0.22006 | within_10=0.7757 | best=0.21742
# epoch 670 | train_loss=0.01850 | val_rmse_log=0.21900 | within_10=0.7735 | best=0.21742
# epoch 675 | train_loss=0.01690 | val_rmse_log=0.22129 | within_10=0.7654 | best=0.21742
# epoch 680 | train_loss=0.01701 | val_rmse_log=0.22099 | within_10=0.7656 | best=0.21742
# epoch 685 | train_loss=0.01680 | val_rmse_log=0.21983 | within_10=0.7740 | best=0.21742
# epoch 690 | train_loss=0.01695 | val_rmse_log=0.21960 | within_10=0.7776 | best=0.21742
# epoch 695 | train_loss=0.01744 | val_rmse_log=0.22276 | within_10=0.7554 | best=0.21742
# epoch 700 | train_loss=0.01680 | val_rmse_log=0.21834 | within_10=0.7835 | best=0.21742
# epoch 705 | train_loss=0.01747 | val_rmse_log=0.22165 | within_10=0.7608 | best=0.21742
# epoch 710 | train_loss=0.01681 | val_rmse_log=0.21910 | within_10=0.7814 | best=0.21742
# epoch 715 | train_loss=0.01698 | val_rmse_log=0.22052 | within_10=0.7730 | best=0.21742
# epoch 720 | train_loss=0.01810 | val_rmse_log=0.22141 | within_10=0.7537 | best=0.21742
# epoch 725 | train_loss=0.01697 | val_rmse_log=0.22034 | within_10=0.7740 | best=0.21742
# epoch 730 | train_loss=0.01668 | val_rmse_log=0.22025 | within_10=0.7692 | best=0.21742
# epoch 735 | train_loss=0.01687 | val_rmse_log=0.22155 | within_10=0.7735 | best=0.21742
# epoch 740 | train_loss=0.01679 | val_rmse_log=0.22092 | within_10=0.7710 | best=0.21742
# epoch 745 | train_loss=0.01692 | val_rmse_log=0.21923 | within_10=0.7706 | best=0.21742
# epoch 750 | train_loss=0.01801 | val_rmse_log=0.22844 | within_10=0.7550 | best=0.21742
# epoch 755 | train_loss=0.01674 | val_rmse_log=0.21917 | within_10=0.7838 | best=0.21742
# epoch 760 | train_loss=0.01812 | val_rmse_log=0.22144 | within_10=0.7807 | best=0.21742
# epoch 765 | train_loss=0.01681 | val_rmse_log=0.21929 | within_10=0.7732 | best=0.21742
# epoch 770 | train_loss=0.01681 | val_rmse_log=0.22139 | within_10=0.7693 | best=0.21742
# epoch 775 | train_loss=0.01661 | val_rmse_log=0.22123 | within_10=0.7698 | best=0.21742
# epoch 780 | train_loss=0.01671 | val_rmse_log=0.22068 | within_10=0.7637 | best=0.21742
# epoch 785 | train_loss=0.01691 | val_rmse_log=0.21985 | within_10=0.7762 | best=0.21742
# epoch 790 | train_loss=0.01689 | val_rmse_log=0.22068 | within_10=0.7705 | best=0.21742
# epoch 795 | train_loss=0.01670 | val_rmse_log=0.22258 | within_10=0.7608 | best=0.21742
# epoch 800 | train_loss=0.01686 | val_rmse_log=0.22049 | within_10=0.7777 | best=0.21742
# epoch 805 | train_loss=0.01654 | val_rmse_log=0.22011 | within_10=0.7761 | best=0.21742
# epoch 810 | train_loss=0.01699 | val_rmse_log=0.22292 | within_10=0.7576 | best=0.21742
# epoch 815 | train_loss=0.01659 | val_rmse_log=0.21972 | within_10=0.7723 | best=0.21742
# epoch 820 | train_loss=0.01663 | val_rmse_log=0.21914 | within_10=0.7767 | best=0.21742
# epoch 825 | train_loss=0.01660 | val_rmse_log=0.21905 | within_10=0.7822 | best=0.21742
# epoch 830 | train_loss=0.01665 | val_rmse_log=0.22087 | within_10=0.7717 | best=0.21742
# epoch 835 | train_loss=0.01669 | val_rmse_log=0.22184 | within_10=0.7717 | best=0.21742
# epoch 840 | train_loss=0.01655 | val_rmse_log=0.22155 | within_10=0.7711 | best=0.21742
# epoch 845 | train_loss=0.01657 | val_rmse_log=0.21941 | within_10=0.7847 | best=0.21742
# epoch 850 | train_loss=0.01673 | val_rmse_log=0.22532 | within_10=0.7406 | best=0.21742
# epoch 855 | train_loss=0.01654 | val_rmse_log=0.22074 | within_10=0.7698 | best=0.21742
# epoch 860 | train_loss=0.01671 | val_rmse_log=0.22119 | within_10=0.7668 | best=0.21742
# epoch 865 | train_loss=0.01657 | val_rmse_log=0.22347 | within_10=0.7608 | best=0.21742
# epoch 870 | train_loss=0.01648 | val_rmse_log=0.22018 | within_10=0.7724 | best=0.21742
# epoch 875 | train_loss=0.01724 | val_rmse_log=0.23224 | within_10=0.7258 | best=0.21742
# epoch 880 | train_loss=0.01657 | val_rmse_log=0.21804 | within_10=0.7857 | best=0.21742
# epoch 885 | train_loss=0.01640 | val_rmse_log=0.22077 | within_10=0.7812 | best=0.21742
# epoch 890 | train_loss=0.01742 | val_rmse_log=0.22067 | within_10=0.7639 | best=0.21742
# epoch 895 | train_loss=0.01647 | val_rmse_log=0.21936 | within_10=0.7811 | best=0.21742
# epoch 900 | train_loss=0.01654 | val_rmse_log=0.22015 | within_10=0.7743 | best=0.21742
# epoch 905 | train_loss=0.01641 | val_rmse_log=0.22041 | within_10=0.7760 | best=0.21742
# epoch 910 | train_loss=0.01657 | val_rmse_log=0.22455 | within_10=0.7711 | best=0.21742
# epoch 915 | train_loss=0.01652 | val_rmse_log=0.21900 | within_10=0.7833 | best=0.21742
# epoch 920 | train_loss=0.01643 | val_rmse_log=0.22014 | within_10=0.7784 | best=0.21742
# epoch 925 | train_loss=0.01640 | val_rmse_log=0.22148 | within_10=0.7734 | best=0.21742
# epoch 930 | train_loss=0.01641 | val_rmse_log=0.22199 | within_10=0.7704 | best=0.21742
# epoch 935 | train_loss=0.01644 | val_rmse_log=0.21900 | within_10=0.7811 | best=0.21742
# epoch 940 | train_loss=0.01641 | val_rmse_log=0.22046 | within_10=0.7747 | best=0.21742
# epoch 945 | train_loss=0.01641 | val_rmse_log=0.21945 | within_10=0.7802 | best=0.21742
# epoch 950 | train_loss=0.01636 | val_rmse_log=0.21809 | within_10=0.7842 | best=0.21742
# epoch 955 | train_loss=0.01641 | val_rmse_log=0.22069 | within_10=0.7808 | best=0.21742
# epoch 960 | train_loss=0.01640 | val_rmse_log=0.21965 | within_10=0.7740 | best=0.21742
# epoch 965 | train_loss=0.01655 | val_rmse_log=0.22089 | within_10=0.7775 | best=0.21742
# epoch 970 | train_loss=0.01642 | val_rmse_log=0.21922 | within_10=0.7831 | best=0.21742
# epoch 975 | train_loss=0.01651 | val_rmse_log=0.22027 | within_10=0.7790 | best=0.21742
# epoch 980 | train_loss=0.01923 | val_rmse_log=0.24734 | within_10=0.7436 | best=0.21742
# epoch 985 | train_loss=0.01646 | val_rmse_log=0.22528 | within_10=0.7687 | best=0.21742
# epoch 990 | train_loss=0.01634 | val_rmse_log=0.21878 | within_10=0.7852 | best=0.21742
# epoch 995 | train_loss=0.01638 | val_rmse_log=0.22026 | within_10=0.7792 | best=0.21742
# epoch 1000 | train_loss=0.01639 | val_rmse_log=0.22049 | within_10=0.7760 | best=0.21742
# epoch 1005 | train_loss=0.01636 | val_rmse_log=0.21907 | within_10=0.7791 | best=0.21742
# epoch 1010 | train_loss=0.01651 | val_rmse_log=0.21921 | within_10=0.7817 | best=0.21742
# epoch 1015 | train_loss=0.01633 | val_rmse_log=0.21985 | within_10=0.7807 | best=0.21742
# epoch 1020 | train_loss=0.01627 | val_rmse_log=0.21946 | within_10=0.7830 | best=0.21742
# epoch 1025 | train_loss=0.01638 | val_rmse_log=0.22080 | within_10=0.7766 | best=0.21742
# epoch 1030 | train_loss=0.01644 | val_rmse_log=0.22172 | within_10=0.7763 | best=0.21742
# epoch 1035 | train_loss=0.01638 | val_rmse_log=0.22180 | within_10=0.7736 | best=0.21742
# epoch 1040 | train_loss=0.01630 | val_rmse_log=0.21930 | within_10=0.7766 | best=0.21742
# epoch 1045 | train_loss=0.01626 | val_rmse_log=0.22102 | within_10=0.7767 | best=0.21742
# epoch 1050 | train_loss=0.01633 | val_rmse_log=0.22009 | within_10=0.7809 | best=0.21742
# epoch 1055 | train_loss=0.01630 | val_rmse_log=0.22085 | within_10=0.7850 | best=0.21742
# epoch 1060 | train_loss=0.01635 | val_rmse_log=0.22117 | within_10=0.7749 | best=0.21742
# epoch 1065 | train_loss=0.01685 | val_rmse_log=0.23470 | within_10=0.7477 | best=0.21742
# epoch 1070 | train_loss=0.01638 | val_rmse_log=0.22062 | within_10=0.7707 | best=0.21742
# epoch 1075 | train_loss=0.01635 | val_rmse_log=0.22119 | within_10=0.7769 | best=0.21742
# epoch 1080 | train_loss=0.01631 | val_rmse_log=0.21884 | within_10=0.7862 | best=0.21742
# epoch 1085 | train_loss=0.01688 | val_rmse_log=0.22171 | within_10=0.7748 | best=0.21742
# epoch 1090 | train_loss=0.01623 | val_rmse_log=0.21923 | within_10=0.7809 | best=0.21742
# epoch 1095 | train_loss=0.01645 | val_rmse_log=0.22073 | within_10=0.7787 | best=0.21742
# epoch 1100 | train_loss=0.01623 | val_rmse_log=0.21914 | within_10=0.7821 | best=0.21742
# epoch 1105 | train_loss=0.01627 | val_rmse_log=0.22002 | within_10=0.7893 | best=0.21742
# epoch 1110 | train_loss=0.01626 | val_rmse_log=0.21825 | within_10=0.7868 | best=0.21742
# epoch 1115 | train_loss=0.01627 | val_rmse_log=0.21902 | within_10=0.7863 | best=0.21742
# epoch 1120 | train_loss=0.01662 | val_rmse_log=0.21938 | within_10=0.7803 | best=0.21742
# epoch 1125 | train_loss=0.01637 | val_rmse_log=0.22140 | within_10=0.7711 | best=0.21742
# epoch 1130 | train_loss=0.01637 | val_rmse_log=0.22205 | within_10=0.7734 | best=0.21742
# epoch 1135 | train_loss=0.01625 | val_rmse_log=0.22089 | within_10=0.7757 | best=0.21742
# epoch 1140 | train_loss=0.01631 | val_rmse_log=0.22192 | within_10=0.7727 | best=0.21742
# epoch 1145 | train_loss=0.01615 | val_rmse_log=0.21948 | within_10=0.7868 | best=0.21742
# epoch 1150 | train_loss=0.01627 | val_rmse_log=0.21941 | within_10=0.7850 | best=0.21742
# epoch 1155 | train_loss=0.01624 | val_rmse_log=0.21880 | within_10=0.7858 | best=0.21742
# epoch 1160 | train_loss=0.01620 | val_rmse_log=0.21961 | within_10=0.7854 | best=0.21742
# epoch 1165 | train_loss=0.01631 | val_rmse_log=0.22033 | within_10=0.7839 | best=0.21742
# epoch 1170 | train_loss=0.01622 | val_rmse_log=0.22105 | within_10=0.7798 | best=0.21742
# epoch 1175 | train_loss=0.01625 | val_rmse_log=0.22067 | within_10=0.7750 | best=0.21742
# epoch 1180 | train_loss=0.01631 | val_rmse_log=0.21985 | within_10=0.7834 | best=0.21742
# epoch 1185 | train_loss=0.01613 | val_rmse_log=0.22203 | within_10=0.7771 | best=0.21742
# epoch 1190 | train_loss=0.01643 | val_rmse_log=0.22231 | within_10=0.7663 | best=0.21742
# epoch 1195 | train_loss=0.01617 | val_rmse_log=0.22082 | within_10=0.7762 | best=0.21742
# epoch 1200 | train_loss=0.01619 | val_rmse_log=0.22120 | within_10=0.7772 | best=0.21742
# epoch 1205 | train_loss=0.01622 | val_rmse_log=0.22034 | within_10=0.7744 | best=0.21742
# epoch 1210 | train_loss=0.01697 | val_rmse_log=0.22114 | within_10=0.7808 | best=0.21742
# epoch 1215 | train_loss=0.01619 | val_rmse_log=0.21917 | within_10=0.7837 | best=0.21742
# epoch 1220 | train_loss=0.01641 | val_rmse_log=0.21935 | within_10=0.7870 | best=0.21742
# epoch 1225 | train_loss=0.01612 | val_rmse_log=0.22010 | within_10=0.7741 | best=0.21742
# epoch 1230 | train_loss=0.01612 | val_rmse_log=0.21963 | within_10=0.7827 | best=0.21742
# epoch 1235 | train_loss=0.01616 | val_rmse_log=0.22115 | within_10=0.7831 | best=0.21742
# epoch 1240 | train_loss=0.01620 | val_rmse_log=0.22103 | within_10=0.7784 | best=0.21742
# epoch 1245 | train_loss=0.01622 | val_rmse_log=0.21946 | within_10=0.7861 | best=0.21742
# epoch 1250 | train_loss=0.01611 | val_rmse_log=0.21965 | within_10=0.7856 | best=0.21742
# epoch 1255 | train_loss=0.01624 | val_rmse_log=0.22114 | within_10=0.7775 | best=0.21742
# epoch 1260 | train_loss=0.01609 | val_rmse_log=0.22116 | within_10=0.7794 | best=0.21742
# epoch 1265 | train_loss=0.01616 | val_rmse_log=0.21999 | within_10=0.7817 | best=0.21742
# epoch 1270 | train_loss=0.01615 | val_rmse_log=0.21931 | within_10=0.7884 | best=0.21742
# epoch 1275 | train_loss=0.01619 | val_rmse_log=0.22151 | within_10=0.7771 | best=0.21742
# epoch 1280 | train_loss=0.01612 | val_rmse_log=0.21923 | within_10=0.7884 | best=0.21742
# epoch 1285 | train_loss=0.01620 | val_rmse_log=0.22029 | within_10=0.7868 | best=0.21742
# epoch 1290 | train_loss=0.01607 | val_rmse_log=0.22140 | within_10=0.7768 | best=0.21742
# epoch 1295 | train_loss=0.01615 | val_rmse_log=0.21888 | within_10=0.7904 | best=0.21742
# epoch 1300 | train_loss=0.01609 | val_rmse_log=0.21988 | within_10=0.7856 | best=0.21742
# epoch 1305 | train_loss=0.01602 | val_rmse_log=0.22199 | within_10=0.7767 | best=0.21742
# epoch 1310 | train_loss=0.01615 | val_rmse_log=0.21911 | within_10=0.7832 | best=0.21742
# epoch 1315 | train_loss=0.01617 | val_rmse_log=0.21937 | within_10=0.7827 | best=0.21742
# epoch 1320 | train_loss=0.01606 | val_rmse_log=0.22028 | within_10=0.7845 | best=0.21742
# epoch 1325 | train_loss=0.01637 | val_rmse_log=0.22317 | within_10=0.7812 | best=0.21742
# epoch 1330 | train_loss=0.01608 | val_rmse_log=0.21998 | within_10=0.7805 | best=0.21742
# epoch 1335 | train_loss=0.01604 | val_rmse_log=0.22023 | within_10=0.7813 | best=0.21742
# epoch 1340 | train_loss=0.01656 | val_rmse_log=0.22220 | within_10=0.7760 | best=0.21742
# epoch 1345 | train_loss=0.01603 | val_rmse_log=0.22041 | within_10=0.7879 | best=0.21742
# epoch 1350 | train_loss=0.01602 | val_rmse_log=0.22053 | within_10=0.7878 | best=0.21742
# epoch 1355 | train_loss=0.01609 | val_rmse_log=0.22110 | within_10=0.7738 | best=0.21742
# epoch 1360 | train_loss=0.01646 | val_rmse_log=0.22181 | within_10=0.7827 | best=0.21742
# epoch 1365 | train_loss=0.01669 | val_rmse_log=0.22117 | within_10=0.7815 | best=0.21742
# epoch 1370 | train_loss=0.01637 | val_rmse_log=0.21915 | within_10=0.7878 | best=0.21742
# epoch 1375 | train_loss=0.01605 | val_rmse_log=0.22208 | within_10=0.7815 | best=0.21742
# epoch 1380 | train_loss=0.01607 | val_rmse_log=0.22082 | within_10=0.7830 | best=0.21742
# epoch 1385 | train_loss=0.01604 | val_rmse_log=0.21885 | within_10=0.7924 | best=0.21742
# epoch 1390 | train_loss=0.01637 | val_rmse_log=0.22264 | within_10=0.7744 | best=0.21742
# epoch 1395 | train_loss=0.01632 | val_rmse_log=0.22110 | within_10=0.7738 | best=0.21742
# epoch 1400 | train_loss=0.01610 | val_rmse_log=0.21994 | within_10=0.7884 | best=0.21742
# epoch 1405 | train_loss=0.01605 | val_rmse_log=0.21960 | within_10=0.7857 | best=0.21742
# epoch 1410 | train_loss=0.01614 | val_rmse_log=0.21991 | within_10=0.7836 | best=0.21742
# epoch 1415 | train_loss=0.01715 | val_rmse_log=0.22820 | within_10=0.7862 | best=0.21742
# epoch 1420 | train_loss=0.01604 | val_rmse_log=0.22330 | within_10=0.7728 | best=0.21742
# epoch 1425 | train_loss=0.01600 | val_rmse_log=0.22048 | within_10=0.7839 | best=0.21742
# epoch 1430 | train_loss=0.01594 | val_rmse_log=0.22094 | within_10=0.7784 | best=0.21742
# epoch 1435 | train_loss=0.01613 | val_rmse_log=0.21882 | within_10=0.7888 | best=0.21742
# epoch 1440 | train_loss=0.01602 | val_rmse_log=0.21889 | within_10=0.7887 | best=0.21742
# epoch 1445 | train_loss=0.01599 | val_rmse_log=0.21914 | within_10=0.7870 | best=0.21742
# epoch 1450 | train_loss=0.01614 | val_rmse_log=0.21981 | within_10=0.7870 | best=0.21742
# epoch 1455 | train_loss=0.01606 | val_rmse_log=0.21905 | within_10=0.7888 | best=0.21742
# epoch 1460 | train_loss=0.01607 | val_rmse_log=0.22176 | within_10=0.7840 | best=0.21742
# epoch 1465 | train_loss=0.01602 | val_rmse_log=0.22123 | within_10=0.7821 | best=0.21742
# epoch 1470 | train_loss=0.01664 | val_rmse_log=0.22403 | within_10=0.7437 | best=0.21742
# epoch 1475 | train_loss=0.01594 | val_rmse_log=0.22156 | within_10=0.7817 | best=0.21742
# epoch 1480 | train_loss=0.01609 | val_rmse_log=0.22114 | within_10=0.7846 | best=0.21742
# epoch 1485 | train_loss=0.01599 | val_rmse_log=0.22043 | within_10=0.7871 | best=0.21742
# epoch 1490 | train_loss=0.01600 | val_rmse_log=0.21994 | within_10=0.7853 | best=0.21742
# epoch 1495 | train_loss=0.01608 | val_rmse_log=0.22192 | within_10=0.7720 | best=0.21742
# epoch 1500 | train_loss=0.01597 | val_rmse_log=0.22136 | within_10=0.7761 | best=0.21742
# epoch 1505 | train_loss=0.01770 | val_rmse_log=0.22233 | within_10=0.7596 | best=0.21742
# epoch 1510 | train_loss=0.01600 | val_rmse_log=0.22082 | within_10=0.7822 | best=0.21742
# epoch 1515 | train_loss=0.01599 | val_rmse_log=0.22184 | within_10=0.7791 | best=0.21742
# epoch 1520 | train_loss=0.01603 | val_rmse_log=0.21957 | within_10=0.7902 | best=0.21742
# epoch 1525 | train_loss=0.01608 | val_rmse_log=0.22052 | within_10=0.7861 | best=0.21742
# epoch 1530 | train_loss=0.02178 | val_rmse_log=0.23122 | within_10=0.7579 | best=0.21742
# epoch 1535 | train_loss=0.01599 | val_rmse_log=0.22038 | within_10=0.7835 | best=0.21742
# epoch 1540 | train_loss=0.01595 | val_rmse_log=0.21925 | within_10=0.7887 | best=0.21742
# epoch 1545 | train_loss=0.01604 | val_rmse_log=0.22021 | within_10=0.7866 | best=0.21742
# epoch 1550 | train_loss=0.01604 | val_rmse_log=0.21885 | within_10=0.7874 | best=0.21742
# epoch 1555 | train_loss=0.01596 | val_rmse_log=0.22068 | within_10=0.7876 | best=0.21742
# epoch 1560 | train_loss=0.01615 | val_rmse_log=0.22015 | within_10=0.7844 | best=0.21742
# epoch 1565 | train_loss=0.01603 | val_rmse_log=0.22132 | within_10=0.7751 | best=0.21742
# epoch 1570 | train_loss=0.01601 | val_rmse_log=0.21998 | within_10=0.7890 | best=0.21742
# epoch 1575 | train_loss=0.01607 | val_rmse_log=0.22156 | within_10=0.7855 | best=0.21742
# epoch 1580 | train_loss=0.01606 | val_rmse_log=0.21911 | within_10=0.7919 | best=0.21742
# epoch 1585 | train_loss=0.01593 | val_rmse_log=0.21998 | within_10=0.7860 | best=0.21742
# epoch 1590 | train_loss=0.01595 | val_rmse_log=0.22083 | within_10=0.7788 | best=0.21742
# epoch 1595 | train_loss=0.01594 | val_rmse_log=0.21992 | within_10=0.7866 | best=0.21742
# epoch 1600 | train_loss=0.01598 | val_rmse_log=0.22063 | within_10=0.7889 | best=0.21742
# epoch 1605 | train_loss=0.01593 | val_rmse_log=0.22067 | within_10=0.7914 | best=0.21742
# epoch 1610 | train_loss=0.01611 | val_rmse_log=0.22032 | within_10=0.7799 | best=0.21742
# epoch 1615 | train_loss=0.01597 | val_rmse_log=0.22177 | within_10=0.7781 | best=0.21742
# epoch 1620 | train_loss=0.01593 | val_rmse_log=0.22157 | within_10=0.7793 | best=0.21742
# epoch 1625 | train_loss=0.01593 | val_rmse_log=0.22193 | within_10=0.7881 | best=0.21742
# epoch 1630 | train_loss=0.01591 | val_rmse_log=0.22204 | within_10=0.7790 | best=0.21742
# epoch 1635 | train_loss=0.01604 | val_rmse_log=0.21959 | within_10=0.7882 | best=0.21742
# epoch 1640 | train_loss=0.01600 | val_rmse_log=0.22143 | within_10=0.7823 | best=0.21742
# epoch 1645 | train_loss=0.01596 | val_rmse_log=0.22233 | within_10=0.7766 | best=0.21742
# epoch 1650 | train_loss=0.01605 | val_rmse_log=0.21961 | within_10=0.7846 | best=0.21742
# epoch 1655 | train_loss=0.01594 | val_rmse_log=0.21967 | within_10=0.7881 | best=0.21742
# epoch 1660 | train_loss=0.01597 | val_rmse_log=0.21863 | within_10=0.7898 | best=0.21742
# epoch 1665 | train_loss=0.01594 | val_rmse_log=0.22066 | within_10=0.7841 | best=0.21742
# epoch 1670 | train_loss=0.01597 | val_rmse_log=0.21994 | within_10=0.7839 | best=0.21742
# epoch 1675 | train_loss=0.01602 | val_rmse_log=0.21969 | within_10=0.7890 | best=0.21742
# epoch 1680 | train_loss=0.01605 | val_rmse_log=0.22132 | within_10=0.7843 | best=0.21742
# epoch 1685 | train_loss=0.01595 | val_rmse_log=0.22086 | within_10=0.7808 | best=0.21742
# epoch 1690 | train_loss=0.01585 | val_rmse_log=0.21967 | within_10=0.7880 | best=0.21742
# epoch 1695 | train_loss=0.01589 | val_rmse_log=0.22061 | within_10=0.7836 | best=0.21742
# epoch 1700 | train_loss=0.01600 | val_rmse_log=0.22220 | within_10=0.7796 | best=0.21742
# epoch 1705 | train_loss=0.01593 | val_rmse_log=0.22177 | within_10=0.7851 | best=0.21742
# epoch 1710 | train_loss=0.01591 | val_rmse_log=0.22004 | within_10=0.7834 | best=0.21742
# epoch 1715 | train_loss=0.01587 | val_rmse_log=0.22071 | within_10=0.7898 | best=0.21742
# epoch 1720 | train_loss=0.01582 | val_rmse_log=0.22216 | within_10=0.7786 | best=0.21742
# epoch 1725 | train_loss=0.01584 | val_rmse_log=0.22052 | within_10=0.7909 | best=0.21742
# epoch 1730 | train_loss=0.01598 | val_rmse_log=0.21968 | within_10=0.7872 | best=0.21742
# epoch 1735 | train_loss=0.01600 | val_rmse_log=0.21923 | within_10=0.7903 | best=0.21742
# epoch 1740 | train_loss=0.01594 | val_rmse_log=0.22059 | within_10=0.7852 | best=0.21742
# epoch 1745 | train_loss=0.01586 | val_rmse_log=0.21974 | within_10=0.7822 | best=0.21742
# epoch 1750 | train_loss=0.01611 | val_rmse_log=0.21963 | within_10=0.7843 | best=0.21742
# epoch 1755 | train_loss=0.01589 | val_rmse_log=0.22173 | within_10=0.7838 | best=0.21742
# epoch 1760 | train_loss=0.01598 | val_rmse_log=0.21969 | within_10=0.7834 | best=0.21742
# epoch 1765 | train_loss=0.01592 | val_rmse_log=0.21983 | within_10=0.7868 | best=0.21742
# epoch 1770 | train_loss=0.01588 | val_rmse_log=0.21971 | within_10=0.7906 | best=0.21742
# epoch 1775 | train_loss=0.01596 | val_rmse_log=0.21928 | within_10=0.7890 | best=0.21742
# epoch 1780 | train_loss=0.01583 | val_rmse_log=0.21938 | within_10=0.7891 | best=0.21742
# epoch 1785 | train_loss=0.01592 | val_rmse_log=0.22130 | within_10=0.7831 | best=0.21742
# epoch 1790 | train_loss=0.01593 | val_rmse_log=0.22012 | within_10=0.7872 | best=0.21742
# epoch 1795 | train_loss=0.01591 | val_rmse_log=0.21875 | within_10=0.7890 | best=0.21742
# epoch 1800 | train_loss=0.01582 | val_rmse_log=0.21956 | within_10=0.7867 | best=0.21742
# epoch 1805 | train_loss=0.01584 | val_rmse_log=0.22146 | within_10=0.7806 | best=0.21742
# epoch 1810 | train_loss=0.01591 | val_rmse_log=0.22070 | within_10=0.7874 | best=0.21742
# epoch 1815 | train_loss=0.01736 | val_rmse_log=0.22504 | within_10=0.7362 | best=0.21742
# epoch 1820 | train_loss=0.01576 | val_rmse_log=0.22044 | within_10=0.7891 | best=0.21742
# epoch 1825 | train_loss=0.01582 | val_rmse_log=0.22127 | within_10=0.7815 | best=0.21742
# epoch 1830 | train_loss=0.01583 | val_rmse_log=0.22029 | within_10=0.7830 | best=0.21742
# epoch 1835 | train_loss=0.01589 | val_rmse_log=0.22026 | within_10=0.7862 | best=0.21742
# epoch 1840 | train_loss=0.01587 | val_rmse_log=0.21891 | within_10=0.7945 | best=0.21742
# epoch 1845 | train_loss=0.01591 | val_rmse_log=0.22280 | within_10=0.7802 | best=0.21742
# epoch 1850 | train_loss=0.01615 | val_rmse_log=0.22192 | within_10=0.7849 | best=0.21742
# epoch 1855 | train_loss=0.01587 | val_rmse_log=0.22172 | within_10=0.7826 | best=0.21742
# epoch 1860 | train_loss=0.01582 | val_rmse_log=0.22134 | within_10=0.7862 | best=0.21742
# epoch 1865 | train_loss=0.01600 | val_rmse_log=0.22216 | within_10=0.7825 | best=0.21742
# epoch 1870 | train_loss=0.01586 | val_rmse_log=0.21945 | within_10=0.7880 | best=0.21742
# epoch 1875 | train_loss=0.01742 | val_rmse_log=0.22200 | within_10=0.7829 | best=0.21742
# epoch 1880 | train_loss=0.01588 | val_rmse_log=0.22195 | within_10=0.7851 | best=0.21742
# epoch 1885 | train_loss=0.01581 | val_rmse_log=0.22017 | within_10=0.7842 | best=0.21742
# epoch 1890 | train_loss=0.01581 | val_rmse_log=0.22022 | within_10=0.7843 | best=0.21742
# epoch 1895 | train_loss=0.01619 | val_rmse_log=0.22619 | within_10=0.7916 | best=0.21742
# epoch 1900 | train_loss=0.01584 | val_rmse_log=0.22101 | within_10=0.7847 | best=0.21742
# epoch 1905 | train_loss=0.01586 | val_rmse_log=0.22049 | within_10=0.7871 | best=0.21742
# epoch 1910 | train_loss=0.01588 | val_rmse_log=0.21906 | within_10=0.7897 | best=0.21742
# epoch 1915 | train_loss=0.01584 | val_rmse_log=0.22097 | within_10=0.7826 | best=0.21742
# epoch 1920 | train_loss=0.01587 | val_rmse_log=0.22129 | within_10=0.7832 | best=0.21742
# epoch 1925 | train_loss=0.01578 | val_rmse_log=0.21982 | within_10=0.7841 | best=0.21742
# epoch 1930 | train_loss=0.01580 | val_rmse_log=0.22140 | within_10=0.7797 | best=0.21742
# epoch 1935 | train_loss=0.01589 | val_rmse_log=0.21939 | within_10=0.7827 | best=0.21742
# epoch 1940 | train_loss=0.01592 | val_rmse_log=0.22095 | within_10=0.7808 | best=0.21742
# epoch 1945 | train_loss=0.01589 | val_rmse_log=0.22025 | within_10=0.7897 | best=0.21742
# epoch 1950 | train_loss=0.01586 | val_rmse_log=0.21945 | within_10=0.7911 | best=0.21742
# epoch 1955 | train_loss=0.01586 | val_rmse_log=0.22111 | within_10=0.7868 | best=0.21742
# epoch 1960 | train_loss=0.01583 | val_rmse_log=0.22015 | within_10=0.7867 | best=0.21742
# epoch 1965 | train_loss=0.01575 | val_rmse_log=0.22174 | within_10=0.7831 | best=0.21742
# epoch 1970 | train_loss=0.01584 | val_rmse_log=0.22020 | within_10=0.7871 | best=0.21742
# epoch 1975 | train_loss=0.01580 | val_rmse_log=0.21978 | within_10=0.7894 | best=0.21742
# epoch 1980 | train_loss=0.01596 | val_rmse_log=0.21853 | within_10=0.7910 | best=0.21742
# epoch 1985 | train_loss=0.01606 | val_rmse_log=0.22028 | within_10=0.7913 | best=0.21742
# epoch 1990 | train_loss=0.01594 | val_rmse_log=0.22021 | within_10=0.7855 | best=0.21742
# epoch 1995 | train_loss=0.01574 | val_rmse_log=0.22131 | within_10=0.7832 | best=0.21742
# epoch 2000 | train_loss=0.01595 | val_rmse_log=0.22008 | within_10=0.7892 | best=0.21742

# %% [markdown]
# # Evaluation

# %%
import pandas as pd
import matplotlib.pyplot as plt

history_df = pd.DataFrame(history)

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(
    history_df["epoch"],
    history_df["train_loss"],
    label="Train loss",
    color="tab:blue",
)

ax1.set_xlabel("Epoch")
ax1.set_ylabel("Train loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()

ax2.plot(
    history_df["epoch"],
    history_df["within_10pct"],
    label="Within 10%",
    color="tab:orange",
)

ax2.set_ylabel("Within 10%", color="tab:orange")
ax2.tick_params(axis="y", labelcolor="tab:orange")
ax2.set_ylim(0, 1)

fig.suptitle("Training Loss and Within-10% Accuracy Over Time")
fig.tight_layout()
plt.show()

# %%
model.load_state_dict(best_state["model"])
print("Best epoch:", best_state["epoch"])
print("Best val RMSE:", best_state["val_rmse"])
# Out:
# Best epoch: 528
# Best val RMSE: 0.21741637650286824

# %%
val_metrics, val_true_log, val_pred_log = evaluate_mlp(model, val_loader)
test_metrics, test_true_log, test_pred_log = evaluate_mlp(model, test_loader)

pd.DataFrame([val_metrics, test_metrics], index=["val", "test"])
# Out:
#       rmse_log     rmse_ms  rmse_percent  median_relative_error  \
# val   0.220082  143.531349      0.335497               0.028991
# test  0.210124  180.000830      0.239345               0.029034
#
#       p90_relative_error  p95_relative_error  within_10pct  \
# val             0.219411            0.401322      0.789229
# test            0.213476            0.404748      0.794908
#
#       median_ratio_error  p90_ratio_error  within_25pct  within_50pct  \
# val             1.029452         1.251246      0.915096      0.966206
# test            1.029510         1.246257      0.915654      0.966764
#
#       within_2x
# val    0.978308
# test   0.977983

# %% [markdown]
# # Save Model

# %%
from pathlib import Path
import torch

model_dir = Path("/content/drive/MyDrive/Models")
model_dir.mkdir(parents=True, exist_ok=True)

save_path = model_dir / "5.pt"

# If using early stopping, load best weights before saving
if "best_state" in globals() and best_state is not None:
    model.load_state_dict(best_state["model"])

torch.save(
    {
        "model_state_dict": model.state_dict(),
        "n_model_features": X_model_train.shape[1],
        "n_hw_features": X_hw_train.shape[1],
        "model_feature_cols": model_feature_cols,
        "model_scaler": model_scaler,
        "hw_scaler": hw_scaler,
        "target_col": "log_average_ms",
        "best_val_rmse": best_val_rmse if "best_val_rmse" in globals() else None,
    },
    save_path,
)

print("Saved to:", save_path)
# Out:
# Saved to: /content/drive/MyDrive/Models/5.pt

# %% [markdown]
# # Analysis

# %%
test_results = test_df.copy()

test_results["pred_log_latency"] = test_pred_log
test_results["true_log_latency"] = test_true_log

test_results["pred_latency_ms"] = np.exp(test_results["pred_log_latency"])
test_results["true_latency_ms"] = np.exp(test_results["true_log_latency"])

test_results["relative_error"] = (
    np.abs(test_results["pred_latency_ms"] - test_results["true_latency_ms"])
    / test_results["true_latency_ms"]
)

# %%
def group_latency_metrics(g):
    y_true = g["true_log_latency"].to_numpy()
    y_pred = g["pred_log_latency"].to_numpy()

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    return pd.Series({
        "count": len(g),
        "rmse_log": np.sqrt(mean_squared_error(y_true, y_pred)),
        "within_10pct": np.mean(rel_err <= 0.10),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
    })

# %%
test_results["abs_log_error"] = np.abs(
    test_results["pred_log_latency"] - test_results["true_log_latency"]
)

test_results.groupby(["cpu_provider", "platform", "num_cores"])["relative_error"].agg(
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
    within_10pct=lambda x: (x <= 0.10).mean(),
    within_25pct=lambda x: (x <= 0.25).mean(),
).reset_index()
# Out:
#   cpu_provider  platform  num_cores  count    median       p90  within_10pct  \
# 0          amd    gcloud          1   2636  0.023210  0.092936      0.908574
# 1          amd    gcloud          2   4015  0.044060  0.177614      0.767123
# 2          amd    gcloud          4   2737  0.052551  0.254220      0.700767
# 3        intel  bluehive          1   1347  0.022236  0.166909      0.851522
# 4        intel  bluehive          2   2686  0.018175  0.154792      0.854803
# 5        intel  bluehive          4   3999  0.021426  0.257947      0.802201
# 6        intel  bluehive          8   2712  0.034885  0.478296      0.708333
# 7        intel    gcloud          6   1351  0.025511  0.209834      0.823094
#
#    within_25pct
# 0      0.979514
# 1      0.953176
# 2      0.896237
# 3      0.948775
# 4      0.934475
# 5      0.898225
# 6      0.807891
# 7      0.916358

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"])["cv"].agg(
    within_10pct=lambda x: (x <= 0.10).mean(),
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
).reset_index()
# Out:
#   cpu_provider  platform  num_cores  within_10pct  count    median       p90
# 0          amd    gcloud          1      0.994310   2636  0.008788  0.027356
# 1          amd    gcloud          2      0.937235   4015  0.031481  0.086614
# 2          amd    gcloud          4      0.910851   2737  0.038253  0.096363
# 3        intel  bluehive          1      1.000000   1347  0.002264  0.006687
# 4        intel  bluehive          2      1.000000   2686  0.004681  0.017785
# 5        intel  bluehive          4      0.980495   3999  0.004934  0.020884
# 6        intel  bluehive          8      0.865413   2712  0.004852  0.207891
# 7        intel    gcloud          6      0.999260   1351  0.007213  0.016820

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"]).apply(
    group_latency_metrics,
    include_groups=False
).reset_index()
# Out:
#   cpu_provider  platform  num_cores   count  rmse_log  within_10pct  \
# 0          amd    gcloud          1  2636.0  0.087102      0.908574
# 1          amd    gcloud          2  4015.0  0.142931      0.767123
# 2          amd    gcloud          4  2737.0  0.173881      0.700767
# 3        intel  bluehive          1  1347.0  0.201887      0.851522
# 4        intel  bluehive          2  2686.0  0.196294      0.854803
# 5        intel  bluehive          4  3999.0  0.227768      0.802201
# 6        intel  bluehive          8  2712.0  0.354221      0.708333
# 7        intel    gcloud          6  1351.0  0.206487      0.823094
#
#    within_25pct  within_50pct
# 0      0.979514      0.995068
# 1      0.953176      0.987049
# 2      0.896237      0.977713
# 3      0.948775      0.972532
# 4      0.934475      0.970588
# 5      0.898225      0.958490
# 6      0.807891      0.904867
# 7      0.916358      0.964471
