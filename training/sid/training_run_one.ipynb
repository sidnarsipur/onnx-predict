# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load and pre-process data

# %%
target_col = "log_average_ms"

feature_cols = ["conv_flops", "matmul_flops",
                  "elementwise_mb", "reduction_mb", "normalization_mb",
                  "movement_mb", "memory_mb", "l1d_cache_kb",
                  "l1i_cache_kb", "l2_cache_kb", "base_clock_mhz",
                  "num_cores", "memory_bandwith_gbs"]

metadata_cols = ["model", "cpu_provider",
                 "machine_type", "platform", "run_id"]

# %%
# load test, train, val sets

train_df = pd.read_csv("train_set.csv")
val_df = pd.read_csv("val_set.csv")
test_df = pd.read_csv("test_set.csv")

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (100252, 154)
# val: (21483, 154)
# test: (21483, 154)

# %%
assert list(train_df.columns) == list(val_df.columns) == list(test_df.columns)

train_df.head()
# Out:
#                                                model input_dimensions  \
# 0                hardcorenas_d_Opset17_extended.onnx    x:1x3x224x224
# 1  vit_base_patch8_224_in21k_Opset17_disable_all....    x:1x3x224x224
# 2    tf_efficientnetv2_m_in21ft1k_Opset17_basic.onnx    x:1x3x384x384
# 3                    shufflenet_v2_x1_5_Opset16.onnx    x:1x3x224x224
# 4                 wide_resnet101_2_Opset16_timm.onnx    x:1x3x224x224
#
#   input_dtypes output_dimensions output_dtypes   conv_flops  matmul_flops  \
# 0    x:float32        668:1x1000   668:float32    472440512       2560000
# 1    x:float32      1089:1x21843  1089:float32    231211008  156097479168
# 2    x:float32       2466:1x1000  2466:float32  31470991360       2560000
# 3    x:float32       1137:1x1000  1137:float32    266034528       2048000
# 4    x:float32        971:1x1000   971:float32  45502005248       4096000
#
#    elementwise_mb  reduction_mb  normalization_mb  ...  base_clock_mhz  \
# 0       50.528229      5.204269          0.000000  ...        2300.000
# 1     1771.169711      0.000000        792.141724  ...        2450.000
# 2     1201.339462     67.736023          0.000000  ...        2449.998
# 3        8.246674      1.630875          0.000000  ...        2449.998
# 4      252.656250      4.218750          0.000000  ...        2300.000
#
#    memory_bandwith_gbs  cpu_provider  machine_type  platform  \
# 0                  717         intel     xeon_plat  bluehive
# 1                  205           amd          epyc    gcloud
# 2                  205           amd          epyc    gcloud
# 3                  205           amd          epyc    gcloud
# 4                  717         intel     xeon_plat  bluehive
#
#                                    repo_file   average_ms   stddev_ms  \
# 0                 hardcorenas_d_Opset17.onnx    14.069188    0.082284
# 1     vit_base_patch8_224_in21k_Opset17.onnx  1481.456045  150.199862
# 2  tf_efficientnetv2_m_in21ft1k_Opset17.onnx   301.127424   12.889699
# 3            shufflenet_v2_x1_5_Opset16.onnx     8.161246    0.036559
# 4         wide_resnet101_2_Opset16_timm.onnx    38.147223    0.068437
#
#         min_ms       max_ms
# 0    13.931521    14.247209
# 1  1094.324125  1632.506909
# 2   286.464729   324.336829
# 3     8.080030     8.197800
# 4    38.035275    38.292409
#
# [5 rows x 154 columns]

# %%
# pre-processing function

def preprocess(df: pd.DataFrame, train=False) -> pd.DataFrame:

  #drop rows with missing features
  df = df.dropna(subset=["average_ms"])

  #remove rows with high standard deviation (only for train)
  cv_limit = 0.1 # 10% cv limit
  df["cv"] = df["stddev_ms"] / df["average_ms"]

  if train:
    df = df[df["cv"] <= cv_limit].copy()

  #add log_average_ms column
  df["log_average_ms"] = np.log(df["average_ms"])

  #remove decimals and round down
  for col in ["elementwise_mb", "reduction_mb", "normalization_mb", "movement_mb"]:
    df[col] = df[col].round(0)

  return df

# %%
train_df = preprocess(train_df, True)
test_df = preprocess(test_df, False)
val_df = preprocess(val_df, False)

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (95814, 156)
# val: (21483, 156)
# test: (21483, 156)

# %% [markdown]
# # Model Training

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X_train = train_df[feature_cols]
y_train = train_df[target_col]

X_val = val_df[feature_cols]
y_val = val_df[target_col]

X_test = test_df[feature_cols]
y_test = test_df[target_col]

# %%
def rmse_log(y_true, y_pred):
  return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def train_xgb(params, X_train, y_train, X_val, y_val):
  model = XGBRegressor(
      objective="reg:squarederror",
      tree_method="hist",
      eval_metric="rmse",
      random_state=67,
      n_jobs=-1,
      early_stopping_rounds=100,
      **params,
  )

  model.fit(
      X_train,
      y_train,
      eval_set=[(X_val, y_val)],
      verbose=100,
  )

  val_pred = model.predict(X_val)
  score = rmse_log(y_val, val_pred)

  return model, score

# %%
from sklearn.model_selection import ParameterSampler

param_dist = {
    "n_estimators": [800, 1200, 1600, 2000, 3000],
    "learning_rate": [0.01, 0.02, 0.03, 0.05, 0.08],
    "max_depth": [3, 4, 5, 6, 7],
    "min_child_weight": [1, 3, 5, 10, 20],
    "subsample": [0.7, 0.8, 0.9, 1.0],
    "colsample_bytree": [0.7, 0.8, 0.9, 1.0],
    "reg_lambda": [1.0, 3.0, 5.0, 10.0, 20.0],
    "reg_alpha": [0.0, 0.01, 0.1, 1.0],
}

# %%
sampled_params = list(ParameterSampler(
    param_dist,
    n_iter=40,
    random_state=42,
))

results = []

best_model = None
best_score = float("inf")
best_params = None

for i, params in enumerate(sampled_params, start=1):
  model, val_rmse = train_xgb(params, X_train, y_train, X_val, y_val)

  row = {
        "run": i,
        "val_rmse_log": val_rmse,
        **params,
    }

  results.append(row)

  if val_rmse < best_score:
    best_score = val_rmse
    best_model = model
    best_params = params

  print(f"{i:02d} | val RMSE log = {val_rmse:.5f} | best = {best_score:.5f}")


tuning_results = pd.DataFrame(results).sort_values("val_rmse_log")
tuning_results.head(10)
# Out:
# [0]	validation_0-rmse:1.45462
# [100]	validation_0-rmse:0.82212
# [200]	validation_0-rmse:0.69883
# [300]	validation_0-rmse:0.63321
# [400]	validation_0-rmse:0.59940
# [500]	validation_0-rmse:0.57632
# [600]	validation_0-rmse:0.55469
# [700]	validation_0-rmse:0.53553
# [800]	validation_0-rmse:0.52211
# [900]	validation_0-rmse:0.51091
# [1000]	validation_0-rmse:0.49863
# [1100]	validation_0-rmse:0.48801
# [1200]	validation_0-rmse:0.47726
# [1300]	validation_0-rmse:0.46931
# [1400]	validation_0-rmse:0.46206
# [1500]	validation_0-rmse:0.45428
# [1600]	validation_0-rmse:0.44553
# [1700]	validation_0-rmse:0.43940
# [1800]	validation_0-rmse:0.43355
# [1900]	validation_0-rmse:0.42801
# [2000]	validation_0-rmse:0.42306
# [2100]	validation_0-rmse:0.41884
# [2200]	validation_0-rmse:0.41469
# [2300]	validation_0-rmse:0.41119
# [2400]	validation_0-rmse:0.40729
# [2500]	validation_0-rmse:0.40412
# [2600]	validation_0-rmse:0.40114
# [2700]	validation_0-rmse:0.39824
# [2800]	validation_0-rmse:0.39523
# [2900]	validation_0-rmse:0.39259
# [2999]	validation_0-rmse:0.39026
# 01 | val RMSE log = 0.39026 | best = 0.39026
# [0]	validation_0-rmse:1.39072
# [100]	validation_0-rmse:0.43019
# [200]	validation_0-rmse:0.35118
# [300]	validation_0-rmse:0.32255
# [400]	validation_0-rmse:0.30957
# [500]	validation_0-rmse:0.30283
# [600]	validation_0-rmse:0.29853
# [700]	validation_0-rmse:0.29587
# [799]	validation_0-rmse:0.29405
# 02 | val RMSE log = 0.29405 | best = 0.29405
# [0]	validation_0-rmse:1.43975
# [100]	validation_0-rmse:0.73432
# [200]	validation_0-rmse:0.62061
# [300]	validation_0-rmse:0.56628
# [400]	validation_0-rmse:0.53336
# [500]	validation_0-rmse:0.50663
# [600]	validation_0-rmse:0.48787
# [700]	validation_0-rmse:0.47155
# [800]	validation_0-rmse:0.45829
# [900]	validation_0-rmse:0.44610
# [1000]	validation_0-rmse:0.43512
# [1100]	validation_0-rmse:0.42588
# [1200]	validation_0-rmse:0.41780
# [1300]	validation_0-rmse:0.40984
# [1400]	validation_0-rmse:0.40363
# [1500]	validation_0-rmse:0.39807
# [1600]	validation_0-rmse:0.39234
# [1700]	validation_0-rmse:0.38757
# [1800]	validation_0-rmse:0.38260
# [1900]	validation_0-rmse:0.37865
# [2000]	validation_0-rmse:0.37518
# [2100]	validation_0-rmse:0.37162
# [2200]	validation_0-rmse:0.36855
# [2300]	validation_0-rmse:0.36546
# [2400]	validation_0-rmse:0.36272
# [2500]	validation_0-rmse:0.36020
# [2600]	validation_0-rmse:0.35764
# [2700]	validation_0-rmse:0.35526
# [2800]	validation_0-rmse:0.35333
# [2900]	validation_0-rmse:0.35133
# [2999]	validation_0-rmse:0.34944
# 03 | val RMSE log = 0.34944 | best = 0.29405
# [0]	validation_0-rmse:1.46859
# [100]	validation_0-rmse:0.97229
# [200]	validation_0-rmse:0.80701
# [300]	validation_0-rmse:0.73273
# [400]	validation_0-rmse:0.68300
# [500]	validation_0-rmse:0.63836
# [600]	validation_0-rmse:0.60615
# [700]	validation_0-rmse:0.58398
# [800]	validation_0-rmse:0.56418
# [900]	validation_0-rmse:0.54783
# [1000]	validation_0-rmse:0.53293
# [1100]	validation_0-rmse:0.52229
# [1199]	validation_0-rmse:0.51096
# 04 | val RMSE log = 0.51096 | best = 0.29405
# [0]	validation_0-rmse:1.45435
# [100]	validation_0-rmse:0.59932
# [200]	validation_0-rmse:0.47596
# [300]	validation_0-rmse:0.42847
# [400]	validation_0-rmse:0.39831
# [500]	validation_0-rmse:0.37314
# [600]	validation_0-rmse:0.35582
# [700]	validation_0-rmse:0.34185
# [800]	validation_0-rmse:0.33292
# [900]	validation_0-rmse:0.32481
# [1000]	validation_0-rmse:0.31745
# [1100]	validation_0-rmse:0.31278
# [1200]	validation_0-rmse:0.30867
# [1300]	validation_0-rmse:0.30626
# [1400]	validation_0-rmse:0.30400
# [1500]	validation_0-rmse:0.30194
# [1600]	validation_0-rmse:0.29951
# [1700]	validation_0-rmse:0.29830
# [1800]	validation_0-rmse:0.29731
# [1900]	validation_0-rmse:0.29624
# [1999]	validation_0-rmse:0.29531
# 05 | val RMSE log = 0.29531 | best = 0.29405
# [0]	validation_0-rmse:1.46200
# [100]	validation_0-rmse:0.87819
# [200]	validation_0-rmse:0.77559
# [300]	validation_0-rmse:0.70101
# [400]	validation_0-rmse:0.65058
# [500]	validation_0-rmse:0.62231
# [600]	validation_0-rmse:0.59950
# [700]	validation_0-rmse:0.58149
# [800]	validation_0-rmse:0.56405
# [900]	validation_0-rmse:0.54971
# [1000]	validation_0-rmse:0.53835
# [1100]	validation_0-rmse:0.52747
# [1200]	validation_0-rmse:0.51820
# [1300]	validation_0-rmse:0.50903
# [1400]	validation_0-rmse:0.50108
# [1500]	validation_0-rmse:0.49287
# [1600]	validation_0-rmse:0.48570
# [1700]	validation_0-rmse:0.47981
# [1800]	validation_0-rmse:0.47206
# [1900]	validation_0-rmse:0.46644
# [1999]	validation_0-rmse:0.46018
# 06 | val RMSE log = 0.46018 | best = 0.29405
# [0]	validation_0-rmse:1.46738
# [100]	validation_0-rmse:0.91330
# [200]	validation_0-rmse:0.74004
# [300]	validation_0-rmse:0.65554
# [400]	validation_0-rmse:0.60203
# [500]	validation_0-rmse:0.56241
# [600]	validation_0-rmse:0.53155
# [700]	validation_0-rmse:0.50611
# [800]	validation_0-rmse:0.48717
# [900]	validation_0-rmse:0.47353
# [1000]	validation_0-rmse:0.45992
# [1100]	validation_0-rmse:0.44883
# [1199]	validation_0-rmse:0.43700
# 07 | val RMSE log = 0.43700 | best = 0.29405
# [0]	validation_0-rmse:1.42416
# [100]	validation_0-rmse:0.50344
# [200]	validation_0-rmse:0.41360
# [300]	validation_0-rmse:0.36584
# [400]	validation_0-rmse:0.34011
# [500]	validation_0-rmse:0.32365
# [600]	validation_0-rmse:0.31426
# [700]	validation_0-rmse:0.30742
# [800]	validation_0-rmse:0.30317
# [900]	validation_0-rmse:0.29998
# [1000]	validation_0-rmse:0.29770
# [1100]	validation_0-rmse:0.29604
# [1199]	validation_0-rmse:0.29464
# 08 | val RMSE log = 0.29462 | best = 0.29405
# [0]	validation_0-rmse:1.45362
# [100]	validation_0-rmse:0.58792
# [200]	validation_0-rmse:0.45938
# [300]	validation_0-rmse:0.40583
# [400]	validation_0-rmse:0.37180
# [500]	validation_0-rmse:0.35024
# [600]	validation_0-rmse:0.33395
# [700]	validation_0-rmse:0.32270
# [800]	validation_0-rmse:0.31536
# [900]	validation_0-rmse:0.30916
# [1000]	validation_0-rmse:0.30502
# [1100]	validation_0-rmse:0.30160
# [1200]	validation_0-rmse:0.29878
# [1300]	validation_0-rmse:0.29691
# [1400]	validation_0-rmse:0.29549
# [1500]	validation_0-rmse:0.29420
# [1600]	validation_0-rmse:0.29320
# [1700]	validation_0-rmse:0.29247
# [1800]	validation_0-rmse:0.29192
# [1900]	validation_0-rmse:0.29155
# [1999]	validation_0-rmse:0.29116
# 09 | val RMSE log = 0.29116 | best = 0.29116
# [0]	validation_0-rmse:1.42406
# [100]	validation_0-rmse:0.50802
# [200]	validation_0-rmse:0.41496
# [300]	validation_0-rmse:0.36865
# [400]	validation_0-rmse:0.34348
# [500]	validation_0-rmse:0.32654
# [600]	validation_0-rmse:0.31675
# [700]	validation_0-rmse:0.30979
# [800]	validation_0-rmse:0.30533
# [900]	validation_0-rmse:0.30152
# [1000]	validation_0-rmse:0.29884
# [1100]	validation_0-rmse:0.29679
# [1200]	validation_0-rmse:0.29491
# [1300]	validation_0-rmse:0.29361
# [1400]	validation_0-rmse:0.29266
# [1500]	validation_0-rmse:0.29183
# [1600]	validation_0-rmse:0.29133
# [1700]	validation_0-rmse:0.29089
# [1800]	validation_0-rmse:0.29050
# [1900]	validation_0-rmse:0.29017
# [1999]	validation_0-rmse:0.28993
# 10 | val RMSE log = 0.28993 | best = 0.28993
# [0]	validation_0-rmse:1.46012
# [100]	validation_0-rmse:0.80172
# [200]	validation_0-rmse:0.68090
# [300]	validation_0-rmse:0.60792
# [400]	validation_0-rmse:0.56596
# [500]	validation_0-rmse:0.53389
# [600]	validation_0-rmse:0.51152
# [700]	validation_0-rmse:0.49151
# [800]	validation_0-rmse:0.47459
# [900]	validation_0-rmse:0.46023
# [1000]	validation_0-rmse:0.44863
# [1100]	validation_0-rmse:0.43596
# [1200]	validation_0-rmse:0.42750
# [1300]	validation_0-rmse:0.41988
# [1400]	validation_0-rmse:0.41063
# [1500]	validation_0-rmse:0.40280
# [1600]	validation_0-rmse:0.39690
# [1700]	validation_0-rmse:0.39149
# [1800]	validation_0-rmse:0.38726
# [1900]	validation_0-rmse:0.38238
# [2000]	validation_0-rmse:0.37674
# [2100]	validation_0-rmse:0.37154
# [2200]	validation_0-rmse:0.36805
# [2300]	validation_0-rmse:0.36474
# [2400]	validation_0-rmse:0.36121
# [2500]	validation_0-rmse:0.35824
# [2600]	validation_0-rmse:0.35607
# [2700]	validation_0-rmse:0.35382
# [2800]	validation_0-rmse:0.35133
# [2900]	validation_0-rmse:0.34850
# [2999]	validation_0-rmse:0.34709
# 11 | val RMSE log = 0.34709 | best = 0.28993
# [0]	validation_0-rmse:1.44451
# [100]	validation_0-rmse:0.57298
# [200]	validation_0-rmse:0.46527
# [300]	validation_0-rmse:0.40924
# [400]	validation_0-rmse:0.37372
# [500]	validation_0-rmse:0.35097
# [600]	validation_0-rmse:0.33668
# [700]	validation_0-rmse:0.32568
# [800]	validation_0-rmse:0.31748
# [900]	validation_0-rmse:0.31146
# [1000]	validation_0-rmse:0.30699
# [1100]	validation_0-rmse:0.30362
# [1200]	validation_0-rmse:0.30101
# [1300]	validation_0-rmse:0.29900
# [1400]	validation_0-rmse:0.29741
# [1500]	validation_0-rmse:0.29620
# [1600]	validation_0-rmse:0.29522
# [1700]	validation_0-rmse:0.29437
# [1800]	validation_0-rmse:0.29370
# [1900]	validation_0-rmse:0.29327
# [2000]	validation_0-rmse:0.29284
# [2100]	validation_0-rmse:0.29262
# [2200]	validation_0-rmse:0.29242
# [2300]	validation_0-rmse:0.29223
# [2400]	validation_0-rmse:0.29201
# [2500]	validation_0-rmse:0.29191
# [2600]	validation_0-rmse:0.29179
# [2700]	validation_0-rmse:0.29176
# [2800]	validation_0-rmse:0.29155
# [2900]	validation_0-rmse:0.29160
# [2928]	validation_0-rmse:0.29158
# 12 | val RMSE log = 0.29149 | best = 0.28993
# [0]	validation_0-rmse:1.44811
# [100]	validation_0-rmse:0.65164
# [200]	validation_0-rmse:0.53194
# [300]	validation_0-rmse:0.47100
# [400]	validation_0-rmse:0.43044
# [500]	validation_0-rmse:0.40328
# [600]	validation_0-rmse:0.38309
# [700]	validation_0-rmse:0.36900
# [799]	validation_0-rmse:0.35556
# 13 | val RMSE log = 0.35556 | best = 0.28993
# [0]	validation_0-rmse:1.41789
# [100]	validation_0-rmse:0.65200
# [200]	validation_0-rmse:0.56179
# [300]	validation_0-rmse:0.51510
# [400]	validation_0-rmse:0.48227
# [500]	validation_0-rmse:0.45953
# [600]	validation_0-rmse:0.43854
# [700]	validation_0-rmse:0.42436
# [800]	validation_0-rmse:0.41145
# [900]	validation_0-rmse:0.40025
# [1000]	validation_0-rmse:0.39392
# [1100]	validation_0-rmse:0.38827
# [1199]	validation_0-rmse:0.38240
# 14 | val RMSE log = 0.38240 | best = 0.28993
# [0]	validation_0-rmse:1.45679
# [100]	validation_0-rmse:0.66561
# [200]	validation_0-rmse:0.53554
# [300]	validation_0-rmse:0.46716
# [400]	validation_0-rmse:0.42769
# [500]	validation_0-rmse:0.39973
# [600]	validation_0-rmse:0.37830
# [700]	validation_0-rmse:0.36038
# [799]	validation_0-rmse:0.34964
# 15 | val RMSE log = 0.34964 | best = 0.28993
# [0]	validation_0-rmse:1.41786
# [100]	validation_0-rmse:0.65262
# [200]	validation_0-rmse:0.56424
# [300]	validation_0-rmse:0.51672
# [400]	validation_0-rmse:0.48542
# [500]	validation_0-rmse:0.46285
# [600]	validation_0-rmse:0.44721
# [700]	validation_0-rmse:0.43180
# [800]	validation_0-rmse:0.42062
# [900]	validation_0-rmse:0.40878
# [1000]	validation_0-rmse:0.39852
# [1100]	validation_0-rmse:0.39007
# [1200]	validation_0-rmse:0.38357
# [1300]	validation_0-rmse:0.37727
# [1400]	validation_0-rmse:0.37262
# [1500]	validation_0-rmse:0.36783
# [1600]	validation_0-rmse:0.36295
# [1700]	validation_0-rmse:0.35895
# [1800]	validation_0-rmse:0.35512
# [1900]	validation_0-rmse:0.35191
# [1999]	validation_0-rmse:0.34912
# 16 | val RMSE log = 0.34912 | best = 0.28993
# [0]	validation_0-rmse:1.45522
# [100]	validation_0-rmse:0.65913
# [200]	validation_0-rmse:0.53140
# [300]	validation_0-rmse:0.46370
# [400]	validation_0-rmse:0.42373
# [500]	validation_0-rmse:0.39554
# [600]	validation_0-rmse:0.37422
# [700]	validation_0-rmse:0.35848
# [799]	validation_0-rmse:0.34715
# 17 | val RMSE log = 0.34715 | best = 0.28993
# [0]	validation_0-rmse:1.45772
# [100]	validation_0-rmse:0.73370
# [200]	validation_0-rmse:0.60039
# [300]	validation_0-rmse:0.52801
# [400]	validation_0-rmse:0.48794
# [500]	validation_0-rmse:0.45642
# [600]	validation_0-rmse:0.43364
# [700]	validation_0-rmse:0.41080
# [799]	validation_0-rmse:0.39493
# 18 | val RMSE log = 0.39493 | best = 0.28993
# [0]	validation_0-rmse:1.46952
# [100]	validation_0-rmse:1.04366
# [200]	validation_0-rmse:0.88590
# [300]	validation_0-rmse:0.82287
# [400]	validation_0-rmse:0.78009
# [500]	validation_0-rmse:0.73947
# [600]	validation_0-rmse:0.70578
# [700]	validation_0-rmse:0.67770
# [800]	validation_0-rmse:0.65399
# [900]	validation_0-rmse:0.63551
# [1000]	validation_0-rmse:0.62098
# [1100]	validation_0-rmse:0.60939
# [1200]	validation_0-rmse:0.59831
# [1300]	validation_0-rmse:0.58772
# [1400]	validation_0-rmse:0.57903
# [1500]	validation_0-rmse:0.57151
# [1600]	validation_0-rmse:0.56364
# [1700]	validation_0-rmse:0.55655
# [1800]	validation_0-rmse:0.55045
# [1900]	validation_0-rmse:0.54434
# [2000]	validation_0-rmse:0.53902
# [2100]	validation_0-rmse:0.53393
# [2200]	validation_0-rmse:0.52940
# [2300]	validation_0-rmse:0.52489
# [2400]	validation_0-rmse:0.52037
# [2500]	validation_0-rmse:0.51657
# [2600]	validation_0-rmse:0.51253
# [2700]	validation_0-rmse:0.50846
# [2800]	validation_0-rmse:0.50512
# [2900]	validation_0-rmse:0.50145
# [2999]	validation_0-rmse:0.49815
# 19 | val RMSE log = 0.49815 | best = 0.28993
# [0]	validation_0-rmse:1.46551
# [100]	validation_0-rmse:0.80926
# [200]	validation_0-rmse:0.59863
# [300]	validation_0-rmse:0.51966
# [400]	validation_0-rmse:0.47330
# [500]	validation_0-rmse:0.44382
# [600]	validation_0-rmse:0.41984
# [700]	validation_0-rmse:0.40005
# [800]	validation_0-rmse:0.38485
# [900]	validation_0-rmse:0.37406
# [1000]	validation_0-rmse:0.36451
# [1100]	validation_0-rmse:0.35496
# [1199]	validation_0-rmse:0.34722
# 20 | val RMSE log = 0.34722 | best = 0.28993
# [0]	validation_0-rmse:1.40070
# [100]	validation_0-rmse:0.48370
# [200]	validation_0-rmse:0.39571
# [300]	validation_0-rmse:0.35598
# [400]	validation_0-rmse:0.33736
# [500]	validation_0-rmse:0.32428
# [600]	validation_0-rmse:0.31547
# [700]	validation_0-rmse:0.30874
# [799]	validation_0-rmse:0.30438
# 21 | val RMSE log = 0.30438 | best = 0.28993
# [0]	validation_0-rmse:1.45775
# [100]	validation_0-rmse:0.74042
# [200]	validation_0-rmse:0.60239
# [300]	validation_0-rmse:0.53348
# [400]	validation_0-rmse:0.49235
# [500]	validation_0-rmse:0.45878
# [600]	validation_0-rmse:0.43606
# [700]	validation_0-rmse:0.41403
# [800]	validation_0-rmse:0.39850
# [900]	validation_0-rmse:0.38530
# [1000]	validation_0-rmse:0.37402
# [1100]	validation_0-rmse:0.36567
# [1199]	validation_0-rmse:0.35745
# 22 | val RMSE log = 0.35745 | best = 0.28993
# [0]	validation_0-rmse:1.38354
# [100]	validation_0-rmse:0.36423
# [200]	validation_0-rmse:0.31490
# [300]	validation_0-rmse:0.29953
# [400]	validation_0-rmse:0.29466
# [500]	validation_0-rmse:0.29321
# [600]	validation_0-rmse:0.29296
# [700]	validation_0-rmse:0.29283
# [779]	validation_0-rmse:0.29301
# 23 | val RMSE log = 0.29269 | best = 0.28993
# [0]	validation_0-rmse:1.46778
# [100]	validation_0-rmse:0.91823
# [200]	validation_0-rmse:0.74565
# [300]	validation_0-rmse:0.65780
# [400]	validation_0-rmse:0.60969
# [500]	validation_0-rmse:0.56888
# [600]	validation_0-rmse:0.53422
# [700]	validation_0-rmse:0.50979
# [800]	validation_0-rmse:0.49071
# [900]	validation_0-rmse:0.47667
# [1000]	validation_0-rmse:0.46404
# [1100]	validation_0-rmse:0.44883
# [1199]	validation_0-rmse:0.43631
# 24 | val RMSE log = 0.43631 | best = 0.28993
# [0]	validation_0-rmse:1.46859
# [100]	validation_0-rmse:0.97187
# [200]	validation_0-rmse:0.80774
# [300]	validation_0-rmse:0.73452
# [400]	validation_0-rmse:0.68785
# [500]	validation_0-rmse:0.64352
# [600]	validation_0-rmse:0.61375
# [700]	validation_0-rmse:0.59020
# [800]	validation_0-rmse:0.56954
# [900]	validation_0-rmse:0.55221
# [1000]	validation_0-rmse:0.53855
# [1100]	validation_0-rmse:0.52549
# [1199]	validation_0-rmse:0.51529
# 25 | val RMSE log = 0.51529 | best = 0.28993
# [0]	validation_0-rmse:1.42965
# [100]	validation_0-rmse:0.56651
# [200]	validation_0-rmse:0.46462
# [300]	validation_0-rmse:0.41378
# [400]	validation_0-rmse:0.37725
# [500]	validation_0-rmse:0.35817
# [600]	validation_0-rmse:0.34529
# [700]	validation_0-rmse:0.33465
# [800]	validation_0-rmse:0.32653
# [900]	validation_0-rmse:0.32073
# [1000]	validation_0-rmse:0.31633
# [1100]	validation_0-rmse:0.31216
# [1200]	validation_0-rmse:0.30936
# [1300]	validation_0-rmse:0.30657
# [1400]	validation_0-rmse:0.30417
# [1500]	validation_0-rmse:0.30237
# [1600]	validation_0-rmse:0.30113
# [1700]	validation_0-rmse:0.29957
# [1800]	validation_0-rmse:0.29833
# [1900]	validation_0-rmse:0.29738
# [2000]	validation_0-rmse:0.29651
# [2100]	validation_0-rmse:0.29607
# [2200]	validation_0-rmse:0.29524
# [2300]	validation_0-rmse:0.29462
# [2400]	validation_0-rmse:0.29417
# [2500]	validation_0-rmse:0.29366
# [2600]	validation_0-rmse:0.29312
# [2700]	validation_0-rmse:0.29265
# [2800]	validation_0-rmse:0.29237
# [2900]	validation_0-rmse:0.29200
# [2999]	validation_0-rmse:0.29168
# 26 | val RMSE log = 0.29168 | best = 0.28993
# [0]	validation_0-rmse:1.42905
# [100]	validation_0-rmse:0.55414
# [200]	validation_0-rmse:0.45723
# [300]	validation_0-rmse:0.40559
# [400]	validation_0-rmse:0.37461
# [500]	validation_0-rmse:0.35291
# [600]	validation_0-rmse:0.33825
# [700]	validation_0-rmse:0.32900
# [800]	validation_0-rmse:0.32167
# [900]	validation_0-rmse:0.31582
# [1000]	validation_0-rmse:0.31143
# [1100]	validation_0-rmse:0.30786
# [1199]	validation_0-rmse:0.30483
# 27 | val RMSE log = 0.30483 | best = 0.28993
# [0]	validation_0-rmse:1.46535
# [100]	validation_0-rmse:0.79509
# [200]	validation_0-rmse:0.59109
# [300]	validation_0-rmse:0.51257
# [400]	validation_0-rmse:0.46399
# [500]	validation_0-rmse:0.43342
# [600]	validation_0-rmse:0.40873
# [700]	validation_0-rmse:0.39090
# [800]	validation_0-rmse:0.37532
# [900]	validation_0-rmse:0.36227
# [1000]	validation_0-rmse:0.35244
# [1100]	validation_0-rmse:0.34409
# [1200]	validation_0-rmse:0.33651
# [1300]	validation_0-rmse:0.32988
# [1400]	validation_0-rmse:0.32504
# [1500]	validation_0-rmse:0.32068
# [1599]	validation_0-rmse:0.31666
# 28 | val RMSE log = 0.31666 | best = 0.28993
# [0]	validation_0-rmse:1.43970
# [100]	validation_0-rmse:0.73160
# [200]	validation_0-rmse:0.62012
# [300]	validation_0-rmse:0.56186
# [400]	validation_0-rmse:0.53250
# [500]	validation_0-rmse:0.50512
# [600]	validation_0-rmse:0.48427
# [700]	validation_0-rmse:0.46813
# [800]	validation_0-rmse:0.45436
# [900]	validation_0-rmse:0.44126
# [1000]	validation_0-rmse:0.43012
# [1100]	validation_0-rmse:0.42095
# [1200]	validation_0-rmse:0.41337
# [1300]	validation_0-rmse:0.40596
# [1400]	validation_0-rmse:0.40060
# [1500]	validation_0-rmse:0.39444
# [1599]	validation_0-rmse:0.38912
# 29 | val RMSE log = 0.38912 | best = 0.28993
# [0]	validation_0-rmse:1.46617
# [100]	validation_0-rmse:0.85543
# [200]	validation_0-rmse:0.66520
# [300]	validation_0-rmse:0.57665
# [400]	validation_0-rmse:0.53008
# [500]	validation_0-rmse:0.49693
# [600]	validation_0-rmse:0.46804
# [700]	validation_0-rmse:0.44660
# [800]	validation_0-rmse:0.42907
# [900]	validation_0-rmse:0.41345
# [1000]	validation_0-rmse:0.40045
# [1100]	validation_0-rmse:0.38844
# [1200]	validation_0-rmse:0.37839
# [1300]	validation_0-rmse:0.36944
# [1400]	validation_0-rmse:0.36189
# [1500]	validation_0-rmse:0.35524
# [1600]	validation_0-rmse:0.34884
# [1700]	validation_0-rmse:0.34371
# [1800]	validation_0-rmse:0.33958
# [1900]	validation_0-rmse:0.33531
# [2000]	validation_0-rmse:0.33167
# [2100]	validation_0-rmse:0.32832
# [2200]	validation_0-rmse:0.32553
# [2300]	validation_0-rmse:0.32264
# [2400]	validation_0-rmse:0.32004
# [2500]	validation_0-rmse:0.31769
# [2600]	validation_0-rmse:0.31562
# [2700]	validation_0-rmse:0.31372
# [2800]	validation_0-rmse:0.31194
# [2900]	validation_0-rmse:0.31026
# [2999]	validation_0-rmse:0.30869
# 30 | val RMSE log = 0.30869 | best = 0.28993
# [0]	validation_0-rmse:1.42969
# [100]	validation_0-rmse:0.56864
# [200]	validation_0-rmse:0.46925
# [300]	validation_0-rmse:0.41975
# [400]	validation_0-rmse:0.38702
# [500]	validation_0-rmse:0.36318
# [600]	validation_0-rmse:0.34922
# [700]	validation_0-rmse:0.33802
# [799]	validation_0-rmse:0.33002
# 31 | val RMSE log = 0.33002 | best = 0.28993
# [0]	validation_0-rmse:1.45189
# [100]	validation_0-rmse:0.74011
# [200]	validation_0-rmse:0.61285
# [300]	validation_0-rmse:0.54968
# [400]	validation_0-rmse:0.51397
# [500]	validation_0-rmse:0.48502
# [600]	validation_0-rmse:0.45937
# [700]	validation_0-rmse:0.44156
# [800]	validation_0-rmse:0.42678
# [900]	validation_0-rmse:0.41293
# [1000]	validation_0-rmse:0.40213
# [1100]	validation_0-rmse:0.39281
# [1199]	validation_0-rmse:0.38380
# 32 | val RMSE log = 0.38380 | best = 0.28993
# [0]	validation_0-rmse:1.38362
# [100]	validation_0-rmse:0.37875
# [200]	validation_0-rmse:0.32042
# [300]	validation_0-rmse:0.30158
# [400]	validation_0-rmse:0.29546
# [500]	validation_0-rmse:0.29257
# [600]	validation_0-rmse:0.29101
# [700]	validation_0-rmse:0.29005
# [800]	validation_0-rmse:0.28952
# [900]	validation_0-rmse:0.28906
# [1000]	validation_0-rmse:0.28891
# [1100]	validation_0-rmse:0.28880
# [1200]	validation_0-rmse:0.28878
# [1300]	validation_0-rmse:0.28873
# [1400]	validation_0-rmse:0.28885
# [1430]	validation_0-rmse:0.28889
# 33 | val RMSE log = 0.28872 | best = 0.28872
# [0]	validation_0-rmse:1.43973
# [100]	validation_0-rmse:0.74042
# [200]	validation_0-rmse:0.62527
# [300]	validation_0-rmse:0.58064
# [400]	validation_0-rmse:0.54573
# [500]	validation_0-rmse:0.51669
# [600]	validation_0-rmse:0.49728
# [700]	validation_0-rmse:0.47962
# [800]	validation_0-rmse:0.46694
# [900]	validation_0-rmse:0.45422
# [1000]	validation_0-rmse:0.44366
# [1100]	validation_0-rmse:0.43373
# [1199]	validation_0-rmse:0.42098
# 34 | val RMSE log = 0.42098 | best = 0.28872
# [0]	validation_0-rmse:1.46860
# [100]	validation_0-rmse:0.97667
# [200]	validation_0-rmse:0.80739
# [300]	validation_0-rmse:0.73875
# [400]	validation_0-rmse:0.68913
# [500]	validation_0-rmse:0.64125
# [600]	validation_0-rmse:0.61119
# [700]	validation_0-rmse:0.58443
# [800]	validation_0-rmse:0.56304
# [900]	validation_0-rmse:0.54543
# [1000]	validation_0-rmse:0.53098
# [1100]	validation_0-rmse:0.52142
# [1200]	validation_0-rmse:0.50985
# [1300]	validation_0-rmse:0.49928
# [1400]	validation_0-rmse:0.49114
# [1500]	validation_0-rmse:0.48461
# [1600]	validation_0-rmse:0.47715
# [1700]	validation_0-rmse:0.47054
# [1800]	validation_0-rmse:0.46407
# [1900]	validation_0-rmse:0.45765
# [2000]	validation_0-rmse:0.45192
# [2100]	validation_0-rmse:0.44497
# [2200]	validation_0-rmse:0.44105
# [2300]	validation_0-rmse:0.43593
# [2400]	validation_0-rmse:0.43105
# [2500]	validation_0-rmse:0.42479
# [2600]	validation_0-rmse:0.42034
# [2700]	validation_0-rmse:0.41703
# [2800]	validation_0-rmse:0.41321
# [2900]	validation_0-rmse:0.41015
# [2999]	validation_0-rmse:0.40700
# 35 | val RMSE log = 0.40700 | best = 0.28872
# [0]	validation_0-rmse:1.45177
# [100]	validation_0-rmse:0.73344
# [200]	validation_0-rmse:0.60948
# [300]	validation_0-rmse:0.54871
# [400]	validation_0-rmse:0.51598
# [500]	validation_0-rmse:0.48776
# [600]	validation_0-rmse:0.46499
# [700]	validation_0-rmse:0.44497
# [800]	validation_0-rmse:0.42827
# [900]	validation_0-rmse:0.41511
# [1000]	validation_0-rmse:0.40500
# [1100]	validation_0-rmse:0.39688
# [1200]	validation_0-rmse:0.38948
# [1300]	validation_0-rmse:0.38184
# [1400]	validation_0-rmse:0.37376
# [1500]	validation_0-rmse:0.36743
# [1600]	validation_0-rmse:0.36139
# [1700]	validation_0-rmse:0.35712
# [1800]	validation_0-rmse:0.35472
# [1900]	validation_0-rmse:0.35092
# [1999]	validation_0-rmse:0.34702
# 36 | val RMSE log = 0.34702 | best = 0.28872
# [0]	validation_0-rmse:1.41782
# [100]	validation_0-rmse:0.64727
# [200]	validation_0-rmse:0.55912
# [300]	validation_0-rmse:0.51064
# [400]	validation_0-rmse:0.47987
# [500]	validation_0-rmse:0.45346
# [600]	validation_0-rmse:0.43677
# [700]	validation_0-rmse:0.42330
# [800]	validation_0-rmse:0.41146
# [900]	validation_0-rmse:0.40192
# [1000]	validation_0-rmse:0.39102
# [1100]	validation_0-rmse:0.38357
# [1200]	validation_0-rmse:0.37676
# [1300]	validation_0-rmse:0.37058
# [1400]	validation_0-rmse:0.36559
# [1500]	validation_0-rmse:0.36115
# [1599]	validation_0-rmse:0.35712
# 37 | val RMSE log = 0.35712 | best = 0.28872
# [0]	validation_0-rmse:1.45775
# [100]	validation_0-rmse:0.74136
# [200]	validation_0-rmse:0.60605
# [300]	validation_0-rmse:0.53443
# [400]	validation_0-rmse:0.49354
# [500]	validation_0-rmse:0.46060
# [600]	validation_0-rmse:0.43760
# [700]	validation_0-rmse:0.41708
# [800]	validation_0-rmse:0.40140
# [900]	validation_0-rmse:0.38770
# [1000]	validation_0-rmse:0.37753
# [1100]	validation_0-rmse:0.36800
# [1199]	validation_0-rmse:0.35954
# 38 | val RMSE log = 0.35954 | best = 0.28872
# [0]	validation_0-rmse:1.44187
# [100]	validation_0-rmse:0.50757
# [200]	validation_0-rmse:0.40754
# [300]	validation_0-rmse:0.36210
# [400]	validation_0-rmse:0.33912
# [500]	validation_0-rmse:0.32281
# [600]	validation_0-rmse:0.31299
# [700]	validation_0-rmse:0.30554
# [800]	validation_0-rmse:0.30126
# [900]	validation_0-rmse:0.29832
# [1000]	validation_0-rmse:0.29621
# [1100]	validation_0-rmse:0.29459
# [1200]	validation_0-rmse:0.29338
# [1300]	validation_0-rmse:0.29251
# [1400]	validation_0-rmse:0.29182
# [1500]	validation_0-rmse:0.29137
# [1600]	validation_0-rmse:0.29104
# [1700]	validation_0-rmse:0.29071
# [1800]	validation_0-rmse:0.29049
# [1900]	validation_0-rmse:0.29030
# [2000]	validation_0-rmse:0.29022
# [2100]	validation_0-rmse:0.29020
# [2200]	validation_0-rmse:0.29018
# [2245]	validation_0-rmse:0.29020
# 39 | val RMSE log = 0.29014 | best = 0.28872
# [0]	validation_0-rmse:1.42935
# [100]	validation_0-rmse:0.56179
# [200]	validation_0-rmse:0.46132
# [300]	validation_0-rmse:0.41195
# [400]	validation_0-rmse:0.38005
# [500]	validation_0-rmse:0.35914
# [600]	validation_0-rmse:0.34717
# [700]	validation_0-rmse:0.33635
# [800]	validation_0-rmse:0.32879
# [900]	validation_0-rmse:0.32172
# [1000]	validation_0-rmse:0.31642
# [1100]	validation_0-rmse:0.31240
# [1200]	validation_0-rmse:0.30858
# [1300]	validation_0-rmse:0.30588
# [1400]	validation_0-rmse:0.30368
# [1500]	validation_0-rmse:0.30166
# [1600]	validation_0-rmse:0.30005
# [1700]	validation_0-rmse:0.29864
# [1800]	validation_0-rmse:0.29742
# [1900]	validation_0-rmse:0.29634
# [1999]	validation_0-rmse:0.29543
# 40 | val RMSE log = 0.29543 | best = 0.28872
#     run  val_rmse_log  subsample  reg_lambda  reg_alpha  n_estimators  \
# 32   33      0.288724        1.0         1.0       1.00          2000
# 9    10      0.289934        0.9        20.0       0.10          2000
# 38   39      0.290143        0.8         1.0       1.00          3000
# 8     9      0.291159        0.9         3.0       0.01          2000
# 11   12      0.291493        0.7         3.0       0.00          3000
# 25   26      0.291676        1.0        20.0       0.10          3000
# 22   23      0.292690        0.8         1.0       0.00          2000
# 1     2      0.294048        1.0         3.0       1.00           800
# 7     8      0.294625        0.8        20.0       0.10          1200
# 4     5      0.295308        1.0        20.0       0.01          2000
#
#     min_child_weight  max_depth  learning_rate  colsample_bytree
# 32                10          7           0.08               0.9
# 9                 10          6           0.05               0.8
# 38                20          7           0.03               0.9
# 8                  1          7           0.02               1.0
# 11                 1          6           0.03               0.9
# 25                 3          5           0.05               1.0
# 22                 5          7           0.08               1.0
# 1                  5          6           0.08               0.9
# 7                 10          6           0.05               0.9
# 4                 20          7           0.02               0.9

# %% [markdown]
# # Evaluation

# %%
final_model = best_model

test_pred = final_model.predict(X_test)
test_rmse_log = np.sqrt(mean_squared_error(y_test, test_pred))

print("Test RMSE: ", test_rmse_log)
# Out:
# Test RMSE:  0.28239565259225735

# %%
def latency_metrics_from_log(y_log_true, y_log_pred):
    true_ms = np.exp(y_log_true)
    pred_ms = np.exp(y_log_pred)

    error_ms = pred_ms - true_ms
    rel_err = np.abs(error_ms) / true_ms
    ratio_err = np.maximum(pred_ms / true_ms, true_ms / pred_ms)

    rmse_log = np.sqrt(mean_squared_error(y_log_true, y_log_pred))
    rmse_ms = np.sqrt(np.mean(error_ms ** 2))
    rmse_percent = np.sqrt(np.mean(((error_ms / true_ms) * 100) ** 2))

    return {
        "rmse_log": rmse_log,
        "rmse_ms": rmse_ms,
        "rmse_percent": rmse_percent,

        "median_relative_error": np.median(rel_err),
        "p90_relative_error": np.percentile(rel_err, 90),
        "p95_relative_error": np.percentile(rel_err, 95),

        "median_percent_error": np.median(rel_err) * 100,
        "p90_percent_error": np.percentile(rel_err, 90) * 100,
        "p95_percent_error": np.percentile(rel_err, 95) * 100,

        "median_ratio_error": np.median(ratio_err),
        "p90_ratio_error": np.percentile(ratio_err, 90),

        "within_10pct": np.mean(rel_err <= 0.10),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
        "within_2x": np.mean(ratio_err <= 2.0),
    }

# %%
val_metrics = latency_metrics_from_log(y_val, final_model.predict(X_val))
test_metrics = latency_metrics_from_log(y_test, final_model.predict(X_test))

pd.DataFrame([val_metrics, test_metrics], index=["val", "test"])
# Out:
#       rmse_log     rmse_ms  rmse_percent  median_relative_error  \
# val   0.288724  148.713468     39.251191               0.079284
# test  0.282396  129.711156     36.121790               0.077346
#
#       p90_relative_error  p95_relative_error  median_percent_error  \
# val             0.416463            0.594870              7.928401
# test            0.410515            0.595775              7.734551
#
#       p90_percent_error  p95_percent_error  median_ratio_error  \
# val           41.646341          59.486969            1.083538
# test          41.051478          59.577511            1.081405
#
#       p90_ratio_error  within_10pct  within_25pct  within_50pct  within_2x
# val          1.523129      0.567425      0.812643      0.925243   0.957501
# test         1.521346      0.575106      0.815575      0.926826   0.958106

# %% [markdown]
# # Analysis

# %%
test_results = test_df.copy()

test_results["pred_log_latency"] = test_pred
test_results["true_log_latency"] = y_test

test_results["pred_latency_ms"] = np.exp(test_results["pred_log_latency"])
test_results["true_latency_ms"] = np.exp(test_results["true_log_latency"])

test_results["relative_error"] = (
    np.abs(test_results["pred_latency_ms"] - test_results["true_latency_ms"])
    / test_results["true_latency_ms"]
)

# %%
def group_latency_metrics(g):
    y_true = g["true_log_latency"].to_numpy()
    y_pred = g["pred_log_latency"].to_numpy()

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    return pd.Series({
        "count": len(g),
        "rmse_log": np.sqrt(mean_squared_error(y_true, y_pred)),
        "within_10pct": np.mean(rel_err <= 0.10),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
    })

# %%
test_results.groupby("platform").apply(group_latency_metrics).reset_index()
# Out:
# /tmp/ipykernel_6910/3061731483.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_results.groupby("platform").apply(group_latency_metrics).reset_index()
#    platform    count  rmse_log  within_10pct  within_25pct  within_50pct
# 0  bluehive  10744.0  0.325766      0.550168      0.778853      0.897710
# 1    gcloud  10739.0  0.230996      0.600056      0.852314      0.955955

# %%
test_results.groupby(["machine_type", "platform"]).apply(group_latency_metrics).reset_index()
# Out:
# /tmp/ipykernel_6910/2224414100.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_results.groupby(["machine_type", "platform"]).apply(group_latency_metrics).reset_index()
#   machine_type  platform    count  rmse_log  within_10pct  within_25pct  \
# 0         epyc    gcloud   9388.0  0.204349      0.622816      0.873349
# 1         xeon    gcloud   1351.0  0.366020      0.441895      0.706144
# 2    xeon_plat  bluehive  10744.0  0.325766      0.550168      0.778853
#
#    within_50pct
# 0      0.965914
# 1      0.886751
# 2      0.897710

# %%
test_results.groupby(["cpu_provider", "platform"]).apply(group_latency_metrics).reset_index()
# Out:
# /tmp/ipykernel_6910/3658681541.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_results.groupby(["cpu_provider", "platform"]).apply(group_latency_metrics).reset_index()
#   cpu_provider  platform    count  rmse_log  within_10pct  within_25pct  \
# 0          amd    gcloud   9388.0  0.204349      0.622816      0.873349
# 1        intel  bluehive  10744.0  0.325766      0.550168      0.778853
# 2        intel    gcloud   1351.0  0.366020      0.441895      0.706144
#
#    within_50pct
# 0      0.965914
# 1      0.897710
# 2      0.886751

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"]).apply(
    group_latency_metrics,
    include_groups=False
).reset_index()
# Out:
#   cpu_provider  platform  num_cores   count  rmse_log  within_10pct  \
# 0          amd    gcloud          1  2636.0  0.149715      0.753414
# 1          amd    gcloud          2  4015.0  0.195955      0.619925
# 2          amd    gcloud          4  2737.0  0.255572      0.501279
# 3        intel  bluehive          1  1347.0  0.241771      0.631032
# 4        intel  bluehive          2  2686.0  0.260675      0.656739
# 5        intel  bluehive          4  3999.0  0.317943      0.541385
# 6        intel  bluehive          8  2712.0  0.418367      0.417404
# 7        intel    gcloud          6  1351.0  0.366020      0.441895
#
#    within_25pct  within_50pct
# 0      0.934750      0.980653
# 1      0.884184      0.974595
# 2      0.798319      0.938984
# 3      0.881960      0.945805
# 4      0.837305      0.931497
# 5      0.775444      0.899725
# 6      0.674779      0.837389
# 7      0.706144      0.886751
