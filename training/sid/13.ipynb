# %%
from sklearn.metrics import mean_squared_error
import random
import numpy as np
import pandas as pd

# %% [markdown]
# # Load and pre-process data

# %%
target_col = "log_average_ms"

node_cols = ["Abs", "Acos", "Add", "ai.onnx.ml::CategoryMapper", "And", "ArgMax", 
             "AveragePool", "BatchNormalization", "Cast", "Ceil", "Clip", 
             "com.microsoft::BiasGelu", "com.microsoft::DynamicQuantizeLSTM", 
             "com.microsoft::DynamicQuantizeMatMul", "com.microsoft::FastGelu", 
             "com.microsoft::FusedConv", "com.microsoft::FusedGemm", 
             "com.microsoft::FusedMatMul", "com.microsoft::MatMulIntegerToFloat", 
             "com.microsoft::QGemm", "com.microsoft::QLinearAdd", 
             "com.microsoft::QLinearAveragePool", "com.microsoft::QLinearConcat", 
             "com.microsoft::QLinearGlobalAveragePool", "com.microsoft::QLinearLeakyRelu", 
             "com.microsoft::QLinearMul", "com.microsoft::QLinearSigmoid", 
             "com.microsoft::QuickGelu", "com.microsoft::SkipLayerNormalization", 
             "Compress", "Concat", "Constant", "ConstantOfShape", "Conv", "ConvInteger", 
             "ConvTranspose", "Cos", "CumSum", "DequantizeLinear", "Div", "Dropout", 
             "DynamicQuantizeLinear", "Einsum", "Equal", "Erf", "Exp", "Expand", 
             "EyeLike", "Flatten", "Floor", "Gather", "GatherElements", "GatherND", 
             "Gelu", "Gemm", "GlobalAveragePool", "Greater", "GreaterOrEqual", "Hardmax", 
             "HardSigmoid", "HardSwish", "Identity", "If", "InstanceNormalization", 
             "LayerNormalization", "LeakyRelu", "Less", "LessOrEqual", "local::preprocess", 
             "Log", "LogSoftmax", "Loop", "LRN", "LSTM", "MatMul", "MatMulInteger", 
             "Max", "MaxPool", "Min", "Mod", "Mul", "Neg", "NonMaxSuppression", "NonZero", 
             "Not", "OneHot", "Or", "Pad", "Pow", "PRelu", "QLinearConv", "QLinearMatMul", 
             "QuantizeLinear", "Range", "Reciprocal", "ReduceMax", "ReduceMean", "ReduceMin", 
             "ReduceProd", "ReduceSum", "Relu", "Reshape", "Resize", "RoiAlign", "Round", 
             "Scan", "ScatterElements", "ScatterND", "Shape", "Sigmoid", 
             "SimplifiedLayerNormalization", "Sin", "Slice", "Softmax", "Split", "Sqrt", 
             "Squeeze", "Sub", "Sum", "Tanh", "Tile", "TopK", "Transpose", "Trilu", 
             "Unsqueeze", "Where", "Xor"]

model_feature_cols = node_cols + ["conv_flops", "matmul_flops",
                "elementwise_mb", "reduction_mb", "normalization_mb",
                "movement_mb", "memory_mb"]

hardware_feature_cols = ["l1d_cache_kb", "l1i_cache_kb", "l2_cache_kb", 
                         "base_clock_mhz", "num_cores", "memory_bandwith_gbs", 
                         "cpu_provider"]

metadata_cols = ["model", "cpu_provider",
                 "machine_type", "platform", "run_id"]

# %%
from google.colab import drive

drive.mount("/content/drive")

# %%
# load test, train, val sets

train_df = pd.read_csv("/content/drive/MyDrive/Data/train_set.csv")
val_df = pd.read_csv("/content/drive/MyDrive/Data/val_set.csv")
test_df = pd.read_csv("/content/drive/MyDrive/Data/test_set.csv")

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (100252, 154)
# val: (21483, 154)
# test: (21483, 154)

# %%
assert list(train_df.columns) == list(val_df.columns) == list(test_df.columns)

train_df.head()
# Out:
#                                                model input_dimensions  \
# 0                hardcorenas_d_Opset17_extended.onnx    x:1x3x224x224
# 1  vit_base_patch8_224_in21k_Opset17_disable_all....    x:1x3x224x224
# 2    tf_efficientnetv2_m_in21ft1k_Opset17_basic.onnx    x:1x3x384x384
# 3                    shufflenet_v2_x1_5_Opset16.onnx    x:1x3x224x224
# 4                 wide_resnet101_2_Opset16_timm.onnx    x:1x3x224x224
#
#   input_dtypes output_dimensions output_dtypes   conv_flops  matmul_flops  \
# 0    x:float32        668:1x1000   668:float32    472440512       2560000
# 1    x:float32      1089:1x21843  1089:float32    231211008  156097479168
# 2    x:float32       2466:1x1000  2466:float32  31470991360       2560000
# 3    x:float32       1137:1x1000  1137:float32    266034528       2048000
# 4    x:float32        971:1x1000   971:float32  45502005248       4096000
#
#    elementwise_mb  reduction_mb  normalization_mb  ...  base_clock_mhz  \
# 0       50.528229      5.204269          0.000000  ...        2300.000
# 1     1771.169711      0.000000        792.141724  ...        2450.000
# 2     1201.339462     67.736023          0.000000  ...        2449.998
# 3        8.246674      1.630875          0.000000  ...        2449.998
# 4      252.656250      4.218750          0.000000  ...        2300.000
#
#    memory_bandwith_gbs  cpu_provider  machine_type  platform  \
# 0                  717         intel     xeon_plat  bluehive
# 1                  205           amd          epyc    gcloud
# 2                  205           amd          epyc    gcloud
# 3                  205           amd          epyc    gcloud
# 4                  717         intel     xeon_plat  bluehive
#
#                                    repo_file   average_ms   stddev_ms  \
# 0                 hardcorenas_d_Opset17.onnx    14.069188    0.082284
# 1     vit_base_patch8_224_in21k_Opset17.onnx  1481.456045  150.199862
# 2  tf_efficientnetv2_m_in21ft1k_Opset17.onnx   301.127424   12.889699
# 3            shufflenet_v2_x1_5_Opset16.onnx     8.161246    0.036559
# 4         wide_resnet101_2_Opset16_timm.onnx    38.147223    0.068437
#
#         min_ms       max_ms
# 0    13.931521    14.247209
# 1  1094.324125  1632.506909
# 2   286.464729   324.336829
# 3     8.080030     8.197800
# 4    38.035275    38.292409
#
# [5 rows x 154 columns]

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

SEED = 67
random.seed(SEED)
np.random.seed(SEED)

# %%
# pre-processing function

def preprocess(df: pd.DataFrame, train=False) -> pd.DataFrame:

  #drop rows with missing target
  df = df.dropna(subset=["average_ms"])

  # keep Run 6/10's strict CV rule on all splits
  cv_limit = 0.1
  df["cv"] = df["stddev_ms"] / df["average_ms"]
  df = df[df["cv"] <= cv_limit].copy()

  #add log_average_ms column
  df["log_average_ms"] = np.log(df["average_ms"])

  #remove decimals and round down
  for col in ["elementwise_mb", "reduction_mb", "normalization_mb", "movement_mb"]:
    df[col] = df[col].round(0)

  return df

# %%
train_df = preprocess(train_df, True)
test_df = preprocess(test_df, False)
val_df = preprocess(val_df, False)

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (95814, 156)
# val: (20494, 156)
# test: (20528, 156)

# %%
for col in model_feature_cols:
    train_df[col] = np.log1p(train_df[col].clip(lower=0))
    val_df[col] = np.log1p(val_df[col].clip(lower=0))
    test_df[col] = np.log1p(test_df[col].clip(lower=0))

# %% [markdown]
# # Data Setup

# %%
target_col = "log_average_ms"

# %%
cpu_provider_map = {
    "intel": 0.0,
    "amd": 1.0,
}

for df in [train_df, val_df, test_df]:
    df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

    if df["cpu_provider_binary"].isna().any():
        bad_values = df.loc[df["cpu_provider_binary"].isna(), "cpu_provider"].unique()
        raise ValueError(f"Unknown cpu_provider values: {bad_values}")

hardware_feature_cols = [
    col for col in hardware_feature_cols
    if col not in {"cpu_provider", "cpu_provider_binary"}
]
hardware_feature_cols.append("cpu_provider_binary")
# Out:
# /tmp/ipykernel_10449/3350037661.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_10449/3350037661.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_10449/3350037661.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

# %%
X_model_train = train_df[model_feature_cols].astype("float32").to_numpy()
X_model_val = val_df[model_feature_cols].astype("float32").to_numpy()
X_model_test = test_df[model_feature_cols].astype("float32").to_numpy()

X_hw_train = train_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_val = val_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_test = test_df[hardware_feature_cols].astype("float32").to_numpy()

y_train = train_df[target_col].astype("float32").to_numpy()
y_val = val_df[target_col].astype("float32").to_numpy()
y_test = test_df[target_col].astype("float32").to_numpy()

# %%
model_scaler = StandardScaler()
hw_scaler = StandardScaler()

X_model_train = model_scaler.fit_transform(X_model_train).astype("float32")
X_model_val = model_scaler.transform(X_model_val).astype("float32")
X_model_test = model_scaler.transform(X_model_test).astype("float32")

X_hw_train = hw_scaler.fit_transform(X_hw_train).astype("float32")
X_hw_val = hw_scaler.transform(X_hw_val).astype("float32")
X_hw_test = hw_scaler.transform(X_hw_test).astype("float32")

# %% [markdown]
# # Model Setup

# %%
def rmse_log(y_true, y_pred):
  return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class TwoTowerLatencyDataset(Dataset):
    def __init__(self, X_model, X_hw, y):
        self.X_model = torch.from_numpy(X_model)
        self.X_hw = torch.from_numpy(X_hw)
        self.y = torch.from_numpy(y)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X_model[idx], self.X_hw[idx], self.y[idx]

# %%
batch_size = 1024

train_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_train, X_hw_train, y_train),
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
)

val_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_val, X_hw_val, y_val),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

test_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_test, X_hw_test, y_test),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout=0.10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim * 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(dim * 2, dim),
        )
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        return self.norm(x + self.net(x))


class GatedFiLMLatencyMLP(nn.Module):
    def __init__(self, n_model_features: int, n_hw_features: int):
        super().__init__()

        emb_dim = 192

        self.model_in = nn.Sequential(
            nn.Linear(n_model_features, 384),
            nn.LayerNorm(384),
            nn.GELU(),
            nn.Dropout(0.12),
            nn.Linear(384, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        self.model_blocks = nn.Sequential(
            ResidualBlock(emb_dim, dropout=0.10),
            ResidualBlock(emb_dim, dropout=0.08),
            ResidualBlock(emb_dim, dropout=0.05),
        )

        self.hw_tower = nn.Sequential(
            nn.Linear(n_hw_features, 96),
            nn.LayerNorm(96),
            nn.GELU(),
            nn.Dropout(0.05),
            nn.Linear(96, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        self.hw_film = nn.Linear(emb_dim, emb_dim * 2)
        self.gate = nn.Sequential(
            nn.Linear(emb_dim * 2, emb_dim),
            nn.Sigmoid(),
        )

        self.fusion = nn.Sequential(
            nn.Linear(emb_dim * 5, 384),
            nn.LayerNorm(384),
            nn.GELU(),
            nn.Dropout(0.12),

            ResidualBlock(384, dropout=0.08),

            nn.Linear(384, 192),
            nn.LayerNorm(192),
            nn.GELU(),
            nn.Dropout(0.05),

            nn.Linear(192, 1),
        )

    def forward(self, model_x, hw_x):
        model_emb = self.model_in(model_x)
        model_emb = self.model_blocks(model_emb)

        hw_emb = self.hw_tower(hw_x)

        gamma, beta = self.hw_film(hw_emb).chunk(2, dim=1)
        film_model = model_emb * (1 + gamma) + beta

        gate = self.gate(torch.cat([model_emb, hw_emb], dim=1))
        conditioned_model = gate * film_model + (1 - gate) * model_emb

        interaction = conditioned_model * hw_emb
        diff = torch.abs(conditioned_model - hw_emb)
        ratio_proxy = conditioned_model / (torch.abs(hw_emb) + 1.0)

        fused = torch.cat(
            [conditioned_model, hw_emb, interaction, diff, ratio_proxy],
            dim=1,
        )

        return self.fusion(fused).squeeze(1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print("device:", device)
# Out:
# device: cuda

# %%
print("model features:", X_model_train.shape[1])
print("hardware features:", X_hw_train.shape[1])
# Out:
# model features: 134
# hardware features: 7

# %%
model = GatedFiLMLatencyMLP(
    n_model_features=X_model_train.shape[1],
    n_hw_features=X_hw_train.shape[1],
).to(device)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=8e-4,
    weight_decay=2e-4,
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=250,
    T_mult=2,
    eta_min=1e-5,
)

loss_fn = nn.SmoothL1Loss(beta=0.05)  # Huber loss on log latency

# %% [markdown]
# # Model Training

# %%
from sklearn.metrics import mean_squared_error

# %%
def evaluate_mlp(model, loader):
    model.eval()

    preds = []
    targets = []

    with torch.no_grad():
        for model_x, hw_x, y in loader:
            model_x = model_x.to(device)
            hw_x = hw_x.to(device)
            y = y.to(device)

            pred = model(model_x, hw_x)

            preds.append(pred.cpu().numpy())
            targets.append(y.cpu().numpy())

    y_pred = np.concatenate(preds)
    y_true = np.concatenate(targets)

    rmse_log = np.sqrt(mean_squared_error(y_true, y_pred))

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    metrics = {
        "rmse_log": rmse_log,
        "rmse_ms": np.sqrt(mean_squared_error(true_ms, pred_ms)),
        "rmse_percent": np.sqrt(mean_squared_error(rel_err, np.zeros_like(rel_err))),
        "median_relative_error": np.median(rel_err),
        "p90_relative_error": np.percentile(rel_err, 90),
        "p95_relative_error": np.percentile(rel_err, 95),
        "within_10pct": np.mean(rel_err <= 0.10),
        "median_ratio_error": np.median(np.maximum(pred_ms / true_ms, true_ms / pred_ms)),
        "p90_ratio_error": np.percentile(np.maximum(pred_ms / true_ms, true_ms / pred_ms), 90),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
        "within_2x": np.mean(np.maximum(pred_ms / true_ms, true_ms / pred_ms) <= 2.0),
    }

    return metrics, y_true, y_pred

# %%
best_val_rmse = float("inf")
best_within_10 = -float("inf")
best_state = None

num_epochs = 1600
patience = 300
min_delta = 1e-5
wait = 0

history = []

for epoch in range(1, num_epochs + 1):
    model.train()
    train_losses = []

    for model_x, hw_x, y in train_loader:
        model_x = model_x.to(device)
        hw_x = hw_x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        pred = model(model_x, hw_x)
        loss = loss_fn(pred, y)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        train_losses.append(loss.item())

    scheduler.step(epoch)

    val_metrics, _, _ = evaluate_mlp(model, val_loader)
    val_rmse = val_metrics["rmse_log"]
    val_within_10 = val_metrics["within_10pct"]

    history.append({
        "epoch": epoch,
        "train_loss": np.mean(train_losses),
        "lr": optimizer.param_groups[0]["lr"],
        **val_metrics,
    })

    improved = (
        val_within_10 > best_within_10 + min_delta
        or (abs(val_within_10 - best_within_10) <= min_delta and val_rmse < best_val_rmse - min_delta)
    )

    if improved:
        best_within_10 = val_within_10
        best_val_rmse = val_rmse
        best_state = {
            "model": {k: v.detach().cpu().clone() for k, v in model.state_dict().items()},
            "epoch": epoch,
            "val_rmse": val_rmse,
            "val_within_10pct": val_within_10,
        }
        wait = 0
    else:
        wait += 1

    if epoch % 5 == 0 or epoch == 1:
        print(
            f"epoch {epoch:04d} | "
            f"train_loss={np.mean(train_losses):.5f} | "
            f"val_rmse_log={val_rmse:.5f} | "
            f"within_10={val_within_10:.4f} | "
            f"best_within_10={best_within_10:.4f} | "
            f"lr={optimizer.param_groups[0]['lr']:.2e}"
        )

    if wait >= patience:
        print(f"Early stopping at epoch {epoch}; best epoch {best_state['epoch']}")
        break
# Out:
# epoch 0001 | train_loss=0.60233 | val_rmse_log=0.53458 | within_10=0.1825 | best_within_10=0.1825 | lr=8.00e-04
# epoch 0005 | train_loss=0.24774 | val_rmse_log=0.34983 | within_10=0.3441 | best_within_10=0.3441 | lr=7.99e-04
# epoch 0010 | train_loss=0.19935 | val_rmse_log=0.33000 | within_10=0.3556 | best_within_10=0.4576 | lr=7.97e-04
# epoch 0015 | train_loss=0.17167 | val_rmse_log=0.26141 | within_10=0.5334 | best_within_10=0.5343 | lr=7.93e-04
# epoch 0020 | train_loss=0.15564 | val_rmse_log=0.26661 | within_10=0.5082 | best_within_10=0.5366 | lr=7.88e-04
# epoch 0025 | train_loss=0.14618 | val_rmse_log=0.26389 | within_10=0.5569 | best_within_10=0.6107 | lr=7.81e-04
# epoch 0030 | train_loss=0.13534 | val_rmse_log=0.24574 | within_10=0.6046 | best_within_10=0.6127 | lr=7.72e-04
# epoch 0035 | train_loss=0.13302 | val_rmse_log=0.24065 | within_10=0.6430 | best_within_10=0.6534 | lr=7.62e-04
# epoch 0040 | train_loss=0.12589 | val_rmse_log=0.23861 | within_10=0.6903 | best_within_10=0.6903 | lr=7.51e-04
# epoch 0045 | train_loss=0.12620 | val_rmse_log=0.23022 | within_10=0.6972 | best_within_10=0.7039 | lr=7.39e-04
# epoch 0050 | train_loss=0.11720 | val_rmse_log=0.22977 | within_10=0.6958 | best_within_10=0.7145 | lr=7.25e-04
# epoch 0055 | train_loss=0.11439 | val_rmse_log=0.22185 | within_10=0.7408 | best_within_10=0.7408 | lr=7.09e-04
# epoch 0060 | train_loss=0.11166 | val_rmse_log=0.22293 | within_10=0.7275 | best_within_10=0.7422 | lr=6.93e-04
# epoch 0065 | train_loss=0.10925 | val_rmse_log=0.23964 | within_10=0.7258 | best_within_10=0.7588 | lr=6.75e-04
# epoch 0070 | train_loss=0.10787 | val_rmse_log=0.23073 | within_10=0.7297 | best_within_10=0.7620 | lr=6.57e-04
# epoch 0075 | train_loss=0.10655 | val_rmse_log=0.22270 | within_10=0.7367 | best_within_10=0.7620 | lr=6.37e-04
# epoch 0080 | train_loss=0.10495 | val_rmse_log=0.22851 | within_10=0.7518 | best_within_10=0.7658 | lr=6.17e-04
# epoch 0085 | train_loss=0.10213 | val_rmse_log=0.21683 | within_10=0.7581 | best_within_10=0.7888 | lr=5.95e-04
# epoch 0090 | train_loss=0.10021 | val_rmse_log=0.21740 | within_10=0.7604 | best_within_10=0.7888 | lr=5.73e-04
# epoch 0095 | train_loss=0.09905 | val_rmse_log=0.21847 | within_10=0.7895 | best_within_10=0.7895 | lr=5.50e-04
# epoch 0100 | train_loss=0.09673 | val_rmse_log=0.21531 | within_10=0.7906 | best_within_10=0.7906 | lr=5.27e-04
# epoch 0105 | train_loss=0.09603 | val_rmse_log=0.21320 | within_10=0.7990 | best_within_10=0.7990 | lr=5.03e-04
# epoch 0110 | train_loss=0.09363 | val_rmse_log=0.21497 | within_10=0.8140 | best_within_10=0.8140 | lr=4.79e-04
# epoch 0115 | train_loss=0.09395 | val_rmse_log=0.21214 | within_10=0.8041 | best_within_10=0.8140 | lr=4.55e-04
# epoch 0120 | train_loss=0.09108 | val_rmse_log=0.21170 | within_10=0.8106 | best_within_10=0.8140 | lr=4.30e-04
# epoch 0125 | train_loss=0.08960 | val_rmse_log=0.21357 | within_10=0.8079 | best_within_10=0.8229 | lr=4.05e-04
# epoch 0130 | train_loss=0.08875 | val_rmse_log=0.21355 | within_10=0.8089 | best_within_10=0.8266 | lr=3.80e-04
# epoch 0135 | train_loss=0.08921 | val_rmse_log=0.21243 | within_10=0.8258 | best_within_10=0.8266 | lr=3.55e-04
# epoch 0140 | train_loss=0.08638 | val_rmse_log=0.21176 | within_10=0.8176 | best_within_10=0.8266 | lr=3.31e-04
# epoch 0145 | train_loss=0.08559 | val_rmse_log=0.21012 | within_10=0.8329 | best_within_10=0.8329 | lr=3.07e-04
# epoch 0150 | train_loss=0.08709 | val_rmse_log=0.22591 | within_10=0.8137 | best_within_10=0.8397 | lr=2.83e-04
# epoch 0155 | train_loss=0.08378 | val_rmse_log=0.21127 | within_10=0.8401 | best_within_10=0.8403 | lr=2.60e-04
# epoch 0160 | train_loss=0.08398 | val_rmse_log=0.21067 | within_10=0.8432 | best_within_10=0.8445 | lr=2.37e-04
# epoch 0165 | train_loss=0.08233 | val_rmse_log=0.21005 | within_10=0.8444 | best_within_10=0.8467 | lr=2.15e-04
# epoch 0170 | train_loss=0.08173 | val_rmse_log=0.20887 | within_10=0.8493 | best_within_10=0.8520 | lr=1.93e-04
# epoch 0175 | train_loss=0.08088 | val_rmse_log=0.20903 | within_10=0.8422 | best_within_10=0.8520 | lr=1.73e-04
# epoch 0180 | train_loss=0.08033 | val_rmse_log=0.20966 | within_10=0.8516 | best_within_10=0.8551 | lr=1.53e-04
# epoch 0185 | train_loss=0.08016 | val_rmse_log=0.20930 | within_10=0.8543 | best_within_10=0.8551 | lr=1.35e-04
# epoch 0190 | train_loss=0.07928 | val_rmse_log=0.20933 | within_10=0.8550 | best_within_10=0.8551 | lr=1.17e-04
# epoch 0195 | train_loss=0.07903 | val_rmse_log=0.20888 | within_10=0.8540 | best_within_10=0.8563 | lr=1.01e-04
# epoch 0200 | train_loss=0.07831 | val_rmse_log=0.20939 | within_10=0.8586 | best_within_10=0.8586 | lr=8.54e-05
# epoch 0205 | train_loss=0.07805 | val_rmse_log=0.20907 | within_10=0.8560 | best_within_10=0.8586 | lr=7.15e-05
# epoch 0210 | train_loss=0.07793 | val_rmse_log=0.20895 | within_10=0.8578 | best_within_10=0.8607 | lr=5.89e-05
# epoch 0215 | train_loss=0.07776 | val_rmse_log=0.20948 | within_10=0.8582 | best_within_10=0.8607 | lr=4.76e-05
# epoch 0220 | train_loss=0.07737 | val_rmse_log=0.20905 | within_10=0.8603 | best_within_10=0.8609 | lr=3.77e-05
# epoch 0225 | train_loss=0.07692 | val_rmse_log=0.20942 | within_10=0.8601 | best_within_10=0.8619 | lr=2.93e-05
# epoch 0230 | train_loss=0.07680 | val_rmse_log=0.20911 | within_10=0.8603 | best_within_10=0.8619 | lr=2.24e-05
# epoch 0235 | train_loss=0.07665 | val_rmse_log=0.20909 | within_10=0.8615 | best_within_10=0.8619 | lr=1.70e-05
# epoch 0240 | train_loss=0.07637 | val_rmse_log=0.20905 | within_10=0.8617 | best_within_10=0.8622 | lr=1.31e-05
# epoch 0245 | train_loss=0.07641 | val_rmse_log=0.20890 | within_10=0.8600 | best_within_10=0.8626 | lr=1.08e-05
# epoch 0250 | train_loss=0.07662 | val_rmse_log=0.20905 | within_10=0.8616 | best_within_10=0.8626 | lr=8.00e-04
# epoch 0255 | train_loss=0.09317 | val_rmse_log=0.23045 | within_10=0.6879 | best_within_10=0.8626 | lr=8.00e-04
# epoch 0260 | train_loss=0.10045 | val_rmse_log=0.21614 | within_10=0.7794 | best_within_10=0.8626 | lr=7.99e-04
# epoch 0265 | train_loss=0.08939 | val_rmse_log=0.22758 | within_10=0.7801 | best_within_10=0.8626 | lr=7.98e-04
# epoch 0270 | train_loss=0.09288 | val_rmse_log=0.22443 | within_10=0.7888 | best_within_10=0.8626 | lr=7.97e-04
# epoch 0275 | train_loss=0.08827 | val_rmse_log=0.21125 | within_10=0.8108 | best_within_10=0.8626 | lr=7.95e-04
# epoch 0280 | train_loss=0.09221 | val_rmse_log=0.22460 | within_10=0.7828 | best_within_10=0.8626 | lr=7.93e-04
# epoch 0285 | train_loss=0.08723 | val_rmse_log=0.22009 | within_10=0.8104 | best_within_10=0.8626 | lr=7.90e-04
# epoch 0290 | train_loss=0.08416 | val_rmse_log=0.21382 | within_10=0.8207 | best_within_10=0.8626 | lr=7.88e-04
# epoch 0295 | train_loss=0.08431 | val_rmse_log=0.21102 | within_10=0.8360 | best_within_10=0.8626 | lr=7.84e-04
# epoch 0300 | train_loss=0.08485 | val_rmse_log=0.21372 | within_10=0.8135 | best_within_10=0.8626 | lr=7.81e-04
# epoch 0305 | train_loss=0.08404 | val_rmse_log=0.21997 | within_10=0.8196 | best_within_10=0.8626 | lr=7.77e-04
# epoch 0310 | train_loss=0.08202 | val_rmse_log=0.21077 | within_10=0.8334 | best_within_10=0.8626 | lr=7.72e-04
# epoch 0315 | train_loss=0.08265 | val_rmse_log=0.21493 | within_10=0.8243 | best_within_10=0.8626 | lr=7.68e-04
# epoch 0320 | train_loss=0.08318 | val_rmse_log=0.22074 | within_10=0.8346 | best_within_10=0.8626 | lr=7.62e-04
# epoch 0325 | train_loss=0.08238 | val_rmse_log=0.21317 | within_10=0.8111 | best_within_10=0.8626 | lr=7.57e-04
# epoch 0330 | train_loss=0.08080 | val_rmse_log=0.21701 | within_10=0.8278 | best_within_10=0.8626 | lr=7.51e-04
# epoch 0335 | train_loss=0.08088 | val_rmse_log=0.22060 | within_10=0.8214 | best_within_10=0.8626 | lr=7.45e-04
# epoch 0340 | train_loss=0.07978 | val_rmse_log=0.21167 | within_10=0.8394 | best_within_10=0.8626 | lr=7.39e-04
# epoch 0345 | train_loss=0.07880 | val_rmse_log=0.21568 | within_10=0.8502 | best_within_10=0.8626 | lr=7.32e-04
# epoch 0350 | train_loss=0.07917 | val_rmse_log=0.21512 | within_10=0.8386 | best_within_10=0.8626 | lr=7.25e-04
# epoch 0355 | train_loss=0.07758 | val_rmse_log=0.22963 | within_10=0.8260 | best_within_10=0.8626 | lr=7.17e-04
# epoch 0360 | train_loss=0.07508 | val_rmse_log=0.21311 | within_10=0.8339 | best_within_10=0.8626 | lr=7.09e-04
# epoch 0365 | train_loss=0.07913 | val_rmse_log=0.22179 | within_10=0.8348 | best_within_10=0.8626 | lr=7.01e-04
# epoch 0370 | train_loss=0.07582 | val_rmse_log=0.22018 | within_10=0.8452 | best_within_10=0.8626 | lr=6.93e-04
# epoch 0375 | train_loss=0.07625 | val_rmse_log=0.21811 | within_10=0.8519 | best_within_10=0.8626 | lr=6.84e-04
# epoch 0380 | train_loss=0.07342 | val_rmse_log=0.21331 | within_10=0.8503 | best_within_10=0.8626 | lr=6.75e-04
# epoch 0385 | train_loss=0.07509 | val_rmse_log=0.25164 | within_10=0.8429 | best_within_10=0.8626 | lr=6.66e-04
# epoch 0390 | train_loss=0.07627 | val_rmse_log=0.21997 | within_10=0.8545 | best_within_10=0.8626 | lr=6.57e-04
# epoch 0395 | train_loss=0.07413 | val_rmse_log=0.22205 | within_10=0.8468 | best_within_10=0.8626 | lr=6.47e-04
# epoch 0400 | train_loss=0.07176 | val_rmse_log=0.21531 | within_10=0.8470 | best_within_10=0.8626 | lr=6.37e-04
# epoch 0405 | train_loss=0.07136 | val_rmse_log=0.21204 | within_10=0.8562 | best_within_10=0.8626 | lr=6.27e-04
# epoch 0410 | train_loss=0.07167 | val_rmse_log=0.22044 | within_10=0.8523 | best_within_10=0.8626 | lr=6.17e-04
# epoch 0415 | train_loss=0.07089 | val_rmse_log=0.21190 | within_10=0.8575 | best_within_10=0.8626 | lr=6.06e-04
# epoch 0420 | train_loss=0.07035 | val_rmse_log=0.21393 | within_10=0.8538 | best_within_10=0.8626 | lr=5.95e-04
# epoch 0425 | train_loss=0.06957 | val_rmse_log=0.21295 | within_10=0.8575 | best_within_10=0.8626 | lr=5.84e-04
# epoch 0430 | train_loss=0.06973 | val_rmse_log=0.21307 | within_10=0.8600 | best_within_10=0.8626 | lr=5.73e-04
# epoch 0435 | train_loss=0.07178 | val_rmse_log=0.22425 | within_10=0.8552 | best_within_10=0.8626 | lr=5.62e-04
# epoch 0440 | train_loss=0.06834 | val_rmse_log=0.21330 | within_10=0.8599 | best_within_10=0.8626 | lr=5.50e-04
# epoch 0445 | train_loss=0.06786 | val_rmse_log=0.21303 | within_10=0.8584 | best_within_10=0.8626 | lr=5.39e-04
# epoch 0450 | train_loss=0.07043 | val_rmse_log=0.22213 | within_10=0.8581 | best_within_10=0.8626 | lr=5.27e-04
# epoch 0455 | train_loss=0.06882 | val_rmse_log=0.21185 | within_10=0.8573 | best_within_10=0.8626 | lr=5.15e-04
# epoch 0460 | train_loss=0.06700 | val_rmse_log=0.21333 | within_10=0.8591 | best_within_10=0.8626 | lr=5.03e-04
# epoch 0465 | train_loss=0.06691 | val_rmse_log=0.21310 | within_10=0.8562 | best_within_10=0.8626 | lr=4.91e-04
# epoch 0470 | train_loss=0.06655 | val_rmse_log=0.21749 | within_10=0.8566 | best_within_10=0.8639 | lr=4.79e-04
# epoch 0475 | train_loss=0.06657 | val_rmse_log=0.21357 | within_10=0.8563 | best_within_10=0.8676 | lr=4.67e-04
# epoch 0480 | train_loss=0.06858 | val_rmse_log=0.22241 | within_10=0.8512 | best_within_10=0.8676 | lr=4.55e-04
# epoch 0485 | train_loss=0.06516 | val_rmse_log=0.21301 | within_10=0.8643 | best_within_10=0.8676 | lr=4.42e-04
# epoch 0490 | train_loss=0.06516 | val_rmse_log=0.21369 | within_10=0.8594 | best_within_10=0.8676 | lr=4.30e-04
# epoch 0495 | train_loss=0.06525 | val_rmse_log=0.21360 | within_10=0.8608 | best_within_10=0.8676 | lr=4.17e-04
# epoch 0500 | train_loss=0.06500 | val_rmse_log=0.21377 | within_10=0.8629 | best_within_10=0.8676 | lr=4.05e-04
# epoch 0505 | train_loss=0.06391 | val_rmse_log=0.21339 | within_10=0.8664 | best_within_10=0.8676 | lr=3.93e-04
# epoch 0510 | train_loss=0.06378 | val_rmse_log=0.21292 | within_10=0.8659 | best_within_10=0.8676 | lr=3.80e-04
# epoch 0515 | train_loss=0.06393 | val_rmse_log=0.21382 | within_10=0.8660 | best_within_10=0.8676 | lr=3.68e-04
# epoch 0520 | train_loss=0.06331 | val_rmse_log=0.21350 | within_10=0.8652 | best_within_10=0.8693 | lr=3.55e-04
# epoch 0525 | train_loss=0.06319 | val_rmse_log=0.21398 | within_10=0.8665 | best_within_10=0.8693 | lr=3.43e-04
# epoch 0530 | train_loss=0.06343 | val_rmse_log=0.21348 | within_10=0.8676 | best_within_10=0.8693 | lr=3.31e-04
# epoch 0535 | train_loss=0.06468 | val_rmse_log=0.21354 | within_10=0.8655 | best_within_10=0.8693 | lr=3.19e-04
# epoch 0540 | train_loss=0.06233 | val_rmse_log=0.21392 | within_10=0.8672 | best_within_10=0.8693 | lr=3.07e-04
# epoch 0545 | train_loss=0.06204 | val_rmse_log=0.21340 | within_10=0.8668 | best_within_10=0.8693 | lr=2.95e-04
# epoch 0550 | train_loss=0.06206 | val_rmse_log=0.21391 | within_10=0.8667 | best_within_10=0.8693 | lr=2.83e-04
# epoch 0555 | train_loss=0.06173 | val_rmse_log=0.21402 | within_10=0.8676 | best_within_10=0.8704 | lr=2.71e-04
# epoch 0560 | train_loss=0.06205 | val_rmse_log=0.21477 | within_10=0.8633 | best_within_10=0.8704 | lr=2.60e-04
# epoch 0565 | train_loss=0.06116 | val_rmse_log=0.21374 | within_10=0.8691 | best_within_10=0.8704 | lr=2.48e-04
# epoch 0570 | train_loss=0.06099 | val_rmse_log=0.21380 | within_10=0.8702 | best_within_10=0.8707 | lr=2.37e-04
# epoch 0575 | train_loss=0.06092 | val_rmse_log=0.21383 | within_10=0.8686 | best_within_10=0.8707 | lr=2.26e-04
# epoch 0580 | train_loss=0.06087 | val_rmse_log=0.21378 | within_10=0.8685 | best_within_10=0.8707 | lr=2.15e-04
# epoch 0585 | train_loss=0.06054 | val_rmse_log=0.21366 | within_10=0.8690 | best_within_10=0.8707 | lr=2.04e-04
# epoch 0590 | train_loss=0.06053 | val_rmse_log=0.21427 | within_10=0.8679 | best_within_10=0.8707 | lr=1.93e-04
# epoch 0595 | train_loss=0.06018 | val_rmse_log=0.21399 | within_10=0.8687 | best_within_10=0.8707 | lr=1.83e-04
# epoch 0600 | train_loss=0.06021 | val_rmse_log=0.21413 | within_10=0.8700 | best_within_10=0.8707 | lr=1.73e-04
# epoch 0605 | train_loss=0.05987 | val_rmse_log=0.21410 | within_10=0.8699 | best_within_10=0.8707 | lr=1.63e-04
# epoch 0610 | train_loss=0.05977 | val_rmse_log=0.21440 | within_10=0.8686 | best_within_10=0.8711 | lr=1.53e-04
# epoch 0615 | train_loss=0.05962 | val_rmse_log=0.21444 | within_10=0.8684 | best_within_10=0.8714 | lr=1.44e-04
# epoch 0620 | train_loss=0.05966 | val_rmse_log=0.21441 | within_10=0.8682 | best_within_10=0.8714 | lr=1.35e-04
# epoch 0625 | train_loss=0.05944 | val_rmse_log=0.21441 | within_10=0.8692 | best_within_10=0.8714 | lr=1.26e-04
# epoch 0630 | train_loss=0.05925 | val_rmse_log=0.21426 | within_10=0.8701 | best_within_10=0.8714 | lr=1.17e-04
# epoch 0635 | train_loss=0.05920 | val_rmse_log=0.21432 | within_10=0.8685 | best_within_10=0.8714 | lr=1.09e-04
# epoch 0640 | train_loss=0.05910 | val_rmse_log=0.21422 | within_10=0.8692 | best_within_10=0.8714 | lr=1.01e-04
# epoch 0645 | train_loss=0.05883 | val_rmse_log=0.21450 | within_10=0.8691 | best_within_10=0.8714 | lr=9.29e-05
# epoch 0650 | train_loss=0.05869 | val_rmse_log=0.21426 | within_10=0.8687 | best_within_10=0.8714 | lr=8.54e-05
# epoch 0655 | train_loss=0.05870 | val_rmse_log=0.21447 | within_10=0.8700 | best_within_10=0.8714 | lr=7.83e-05
# epoch 0660 | train_loss=0.05849 | val_rmse_log=0.21450 | within_10=0.8682 | best_within_10=0.8714 | lr=7.15e-05
# epoch 0665 | train_loss=0.05845 | val_rmse_log=0.21448 | within_10=0.8695 | best_within_10=0.8714 | lr=6.50e-05
# epoch 0670 | train_loss=0.05849 | val_rmse_log=0.21445 | within_10=0.8699 | best_within_10=0.8714 | lr=5.89e-05
# epoch 0675 | train_loss=0.05815 | val_rmse_log=0.21427 | within_10=0.8696 | best_within_10=0.8714 | lr=5.31e-05
# epoch 0680 | train_loss=0.05834 | val_rmse_log=0.21461 | within_10=0.8693 | best_within_10=0.8714 | lr=4.76e-05
# epoch 0685 | train_loss=0.05833 | val_rmse_log=0.21422 | within_10=0.8693 | best_within_10=0.8714 | lr=4.25e-05
# epoch 0690 | train_loss=0.05810 | val_rmse_log=0.21420 | within_10=0.8702 | best_within_10=0.8714 | lr=3.77e-05
# epoch 0695 | train_loss=0.05814 | val_rmse_log=0.21438 | within_10=0.8708 | best_within_10=0.8714 | lr=3.34e-05
# epoch 0700 | train_loss=0.05813 | val_rmse_log=0.21449 | within_10=0.8701 | best_within_10=0.8714 | lr=2.93e-05
# epoch 0705 | train_loss=0.05801 | val_rmse_log=0.21426 | within_10=0.8705 | best_within_10=0.8714 | lr=2.57e-05
# epoch 0710 | train_loss=0.05805 | val_rmse_log=0.21429 | within_10=0.8701 | best_within_10=0.8714 | lr=2.24e-05
# epoch 0715 | train_loss=0.05790 | val_rmse_log=0.21434 | within_10=0.8705 | best_within_10=0.8714 | lr=1.95e-05
# epoch 0720 | train_loss=0.05779 | val_rmse_log=0.21451 | within_10=0.8698 | best_within_10=0.8714 | lr=1.70e-05
# epoch 0725 | train_loss=0.05795 | val_rmse_log=0.21461 | within_10=0.8695 | best_within_10=0.8714 | lr=1.49e-05
# epoch 0730 | train_loss=0.05782 | val_rmse_log=0.21444 | within_10=0.8694 | best_within_10=0.8714 | lr=1.31e-05
# epoch 0735 | train_loss=0.05776 | val_rmse_log=0.21441 | within_10=0.8702 | best_within_10=0.8714 | lr=1.18e-05
# epoch 0740 | train_loss=0.05775 | val_rmse_log=0.21442 | within_10=0.8704 | best_within_10=0.8714 | lr=1.08e-05
# epoch 0745 | train_loss=0.05777 | val_rmse_log=0.21450 | within_10=0.8699 | best_within_10=0.8714 | lr=1.02e-05
# epoch 0750 | train_loss=0.05794 | val_rmse_log=0.21439 | within_10=0.8694 | best_within_10=0.8714 | lr=8.00e-04
# epoch 0755 | train_loss=0.07001 | val_rmse_log=0.23348 | within_10=0.8490 | best_within_10=0.8714 | lr=8.00e-04
# epoch 0760 | train_loss=0.07058 | val_rmse_log=0.21373 | within_10=0.8428 | best_within_10=0.8714 | lr=8.00e-04
# epoch 0765 | train_loss=0.06480 | val_rmse_log=0.21260 | within_10=0.8526 | best_within_10=0.8714 | lr=8.00e-04
# epoch 0770 | train_loss=0.06777 | val_rmse_log=0.21318 | within_10=0.8513 | best_within_10=0.8714 | lr=7.99e-04
# epoch 0775 | train_loss=0.06426 | val_rmse_log=0.21253 | within_10=0.8607 | best_within_10=0.8714 | lr=7.99e-04
# epoch 0780 | train_loss=0.06362 | val_rmse_log=0.21223 | within_10=0.8573 | best_within_10=0.8714 | lr=7.98e-04
# epoch 0785 | train_loss=0.06296 | val_rmse_log=0.21234 | within_10=0.8627 | best_within_10=0.8714 | lr=7.98e-04
# epoch 0790 | train_loss=0.06359 | val_rmse_log=0.21185 | within_10=0.8606 | best_within_10=0.8714 | lr=7.97e-04
# epoch 0795 | train_loss=0.06783 | val_rmse_log=0.21355 | within_10=0.8614 | best_within_10=0.8714 | lr=7.96e-04
# epoch 0800 | train_loss=0.06423 | val_rmse_log=0.21896 | within_10=0.8568 | best_within_10=0.8714 | lr=7.95e-04
# epoch 0805 | train_loss=0.06278 | val_rmse_log=0.21464 | within_10=0.8586 | best_within_10=0.8714 | lr=7.94e-04
# epoch 0810 | train_loss=0.06269 | val_rmse_log=0.21436 | within_10=0.8601 | best_within_10=0.8714 | lr=7.93e-04
# epoch 0815 | train_loss=0.06267 | val_rmse_log=0.21537 | within_10=0.8589 | best_within_10=0.8714 | lr=7.92e-04
# epoch 0820 | train_loss=0.06249 | val_rmse_log=0.21799 | within_10=0.8623 | best_within_10=0.8714 | lr=7.90e-04
# epoch 0825 | train_loss=0.06213 | val_rmse_log=0.21485 | within_10=0.8628 | best_within_10=0.8714 | lr=7.89e-04
# epoch 0830 | train_loss=0.06138 | val_rmse_log=0.21572 | within_10=0.8623 | best_within_10=0.8714 | lr=7.88e-04
# epoch 0835 | train_loss=0.06229 | val_rmse_log=0.21735 | within_10=0.8536 | best_within_10=0.8714 | lr=7.86e-04
# epoch 0840 | train_loss=0.06098 | val_rmse_log=0.21487 | within_10=0.8619 | best_within_10=0.8714 | lr=7.84e-04
# epoch 0845 | train_loss=0.06080 | val_rmse_log=0.21947 | within_10=0.8573 | best_within_10=0.8714 | lr=7.83e-04
# epoch 0850 | train_loss=0.06148 | val_rmse_log=0.21600 | within_10=0.8602 | best_within_10=0.8714 | lr=7.81e-04
# epoch 0855 | train_loss=0.06605 | val_rmse_log=0.22688 | within_10=0.8599 | best_within_10=0.8714 | lr=7.79e-04
# epoch 0860 | train_loss=0.05967 | val_rmse_log=0.21524 | within_10=0.8657 | best_within_10=0.8714 | lr=7.77e-04
# epoch 0865 | train_loss=0.06237 | val_rmse_log=0.21539 | within_10=0.8623 | best_within_10=0.8714 | lr=7.75e-04
# epoch 0870 | train_loss=0.06039 | val_rmse_log=0.21885 | within_10=0.8568 | best_within_10=0.8714 | lr=7.72e-04
# epoch 0875 | train_loss=0.06047 | val_rmse_log=0.21413 | within_10=0.8613 | best_within_10=0.8714 | lr=7.70e-04
# epoch 0880 | train_loss=0.07107 | val_rmse_log=0.21765 | within_10=0.8561 | best_within_10=0.8714 | lr=7.68e-04
# epoch 0885 | train_loss=0.05944 | val_rmse_log=0.21493 | within_10=0.8610 | best_within_10=0.8714 | lr=7.65e-04
# epoch 0890 | train_loss=0.06005 | val_rmse_log=0.22567 | within_10=0.8556 | best_within_10=0.8714 | lr=7.62e-04
# epoch 0895 | train_loss=0.06114 | val_rmse_log=0.22491 | within_10=0.8585 | best_within_10=0.8714 | lr=7.60e-04
# epoch 0900 | train_loss=0.06068 | val_rmse_log=0.21636 | within_10=0.8622 | best_within_10=0.8714 | lr=7.57e-04
# epoch 0905 | train_loss=0.05888 | val_rmse_log=0.23371 | within_10=0.8502 | best_within_10=0.8714 | lr=7.54e-04
# epoch 0910 | train_loss=0.05928 | val_rmse_log=0.22773 | within_10=0.8558 | best_within_10=0.8714 | lr=7.51e-04
# Early stopping at epoch 912; best epoch 612

# %% [markdown]
# # Evaluation

# %%
import pandas as pd
import matplotlib.pyplot as plt

history_df = pd.DataFrame(history)

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(
    history_df["epoch"],
    history_df["train_loss"],
    label="Train loss",
    color="tab:blue",
)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Train loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.plot(
    history_df["epoch"],
    history_df["within_10pct"],
    label="Within 10%",
    color="tab:orange",
)
ax2.plot(
    history_df["epoch"],
    history_df["rmse_log"],
    label="Val RMSE log",
    color="tab:green",
    alpha=0.6,
)
ax2.set_ylabel("Validation metrics")
ax2.set_ylim(0, max(1.0, history_df["rmse_log"].max() * 1.1))

fig.suptitle("Training Loss, Within-10%, and RMSE Over Time")
fig.tight_layout()
plt.show()

history_df.sort_values(["within_10pct", "rmse_log"], ascending=[False, True]).head(10)
# Out:
#      epoch  train_loss        lr  rmse_log     rmse_ms  rmse_percent  \
# 611    612    0.059763  0.000149  0.213859  151.590558      0.413436
# 643    644    0.058787  0.000094  0.214241  151.419694      0.415310
# 606    607    0.059908  0.000159  0.213790  150.628345      0.414273
# 626    627    0.059311  0.000122  0.214143  152.144475      0.414902
# 701    702    0.057938  0.000028  0.214388  152.296348      0.415278
# 610    611    0.059749  0.000151  0.214160  151.438641      0.417014
# 677    678    0.058304  0.000050  0.214198  154.437683      0.416117
# 707    708    0.057927  0.000024  0.214251  151.800798      0.414650
# 673    674    0.058247  0.000054  0.214408  155.006458      0.416449
# 668    669    0.058567  0.000060  0.214192  152.016119      0.415714
#
#      median_relative_error  p90_relative_error  p95_relative_error  \
# 611               0.020284            0.142407            0.324966
# 643               0.019232            0.144734            0.326346
# 606               0.019543            0.140330            0.324793
# 626               0.019425            0.143528            0.323629
# 701               0.017368            0.143614            0.326676
# 610               0.018172            0.143201            0.324130
# 677               0.018180            0.144121            0.325417
# 707               0.017460            0.144275            0.325370
# 673               0.018732            0.142706            0.322550
# 668               0.017819            0.142982            0.327532
#
#      within_10pct  median_ratio_error  p90_ratio_error  within_25pct  \
# 611      0.871377            1.020510         1.151232      0.937250
# 643      0.871231            1.019401         1.153186      0.936908
# 606      0.871133            1.019734         1.149988      0.937396
# 626      0.871084            1.019619         1.154031      0.936664
# 701      0.871084            1.017543         1.153350      0.936664
# 610      0.870987            1.018340         1.151088      0.936664
# 677      0.870889            1.018337         1.153012      0.936713
# 707      0.870840            1.017615         1.154208      0.936616
# 673      0.870840            1.018935         1.152163      0.936957
# 668      0.870791            1.018019         1.151440      0.936908
#
#      within_50pct  within_2x
# 611      0.967259   0.982141
# 643      0.966966   0.982044
# 606      0.967161   0.982287
# 626      0.967405   0.982239
# 701      0.966917   0.982092
# 610      0.966966   0.982141
# 677      0.966820   0.982092
# 707      0.966868   0.982044
# 673      0.966868   0.982092
# 668      0.966966   0.981995

# %%
model.load_state_dict(best_state["model"])
print("Best epoch:", best_state["epoch"])
print("Best val RMSE:", best_state["val_rmse"])
print("Best val within_10pct:", best_state["val_within_10pct"])
# Out:
# Best epoch: 612
# Best val RMSE: 0.21385890474349278
# Best val within_10pct: 0.871376988386845

# %%
val_metrics, val_true_log, val_pred_log = evaluate_mlp(model, val_loader)
test_metrics, test_true_log, test_pred_log = evaluate_mlp(model, test_loader)

pd.DataFrame([val_metrics, test_metrics], index=["val", "test"])
# Out:
#       rmse_log     rmse_ms  rmse_percent  median_relative_error  \
# val   0.213859  151.590558      0.413436               0.020284
# test  0.193490  115.915838      0.300388               0.020046
#
#       p90_relative_error  p95_relative_error  within_10pct  \
# val             0.142407            0.324966      0.871377
# test            0.133075            0.317705      0.875633
#
#       median_ratio_error  p90_ratio_error  within_25pct  within_50pct  \
# val             1.020510         1.151232      0.937250      0.967259
# test            1.020287         1.142147      0.938572      0.968287
#
#       within_2x
# val    0.982141
# test   0.983583

# %% [markdown]
# # Save Model

# %%
from pathlib import Path
import torch

model_dir = Path("/content/drive/MyDrive/Models")
model_dir.mkdir(parents=True, exist_ok=True)

save_path = model_dir / "13.pt"

if "best_state" in globals() and best_state is not None:
    model.load_state_dict(best_state["model"])

torch.save(
    {
        "model_state_dict": model.state_dict(),
        "n_model_features": X_model_train.shape[1],
        "n_hw_features": X_hw_train.shape[1],
        "model_feature_cols": model_feature_cols,
        "hardware_feature_cols": hardware_feature_cols,
        "model_scaler": model_scaler,
        "hw_scaler": hw_scaler,
        "target_col": "log_average_ms",
        "best_val_rmse": best_val_rmse if "best_val_rmse" in globals() else None,
        "best_val_within_10pct": best_within_10 if "best_within_10" in globals() else None,
        "seed": SEED,
    },
    save_path,
)

print("Saved to:", save_path)
# Out:
# Saved to: /content/drive/MyDrive/Models/13.pt

# %% [markdown]
# # Analysis

# %%
test_results = test_df.copy()

test_results["pred_log_latency"] = test_pred_log
test_results["true_log_latency"] = test_true_log

test_results["pred_latency_ms"] = np.exp(test_results["pred_log_latency"])
test_results["true_latency_ms"] = np.exp(test_results["true_log_latency"])

test_results["relative_error"] = (
    np.abs(test_results["pred_latency_ms"] - test_results["true_latency_ms"])
    / test_results["true_latency_ms"]
)

# %%
def group_latency_metrics(g):
    y_true = g["true_log_latency"].to_numpy()
    y_pred = g["pred_log_latency"].to_numpy()

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    return pd.Series({
        "count": len(g),
        "rmse_log": np.sqrt(mean_squared_error(y_true, y_pred)),
        "within_10pct": np.mean(rel_err <= 0.10),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
    })

# %%
test_results["abs_log_error"] = np.abs(
    test_results["pred_log_latency"] - test_results["true_log_latency"]
)

test_results.groupby(["cpu_provider", "platform", "num_cores"])["relative_error"].agg(
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
    within_10pct=lambda x: (x <= 0.10).mean(),
    within_25pct=lambda x: (x <= 0.25).mean(),
).reset_index()

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"])["cv"].agg(
    within_10pct=lambda x: (x <= 0.10).mean(),
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
).reset_index()

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"]).apply(
    group_latency_metrics,
    include_groups=False
).reset_index()
