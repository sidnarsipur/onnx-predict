# %%
from sklearn.metrics import mean_squared_error
import random
import numpy as np
import pandas as pd

# %% [markdown]
# # Load and pre-process data

# %%
target_col = "log_average_ms"

node_cols = ["Abs", "Acos", "Add", "ai.onnx.ml::CategoryMapper", "And", "ArgMax", 
             "AveragePool", "BatchNormalization", "Cast", "Ceil", "Clip", 
             "com.microsoft::BiasGelu", "com.microsoft::DynamicQuantizeLSTM", 
             "com.microsoft::DynamicQuantizeMatMul", "com.microsoft::FastGelu", 
             "com.microsoft::FusedConv", "com.microsoft::FusedGemm", 
             "com.microsoft::FusedMatMul", "com.microsoft::MatMulIntegerToFloat", 
             "com.microsoft::QGemm", "com.microsoft::QLinearAdd", 
             "com.microsoft::QLinearAveragePool", "com.microsoft::QLinearConcat", 
             "com.microsoft::QLinearGlobalAveragePool", "com.microsoft::QLinearLeakyRelu", 
             "com.microsoft::QLinearMul", "com.microsoft::QLinearSigmoid", 
             "com.microsoft::QuickGelu", "com.microsoft::SkipLayerNormalization", 
             "Compress", "Concat", "Constant", "ConstantOfShape", "Conv", "ConvInteger", 
             "ConvTranspose", "Cos", "CumSum", "DequantizeLinear", "Div", "Dropout", 
             "DynamicQuantizeLinear", "Einsum", "Equal", "Erf", "Exp", "Expand", 
             "EyeLike", "Flatten", "Floor", "Gather", "GatherElements", "GatherND", 
             "Gelu", "Gemm", "GlobalAveragePool", "Greater", "GreaterOrEqual", "Hardmax", 
             "HardSigmoid", "HardSwish", "Identity", "If", "InstanceNormalization", 
             "LayerNormalization", "LeakyRelu", "Less", "LessOrEqual", "local::preprocess", 
             "Log", "LogSoftmax", "Loop", "LRN", "LSTM", "MatMul", "MatMulInteger", 
             "Max", "MaxPool", "Min", "Mod", "Mul", "Neg", "NonMaxSuppression", "NonZero", 
             "Not", "OneHot", "Or", "Pad", "Pow", "PRelu", "QLinearConv", "QLinearMatMul", 
             "QuantizeLinear", "Range", "Reciprocal", "ReduceMax", "ReduceMean", "ReduceMin", 
             "ReduceProd", "ReduceSum", "Relu", "Reshape", "Resize", "RoiAlign", "Round", 
             "Scan", "ScatterElements", "ScatterND", "Shape", "Sigmoid", 
             "SimplifiedLayerNormalization", "Sin", "Slice", "Softmax", "Split", "Sqrt", 
             "Squeeze", "Sub", "Sum", "Tanh", "Tile", "TopK", "Transpose", "Trilu", 
             "Unsqueeze", "Where", "Xor"]

base_model_feature_cols = node_cols + ["conv_flops", "matmul_flops",
                "elementwise_mb", "reduction_mb", "normalization_mb",
                "movement_mb", "memory_mb"]

engineered_model_feature_cols = [
    "total_flops",
    "total_mb",
    "operational_intensity",
    "conv_frac",
    "matmul_frac",
    "elementwise_frac",
    "reduction_frac",
    "normalization_frac",
    "movement_frac",
    "memory_frac",
]

model_feature_cols = base_model_feature_cols + engineered_model_feature_cols

hardware_feature_cols = ["l1d_cache_kb", "l1i_cache_kb", "l2_cache_kb", 
                         "base_clock_mhz", "num_cores", "memory_bandwith_gbs", 
                         "cpu_provider", "bandwidth_per_core_gbs",
                         "l2_cache_per_core_kb", "clock_x_cores_mhz"]

metadata_cols = ["model", "cpu_provider",
                 "machine_type", "platform", "run_id"]

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# load test, train, val sets

train_df = pd.read_csv("/content/drive/MyDrive/Data/train_set.csv")
val_df = pd.read_csv("/content/drive/MyDrive/Data/val_set.csv")
test_df = pd.read_csv("/content/drive/MyDrive/Data/test_set.csv")

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (100252, 154)
# val: (21483, 154)
# test: (21483, 154)

# %%
assert list(train_df.columns) == list(val_df.columns) == list(test_df.columns)

train_df.head()
# Out:
#                                                model input_dimensions  \
# 0                hardcorenas_d_Opset17_extended.onnx    x:1x3x224x224
# 1  vit_base_patch8_224_in21k_Opset17_disable_all....    x:1x3x224x224
# 2    tf_efficientnetv2_m_in21ft1k_Opset17_basic.onnx    x:1x3x384x384
# 3                    shufflenet_v2_x1_5_Opset16.onnx    x:1x3x224x224
# 4                 wide_resnet101_2_Opset16_timm.onnx    x:1x3x224x224
#
#   input_dtypes output_dimensions output_dtypes   conv_flops  matmul_flops  \
# 0    x:float32        668:1x1000   668:float32    472440512       2560000
# 1    x:float32      1089:1x21843  1089:float32    231211008  156097479168
# 2    x:float32       2466:1x1000  2466:float32  31470991360       2560000
# 3    x:float32       1137:1x1000  1137:float32    266034528       2048000
# 4    x:float32        971:1x1000   971:float32  45502005248       4096000
#
#    elementwise_mb  reduction_mb  normalization_mb  ...  base_clock_mhz  \
# 0       50.528229      5.204269          0.000000  ...        2300.000
# 1     1771.169711      0.000000        792.141724  ...        2450.000
# 2     1201.339462     67.736023          0.000000  ...        2449.998
# 3        8.246674      1.630875          0.000000  ...        2449.998
# 4      252.656250      4.218750          0.000000  ...        2300.000
#
#    memory_bandwith_gbs  cpu_provider  machine_type  platform  \
# 0                  717         intel     xeon_plat  bluehive
# 1                  205           amd          epyc    gcloud
# 2                  205           amd          epyc    gcloud
# 3                  205           amd          epyc    gcloud
# 4                  717         intel     xeon_plat  bluehive
#
#                                    repo_file   average_ms   stddev_ms  \
# 0                 hardcorenas_d_Opset17.onnx    14.069188    0.082284
# 1     vit_base_patch8_224_in21k_Opset17.onnx  1481.456045  150.199862
# 2  tf_efficientnetv2_m_in21ft1k_Opset17.onnx   301.127424   12.889699
# 3            shufflenet_v2_x1_5_Opset16.onnx     8.161246    0.036559
# 4         wide_resnet101_2_Opset16_timm.onnx    38.147223    0.068437
#
#         min_ms       max_ms
# 0    13.931521    14.247209
# 1  1094.324125  1632.506909
# 2   286.464729   324.336829
# 3     8.080030     8.197800
# 4    38.035275    38.292409
#
# [5 rows x 154 columns]

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler

SEED = 67
random.seed(SEED)
np.random.seed(SEED)

# %%
# pre-processing function

def add_engineered_features(df: pd.DataFrame) -> pd.DataFrame:
  df = df.copy()

  total_flops = df["conv_flops"].fillna(0) + df["matmul_flops"].fillna(0)
  total_mb = (
      df["elementwise_mb"].fillna(0)
      + df["reduction_mb"].fillna(0)
      + df["normalization_mb"].fillna(0)
      + df["movement_mb"].fillna(0)
      + df["memory_mb"].fillna(0)
  )

  df["total_flops"] = total_flops
  df["total_mb"] = total_mb
  df["operational_intensity"] = total_flops / (total_mb + 1.0)

  df["conv_frac"] = df["conv_flops"].fillna(0) / (total_flops + 1.0)
  df["matmul_frac"] = df["matmul_flops"].fillna(0) / (total_flops + 1.0)
  df["elementwise_frac"] = df["elementwise_mb"].fillna(0) / (total_mb + 1.0)
  df["reduction_frac"] = df["reduction_mb"].fillna(0) / (total_mb + 1.0)
  df["normalization_frac"] = df["normalization_mb"].fillna(0) / (total_mb + 1.0)
  df["movement_frac"] = df["movement_mb"].fillna(0) / (total_mb + 1.0)
  df["memory_frac"] = df["memory_mb"].fillna(0) / (total_mb + 1.0)

  df["bandwidth_per_core_gbs"] = df["memory_bandwith_gbs"] / (df["num_cores"] + 1.0)
  df["l2_cache_per_core_kb"] = df["l2_cache_kb"] / (df["num_cores"] + 1.0)
  df["clock_x_cores_mhz"] = df["base_clock_mhz"] * df["num_cores"]

  return df


def preprocess(df: pd.DataFrame, train=False) -> pd.DataFrame:

  #drop rows with missing target
  df = df.dropna(subset=["average_ms"])

  # keep Run 6's strict CV rule on all splits
  cv_limit = 0.1
  df["cv"] = df["stddev_ms"] / df["average_ms"]
  df = df[df["cv"] <= cv_limit].copy()

  #add log_average_ms column
  df["log_average_ms"] = np.log(df["average_ms"])

  #remove decimals and round down
  for col in ["elementwise_mb", "reduction_mb", "normalization_mb", "movement_mb"]:
    df[col] = df[col].round(0)

  df = add_engineered_features(df)

  return df

# %%
train_df = preprocess(train_df, True)
test_df = preprocess(test_df, False)
val_df = preprocess(val_df, False)

print("train:", train_df.shape)
print("val:", val_df.shape)
print("test:", test_df.shape)
# Out:
# train: (95814, 169)
# val: (20494, 169)
# test: (20528, 169)

# %%
for col in model_feature_cols:
    train_df[col] = np.log1p(train_df[col].clip(lower=0))
    val_df[col] = np.log1p(val_df[col].clip(lower=0))
    test_df[col] = np.log1p(test_df[col].clip(lower=0))

# %% [markdown]
# # Data Setup

# %%
target_col = "log_average_ms"

# %%
cpu_provider_map = {
    "intel": 0.0,
    "amd": 1.0,
}

for df in [train_df, val_df, test_df]:
    df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

    if df["cpu_provider_binary"].isna().any():
        bad_values = df.loc[df["cpu_provider_binary"].isna(), "cpu_provider"].unique()
        raise ValueError(f"Unknown cpu_provider values: {bad_values}")

hardware_feature_cols = [
    col for col in hardware_feature_cols
    if col not in {"cpu_provider", "cpu_provider_binary"}
]
hardware_feature_cols.append("cpu_provider_binary")
# Out:
# /tmp/ipykernel_1937/3350037661.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_1937/3350037661.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)
# /tmp/ipykernel_1937/3350037661.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cpu_provider_binary"] = df["cpu_provider"].map(cpu_provider_map)

# %%
X_model_train = train_df[model_feature_cols].astype("float32").to_numpy()
X_model_val = val_df[model_feature_cols].astype("float32").to_numpy()
X_model_test = test_df[model_feature_cols].astype("float32").to_numpy()

X_hw_train = train_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_val = val_df[hardware_feature_cols].astype("float32").to_numpy()
X_hw_test = test_df[hardware_feature_cols].astype("float32").to_numpy()

y_train = train_df[target_col].astype("float32").to_numpy()
y_val = val_df[target_col].astype("float32").to_numpy()
y_test = test_df[target_col].astype("float32").to_numpy()

# %%
model_scaler = StandardScaler()
hw_scaler = StandardScaler()

X_model_train = model_scaler.fit_transform(X_model_train).astype("float32")
X_model_val = model_scaler.transform(X_model_val).astype("float32")
X_model_test = model_scaler.transform(X_model_test).astype("float32")

X_hw_train = hw_scaler.fit_transform(X_hw_train).astype("float32")
X_hw_val = hw_scaler.transform(X_hw_val).astype("float32")
X_hw_test = hw_scaler.transform(X_hw_test).astype("float32")

# %% [markdown]
# # Model Setup

# %%
def rmse_log(y_true, y_pred):
  return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class TwoTowerLatencyDataset(Dataset):
    def __init__(self, X_model, X_hw, y):
        self.X_model = torch.from_numpy(X_model)
        self.X_hw = torch.from_numpy(X_hw)
        self.y = torch.from_numpy(y)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X_model[idx], self.X_hw[idx], self.y[idx]

# %%
batch_size = 1024

train_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_train, X_hw_train, y_train),
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
)

val_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_val, X_hw_val, y_val),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

test_loader = DataLoader(
    TwoTowerLatencyDataset(X_model_test, X_hw_test, y_test),
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout=0.10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim * 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(dim * 2, dim),
        )
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        return self.norm(x + self.net(x))


class GatedFiLMLatencyMLP(nn.Module):
    def __init__(self, n_model_features: int, n_hw_features: int):
        super().__init__()

        emb_dim = 192

        self.model_in = nn.Sequential(
            nn.Linear(n_model_features, 384),
            nn.LayerNorm(384),
            nn.GELU(),
            nn.Dropout(0.12),
            nn.Linear(384, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        self.model_blocks = nn.Sequential(
            ResidualBlock(emb_dim, dropout=0.10),
            ResidualBlock(emb_dim, dropout=0.08),
            ResidualBlock(emb_dim, dropout=0.05),
        )

        self.hw_tower = nn.Sequential(
            nn.Linear(n_hw_features, 96),
            nn.LayerNorm(96),
            nn.GELU(),
            nn.Dropout(0.05),
            nn.Linear(96, emb_dim),
            nn.LayerNorm(emb_dim),
            nn.GELU(),
        )

        self.hw_film = nn.Linear(emb_dim, emb_dim * 2)
        self.gate = nn.Sequential(
            nn.Linear(emb_dim * 2, emb_dim),
            nn.Sigmoid(),
        )

        self.fusion = nn.Sequential(
            nn.Linear(emb_dim * 5, 384),
            nn.LayerNorm(384),
            nn.GELU(),
            nn.Dropout(0.12),

            ResidualBlock(384, dropout=0.08),

            nn.Linear(384, 192),
            nn.LayerNorm(192),
            nn.GELU(),
            nn.Dropout(0.05),

            nn.Linear(192, 1),
        )

    def forward(self, model_x, hw_x):
        model_emb = self.model_in(model_x)
        model_emb = self.model_blocks(model_emb)

        hw_emb = self.hw_tower(hw_x)

        gamma, beta = self.hw_film(hw_emb).chunk(2, dim=1)
        film_model = model_emb * (1 + gamma) + beta

        gate = self.gate(torch.cat([model_emb, hw_emb], dim=1))
        conditioned_model = gate * film_model + (1 - gate) * model_emb

        interaction = conditioned_model * hw_emb
        diff = torch.abs(conditioned_model - hw_emb)
        ratio_proxy = conditioned_model / (torch.abs(hw_emb) + 1.0)

        fused = torch.cat(
            [conditioned_model, hw_emb, interaction, diff, ratio_proxy],
            dim=1,
        )

        return self.fusion(fused).squeeze(1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print("device:", device)
# Out:
# device: cuda

# %%
print("model features:", X_model_train.shape[1])
print("hardware features:", X_hw_train.shape[1])
# Out:
# model features: 144
# hardware features: 10

# %%
model = GatedFiLMLatencyMLP(
    n_model_features=X_model_train.shape[1],
    n_hw_features=X_hw_train.shape[1],
).to(device)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=8e-4,
    weight_decay=2e-4,
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=250,
    T_mult=2,
    eta_min=1e-5,
)

loss_fn = nn.SmoothL1Loss(beta=0.05)  # Huber loss on log latency

# %% [markdown]
# # Model Training

# %%
from sklearn.metrics import mean_squared_error

# %%
def evaluate_mlp(model, loader):
    model.eval()

    preds = []
    targets = []

    with torch.no_grad():
        for model_x, hw_x, y in loader:
            model_x = model_x.to(device)
            hw_x = hw_x.to(device)
            y = y.to(device)

            pred = model(model_x, hw_x)

            preds.append(pred.cpu().numpy())
            targets.append(y.cpu().numpy())

    y_pred = np.concatenate(preds)
    y_true = np.concatenate(targets)

    rmse_log = np.sqrt(mean_squared_error(y_true, y_pred))

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    metrics = {
        "rmse_log": rmse_log,
        "rmse_ms": np.sqrt(mean_squared_error(true_ms, pred_ms)),
        "rmse_percent": np.sqrt(mean_squared_error(rel_err, np.zeros_like(rel_err))),
        "median_relative_error": np.median(rel_err),
        "p90_relative_error": np.percentile(rel_err, 90),
        "p95_relative_error": np.percentile(rel_err, 95),
        "within_10pct": np.mean(rel_err <= 0.10),
        "median_ratio_error": np.median(np.maximum(pred_ms / true_ms, true_ms / pred_ms)),
        "p90_ratio_error": np.percentile(np.maximum(pred_ms / true_ms, true_ms / pred_ms), 90),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
        "within_2x": np.mean(np.maximum(pred_ms / true_ms, true_ms / pred_ms) <= 2.0),
    }

    return metrics, y_true, y_pred

# %%
best_val_rmse = float("inf")
best_within_10 = -float("inf")
best_state = None

num_epochs = 1600
patience = 300
min_delta = 1e-5
wait = 0

history = []

for epoch in range(1, num_epochs + 1):
    model.train()
    train_losses = []

    for model_x, hw_x, y in train_loader:
        model_x = model_x.to(device)
        hw_x = hw_x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        pred = model(model_x, hw_x)
        loss = loss_fn(pred, y)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        train_losses.append(loss.item())

    scheduler.step(epoch)

    val_metrics, _, _ = evaluate_mlp(model, val_loader)
    val_rmse = val_metrics["rmse_log"]
    val_within_10 = val_metrics["within_10pct"]

    history.append({
        "epoch": epoch,
        "train_loss": np.mean(train_losses),
        "lr": optimizer.param_groups[0]["lr"],
        **val_metrics,
    })

    improved = (
        val_within_10 > best_within_10 + min_delta
        or (abs(val_within_10 - best_within_10) <= min_delta and val_rmse < best_val_rmse - min_delta)
    )

    if improved:
        best_within_10 = val_within_10
        best_val_rmse = val_rmse
        best_state = {
            "model": {k: v.detach().cpu().clone() for k, v in model.state_dict().items()},
            "epoch": epoch,
            "val_rmse": val_rmse,
            "val_within_10pct": val_within_10,
        }
        wait = 0
    else:
        wait += 1

    if epoch % 5 == 0 or epoch == 1:
        print(
            f"epoch {epoch:04d} | "
            f"train_loss={np.mean(train_losses):.5f} | "
            f"val_rmse_log={val_rmse:.5f} | "
            f"within_10={val_within_10:.4f} | "
            f"best_within_10={best_within_10:.4f} | "
            f"lr={optimizer.param_groups[0]['lr']:.2e}"
        )

    if wait >= patience:
        print(f"Early stopping at epoch {epoch}; best epoch {best_state['epoch']}")
        break
# Out:
# epoch 0001 | train_loss=0.56040 | val_rmse_log=0.47231 | within_10=0.1599 | best_within_10=0.1599 | lr=8.00e-04
# epoch 0005 | train_loss=0.21614 | val_rmse_log=0.30163 | within_10=0.4586 | best_within_10=0.4586 | lr=7.99e-04
# epoch 0010 | train_loss=0.17268 | val_rmse_log=0.27675 | within_10=0.5172 | best_within_10=0.5172 | lr=7.97e-04
# epoch 0015 | train_loss=0.16040 | val_rmse_log=0.26945 | within_10=0.4923 | best_within_10=0.5772 | lr=7.93e-04
# epoch 0020 | train_loss=0.14506 | val_rmse_log=0.26063 | within_10=0.5107 | best_within_10=0.6017 | lr=7.88e-04
# epoch 0025 | train_loss=0.14345 | val_rmse_log=0.25833 | within_10=0.4866 | best_within_10=0.6408 | lr=7.81e-04
# epoch 0030 | train_loss=0.12892 | val_rmse_log=0.24321 | within_10=0.6074 | best_within_10=0.6520 | lr=7.72e-04
# epoch 0035 | train_loss=0.13245 | val_rmse_log=0.25809 | within_10=0.5418 | best_within_10=0.6920 | lr=7.62e-04
# epoch 0040 | train_loss=0.12434 | val_rmse_log=0.23514 | within_10=0.7056 | best_within_10=0.7056 | lr=7.51e-04
# epoch 0045 | train_loss=0.11806 | val_rmse_log=0.23443 | within_10=0.7136 | best_within_10=0.7136 | lr=7.39e-04
# epoch 0050 | train_loss=0.11459 | val_rmse_log=0.22754 | within_10=0.7392 | best_within_10=0.7441 | lr=7.25e-04
# epoch 0055 | train_loss=0.11295 | val_rmse_log=0.23675 | within_10=0.6321 | best_within_10=0.7555 | lr=7.09e-04
# epoch 0060 | train_loss=0.10978 | val_rmse_log=0.22552 | within_10=0.7648 | best_within_10=0.7648 | lr=6.93e-04
# epoch 0065 | train_loss=0.10871 | val_rmse_log=0.23073 | within_10=0.7532 | best_within_10=0.7665 | lr=6.75e-04
# epoch 0070 | train_loss=0.10870 | val_rmse_log=0.23015 | within_10=0.7165 | best_within_10=0.7759 | lr=6.57e-04
# epoch 0075 | train_loss=0.10662 | val_rmse_log=0.22453 | within_10=0.7875 | best_within_10=0.7886 | lr=6.37e-04
# epoch 0080 | train_loss=0.10313 | val_rmse_log=0.22226 | within_10=0.7809 | best_within_10=0.7886 | lr=6.17e-04
# epoch 0085 | train_loss=0.10020 | val_rmse_log=0.22256 | within_10=0.7916 | best_within_10=0.7920 | lr=5.95e-04
# epoch 0090 | train_loss=0.09960 | val_rmse_log=0.22364 | within_10=0.7565 | best_within_10=0.8082 | lr=5.73e-04
# epoch 0095 | train_loss=0.09915 | val_rmse_log=0.24610 | within_10=0.7168 | best_within_10=0.8082 | lr=5.50e-04
# epoch 0100 | train_loss=0.09655 | val_rmse_log=0.21954 | within_10=0.8059 | best_within_10=0.8155 | lr=5.27e-04
# epoch 0105 | train_loss=0.09457 | val_rmse_log=0.21900 | within_10=0.8158 | best_within_10=0.8158 | lr=5.03e-04
# epoch 0110 | train_loss=0.09292 | val_rmse_log=0.22040 | within_10=0.8124 | best_within_10=0.8179 | lr=4.79e-04
# epoch 0115 | train_loss=0.09205 | val_rmse_log=0.21039 | within_10=0.8282 | best_within_10=0.8282 | lr=4.55e-04
# epoch 0120 | train_loss=0.09130 | val_rmse_log=0.21873 | within_10=0.8240 | best_within_10=0.8282 | lr=4.30e-04
# epoch 0125 | train_loss=0.09068 | val_rmse_log=0.21815 | within_10=0.8346 | best_within_10=0.8387 | lr=4.05e-04
# epoch 0130 | train_loss=0.08794 | val_rmse_log=0.21899 | within_10=0.8313 | best_within_10=0.8399 | lr=3.80e-04
# epoch 0135 | train_loss=0.08739 | val_rmse_log=0.21251 | within_10=0.8082 | best_within_10=0.8437 | lr=3.55e-04
# epoch 0140 | train_loss=0.08628 | val_rmse_log=0.21014 | within_10=0.8465 | best_within_10=0.8465 | lr=3.31e-04
# epoch 0145 | train_loss=0.08546 | val_rmse_log=0.22021 | within_10=0.8341 | best_within_10=0.8491 | lr=3.07e-04
# epoch 0150 | train_loss=0.08429 | val_rmse_log=0.21480 | within_10=0.8364 | best_within_10=0.8554 | lr=2.83e-04
# epoch 0155 | train_loss=0.08412 | val_rmse_log=0.21681 | within_10=0.8508 | best_within_10=0.8554 | lr=2.60e-04
# epoch 0160 | train_loss=0.08392 | val_rmse_log=0.21748 | within_10=0.8479 | best_within_10=0.8554 | lr=2.37e-04
# epoch 0165 | train_loss=0.08183 | val_rmse_log=0.21009 | within_10=0.8558 | best_within_10=0.8558 | lr=2.15e-04
# epoch 0170 | train_loss=0.08199 | val_rmse_log=0.20987 | within_10=0.8532 | best_within_10=0.8560 | lr=1.93e-04
# epoch 0175 | train_loss=0.08011 | val_rmse_log=0.20983 | within_10=0.8606 | best_within_10=0.8606 | lr=1.73e-04
# epoch 0180 | train_loss=0.08067 | val_rmse_log=0.21008 | within_10=0.8619 | best_within_10=0.8619 | lr=1.53e-04
# epoch 0185 | train_loss=0.07926 | val_rmse_log=0.21079 | within_10=0.8635 | best_within_10=0.8635 | lr=1.35e-04
# epoch 0190 | train_loss=0.08047 | val_rmse_log=0.21837 | within_10=0.8642 | best_within_10=0.8642 | lr=1.17e-04
# epoch 0195 | train_loss=0.07812 | val_rmse_log=0.21014 | within_10=0.8646 | best_within_10=0.8646 | lr=1.01e-04
# epoch 0200 | train_loss=0.07765 | val_rmse_log=0.21001 | within_10=0.8622 | best_within_10=0.8654 | lr=8.54e-05
# epoch 0205 | train_loss=0.07850 | val_rmse_log=0.21816 | within_10=0.8661 | best_within_10=0.8661 | lr=7.15e-05
# epoch 0210 | train_loss=0.07726 | val_rmse_log=0.20935 | within_10=0.8646 | best_within_10=0.8661 | lr=5.89e-05
# epoch 0215 | train_loss=0.07677 | val_rmse_log=0.20974 | within_10=0.8652 | best_within_10=0.8671 | lr=4.76e-05
# epoch 0220 | train_loss=0.07663 | val_rmse_log=0.20963 | within_10=0.8676 | best_within_10=0.8676 | lr=3.77e-05
# epoch 0225 | train_loss=0.07652 | val_rmse_log=0.20987 | within_10=0.8654 | best_within_10=0.8676 | lr=2.93e-05
# epoch 0230 | train_loss=0.07618 | val_rmse_log=0.20978 | within_10=0.8654 | best_within_10=0.8684 | lr=2.24e-05
# epoch 0235 | train_loss=0.07623 | val_rmse_log=0.20925 | within_10=0.8669 | best_within_10=0.8684 | lr=1.70e-05
# epoch 0240 | train_loss=0.07590 | val_rmse_log=0.20943 | within_10=0.8671 | best_within_10=0.8684 | lr=1.31e-05
# epoch 0245 | train_loss=0.07584 | val_rmse_log=0.20948 | within_10=0.8669 | best_within_10=0.8684 | lr=1.08e-05
# epoch 0250 | train_loss=0.07577 | val_rmse_log=0.20949 | within_10=0.8667 | best_within_10=0.8684 | lr=8.00e-04
# epoch 0255 | train_loss=0.09492 | val_rmse_log=0.22509 | within_10=0.7936 | best_within_10=0.8684 | lr=8.00e-04
# epoch 0260 | train_loss=0.09124 | val_rmse_log=0.21337 | within_10=0.8120 | best_within_10=0.8684 | lr=7.99e-04
# epoch 0265 | train_loss=0.09117 | val_rmse_log=0.21314 | within_10=0.8013 | best_within_10=0.8684 | lr=7.98e-04
# epoch 0270 | train_loss=0.08769 | val_rmse_log=0.22106 | within_10=0.7812 | best_within_10=0.8684 | lr=7.97e-04
# epoch 0275 | train_loss=0.09020 | val_rmse_log=0.22332 | within_10=0.7773 | best_within_10=0.8684 | lr=7.95e-04
# epoch 0280 | train_loss=0.08610 | val_rmse_log=0.21710 | within_10=0.7710 | best_within_10=0.8684 | lr=7.93e-04
# epoch 0285 | train_loss=0.08862 | val_rmse_log=0.22420 | within_10=0.8176 | best_within_10=0.8684 | lr=7.90e-04
# epoch 0290 | train_loss=0.08539 | val_rmse_log=0.22109 | within_10=0.8202 | best_within_10=0.8684 | lr=7.88e-04
# epoch 0295 | train_loss=0.08493 | val_rmse_log=0.24148 | within_10=0.8408 | best_within_10=0.8684 | lr=7.84e-04
# epoch 0300 | train_loss=0.08418 | val_rmse_log=0.21881 | within_10=0.8281 | best_within_10=0.8684 | lr=7.81e-04
# epoch 0305 | train_loss=0.08618 | val_rmse_log=0.21991 | within_10=0.8129 | best_within_10=0.8684 | lr=7.77e-04
# epoch 0310 | train_loss=0.08188 | val_rmse_log=0.21295 | within_10=0.8327 | best_within_10=0.8684 | lr=7.72e-04
# epoch 0315 | train_loss=0.08284 | val_rmse_log=0.22078 | within_10=0.8259 | best_within_10=0.8684 | lr=7.68e-04
# epoch 0320 | train_loss=0.08096 | val_rmse_log=0.22162 | within_10=0.8291 | best_within_10=0.8684 | lr=7.62e-04
# epoch 0325 | train_loss=0.08068 | val_rmse_log=0.21410 | within_10=0.8418 | best_within_10=0.8684 | lr=7.57e-04
# epoch 0330 | train_loss=0.08126 | val_rmse_log=0.21928 | within_10=0.8419 | best_within_10=0.8684 | lr=7.51e-04
# epoch 0335 | train_loss=0.07905 | val_rmse_log=0.21674 | within_10=0.8300 | best_within_10=0.8684 | lr=7.45e-04
# epoch 0340 | train_loss=0.07841 | val_rmse_log=0.22646 | within_10=0.8346 | best_within_10=0.8684 | lr=7.39e-04
# epoch 0345 | train_loss=0.07790 | val_rmse_log=0.21075 | within_10=0.8563 | best_within_10=0.8684 | lr=7.32e-04
# epoch 0350 | train_loss=0.07767 | val_rmse_log=0.22516 | within_10=0.8274 | best_within_10=0.8684 | lr=7.25e-04
# epoch 0355 | train_loss=0.07728 | val_rmse_log=0.22135 | within_10=0.8272 | best_within_10=0.8684 | lr=7.17e-04
# epoch 0360 | train_loss=0.07650 | val_rmse_log=0.22093 | within_10=0.8460 | best_within_10=0.8684 | lr=7.09e-04
# epoch 0365 | train_loss=0.07630 | val_rmse_log=0.22231 | within_10=0.8492 | best_within_10=0.8684 | lr=7.01e-04
# epoch 0370 | train_loss=0.07757 | val_rmse_log=0.21739 | within_10=0.8340 | best_within_10=0.8684 | lr=6.93e-04
# epoch 0375 | train_loss=0.07336 | val_rmse_log=0.22318 | within_10=0.8561 | best_within_10=0.8684 | lr=6.84e-04
# epoch 0380 | train_loss=0.07528 | val_rmse_log=0.22302 | within_10=0.8456 | best_within_10=0.8684 | lr=6.75e-04
# epoch 0385 | train_loss=0.07473 | val_rmse_log=0.21297 | within_10=0.8539 | best_within_10=0.8684 | lr=6.66e-04
# epoch 0390 | train_loss=0.07236 | val_rmse_log=0.21526 | within_10=0.8476 | best_within_10=0.8684 | lr=6.57e-04
# epoch 0395 | train_loss=0.07511 | val_rmse_log=0.22579 | within_10=0.8561 | best_within_10=0.8684 | lr=6.47e-04
# epoch 0400 | train_loss=0.07197 | val_rmse_log=0.21235 | within_10=0.8596 | best_within_10=0.8684 | lr=6.37e-04
# epoch 0405 | train_loss=0.07192 | val_rmse_log=0.21419 | within_10=0.8487 | best_within_10=0.8684 | lr=6.27e-04
# epoch 0410 | train_loss=0.07145 | val_rmse_log=0.22212 | within_10=0.8456 | best_within_10=0.8684 | lr=6.17e-04
# epoch 0415 | train_loss=0.07203 | val_rmse_log=0.22011 | within_10=0.8525 | best_within_10=0.8684 | lr=6.06e-04
# epoch 0420 | train_loss=0.07248 | val_rmse_log=0.22005 | within_10=0.8586 | best_within_10=0.8684 | lr=5.95e-04
# epoch 0425 | train_loss=0.06903 | val_rmse_log=0.21458 | within_10=0.8607 | best_within_10=0.8684 | lr=5.84e-04
# epoch 0430 | train_loss=0.07082 | val_rmse_log=0.21817 | within_10=0.8556 | best_within_10=0.8684 | lr=5.73e-04
# epoch 0435 | train_loss=0.06908 | val_rmse_log=0.21249 | within_10=0.8620 | best_within_10=0.8684 | lr=5.62e-04
# epoch 0440 | train_loss=0.06787 | val_rmse_log=0.21180 | within_10=0.8605 | best_within_10=0.8684 | lr=5.50e-04
# epoch 0445 | train_loss=0.06974 | val_rmse_log=0.21923 | within_10=0.8624 | best_within_10=0.8684 | lr=5.39e-04
# epoch 0450 | train_loss=0.06909 | val_rmse_log=0.22182 | within_10=0.8641 | best_within_10=0.8684 | lr=5.27e-04
# epoch 0455 | train_loss=0.06694 | val_rmse_log=0.21245 | within_10=0.8674 | best_within_10=0.8684 | lr=5.15e-04
# epoch 0460 | train_loss=0.06662 | val_rmse_log=0.21323 | within_10=0.8664 | best_within_10=0.8684 | lr=5.03e-04
# epoch 0465 | train_loss=0.06768 | val_rmse_log=0.21143 | within_10=0.8638 | best_within_10=0.8684 | lr=4.91e-04
# epoch 0470 | train_loss=0.06637 | val_rmse_log=0.21270 | within_10=0.8629 | best_within_10=0.8684 | lr=4.79e-04
# epoch 0475 | train_loss=0.06707 | val_rmse_log=0.21269 | within_10=0.8650 | best_within_10=0.8684 | lr=4.67e-04
# epoch 0480 | train_loss=0.06771 | val_rmse_log=0.22057 | within_10=0.8612 | best_within_10=0.8684 | lr=4.55e-04
# epoch 0485 | train_loss=0.06534 | val_rmse_log=0.21317 | within_10=0.8645 | best_within_10=0.8684 | lr=4.42e-04
# epoch 0490 | train_loss=0.06486 | val_rmse_log=0.21339 | within_10=0.8672 | best_within_10=0.8684 | lr=4.30e-04
# epoch 0495 | train_loss=0.06474 | val_rmse_log=0.21335 | within_10=0.8664 | best_within_10=0.8688 | lr=4.17e-04
# epoch 0500 | train_loss=0.06445 | val_rmse_log=0.22374 | within_10=0.8632 | best_within_10=0.8688 | lr=4.05e-04
# epoch 0505 | train_loss=0.06374 | val_rmse_log=0.21261 | within_10=0.8677 | best_within_10=0.8688 | lr=3.93e-04
# epoch 0510 | train_loss=0.06371 | val_rmse_log=0.21328 | within_10=0.8688 | best_within_10=0.8694 | lr=3.80e-04
# epoch 0515 | train_loss=0.06371 | val_rmse_log=0.22388 | within_10=0.8623 | best_within_10=0.8694 | lr=3.68e-04
# epoch 0520 | train_loss=0.06350 | val_rmse_log=0.21319 | within_10=0.8672 | best_within_10=0.8694 | lr=3.55e-04
# epoch 0525 | train_loss=0.06357 | val_rmse_log=0.21325 | within_10=0.8681 | best_within_10=0.8694 | lr=3.43e-04
# epoch 0530 | train_loss=0.06261 | val_rmse_log=0.21366 | within_10=0.8673 | best_within_10=0.8694 | lr=3.31e-04
# epoch 0535 | train_loss=0.06270 | val_rmse_log=0.21347 | within_10=0.8693 | best_within_10=0.8696 | lr=3.19e-04
# epoch 0540 | train_loss=0.06235 | val_rmse_log=0.21300 | within_10=0.8701 | best_within_10=0.8701 | lr=3.07e-04
# epoch 0545 | train_loss=0.06224 | val_rmse_log=0.21360 | within_10=0.8694 | best_within_10=0.8701 | lr=2.95e-04
# epoch 0550 | train_loss=0.06244 | val_rmse_log=0.21332 | within_10=0.8666 | best_within_10=0.8701 | lr=2.83e-04
# epoch 0555 | train_loss=0.06150 | val_rmse_log=0.21414 | within_10=0.8664 | best_within_10=0.8701 | lr=2.71e-04
# epoch 0560 | train_loss=0.06137 | val_rmse_log=0.21356 | within_10=0.8684 | best_within_10=0.8711 | lr=2.60e-04
# epoch 0565 | train_loss=0.06144 | val_rmse_log=0.21424 | within_10=0.8680 | best_within_10=0.8711 | lr=2.48e-04
# epoch 0570 | train_loss=0.06132 | val_rmse_log=0.21397 | within_10=0.8692 | best_within_10=0.8711 | lr=2.37e-04
# epoch 0575 | train_loss=0.06105 | val_rmse_log=0.21457 | within_10=0.8670 | best_within_10=0.8711 | lr=2.26e-04
# epoch 0580 | train_loss=0.06088 | val_rmse_log=0.21390 | within_10=0.8676 | best_within_10=0.8711 | lr=2.15e-04
# epoch 0585 | train_loss=0.06067 | val_rmse_log=0.21336 | within_10=0.8695 | best_within_10=0.8711 | lr=2.04e-04
# epoch 0590 | train_loss=0.06083 | val_rmse_log=0.21414 | within_10=0.8687 | best_within_10=0.8711 | lr=1.93e-04
# epoch 0595 | train_loss=0.06029 | val_rmse_log=0.21343 | within_10=0.8705 | best_within_10=0.8711 | lr=1.83e-04
# epoch 0600 | train_loss=0.06012 | val_rmse_log=0.21359 | within_10=0.8697 | best_within_10=0.8711 | lr=1.73e-04
# epoch 0605 | train_loss=0.06019 | val_rmse_log=0.21359 | within_10=0.8701 | best_within_10=0.8711 | lr=1.63e-04
# epoch 0610 | train_loss=0.05994 | val_rmse_log=0.21446 | within_10=0.8690 | best_within_10=0.8711 | lr=1.53e-04
# epoch 0615 | train_loss=0.06006 | val_rmse_log=0.21612 | within_10=0.8664 | best_within_10=0.8711 | lr=1.44e-04
# epoch 0620 | train_loss=0.05957 | val_rmse_log=0.21387 | within_10=0.8713 | best_within_10=0.8718 | lr=1.35e-04
# epoch 0625 | train_loss=0.05952 | val_rmse_log=0.21372 | within_10=0.8702 | best_within_10=0.8718 | lr=1.26e-04
# epoch 0630 | train_loss=0.05930 | val_rmse_log=0.21404 | within_10=0.8704 | best_within_10=0.8718 | lr=1.17e-04
# epoch 0635 | train_loss=0.05908 | val_rmse_log=0.21432 | within_10=0.8705 | best_within_10=0.8718 | lr=1.09e-04
# epoch 0640 | train_loss=0.05932 | val_rmse_log=0.21363 | within_10=0.8711 | best_within_10=0.8718 | lr=1.01e-04
# epoch 0645 | train_loss=0.05887 | val_rmse_log=0.21425 | within_10=0.8698 | best_within_10=0.8718 | lr=9.29e-05
# epoch 0650 | train_loss=0.05887 | val_rmse_log=0.21433 | within_10=0.8699 | best_within_10=0.8718 | lr=8.54e-05
# epoch 0655 | train_loss=0.05879 | val_rmse_log=0.21436 | within_10=0.8714 | best_within_10=0.8718 | lr=7.83e-05
# epoch 0660 | train_loss=0.05872 | val_rmse_log=0.21436 | within_10=0.8706 | best_within_10=0.8718 | lr=7.15e-05
# epoch 0665 | train_loss=0.05869 | val_rmse_log=0.21414 | within_10=0.8705 | best_within_10=0.8718 | lr=6.50e-05
# epoch 0670 | train_loss=0.05847 | val_rmse_log=0.21431 | within_10=0.8705 | best_within_10=0.8718 | lr=5.89e-05
# epoch 0675 | train_loss=0.05837 | val_rmse_log=0.21420 | within_10=0.8703 | best_within_10=0.8718 | lr=5.31e-05
# epoch 0680 | train_loss=0.05834 | val_rmse_log=0.21447 | within_10=0.8696 | best_within_10=0.8718 | lr=4.76e-05
# epoch 0685 | train_loss=0.05825 | val_rmse_log=0.21442 | within_10=0.8699 | best_within_10=0.8718 | lr=4.25e-05
# epoch 0690 | train_loss=0.05817 | val_rmse_log=0.21438 | within_10=0.8708 | best_within_10=0.8718 | lr=3.77e-05
# epoch 0695 | train_loss=0.05825 | val_rmse_log=0.21444 | within_10=0.8698 | best_within_10=0.8718 | lr=3.34e-05
# epoch 0700 | train_loss=0.05830 | val_rmse_log=0.21440 | within_10=0.8701 | best_within_10=0.8718 | lr=2.93e-05
# epoch 0705 | train_loss=0.05823 | val_rmse_log=0.21446 | within_10=0.8706 | best_within_10=0.8718 | lr=2.57e-05
# epoch 0710 | train_loss=0.05822 | val_rmse_log=0.21434 | within_10=0.8708 | best_within_10=0.8718 | lr=2.24e-05
# epoch 0715 | train_loss=0.05815 | val_rmse_log=0.21454 | within_10=0.8697 | best_within_10=0.8718 | lr=1.95e-05
# epoch 0720 | train_loss=0.05792 | val_rmse_log=0.21449 | within_10=0.8696 | best_within_10=0.8718 | lr=1.70e-05
# epoch 0725 | train_loss=0.05804 | val_rmse_log=0.21434 | within_10=0.8699 | best_within_10=0.8718 | lr=1.49e-05
# epoch 0730 | train_loss=0.05791 | val_rmse_log=0.21448 | within_10=0.8704 | best_within_10=0.8718 | lr=1.31e-05
# epoch 0735 | train_loss=0.05787 | val_rmse_log=0.21431 | within_10=0.8700 | best_within_10=0.8718 | lr=1.18e-05
# epoch 0740 | train_loss=0.05789 | val_rmse_log=0.21459 | within_10=0.8701 | best_within_10=0.8718 | lr=1.08e-05
# epoch 0745 | train_loss=0.05768 | val_rmse_log=0.21438 | within_10=0.8703 | best_within_10=0.8718 | lr=1.02e-05
# epoch 0750 | train_loss=0.05785 | val_rmse_log=0.21447 | within_10=0.8703 | best_within_10=0.8718 | lr=8.00e-04
# epoch 0755 | train_loss=0.06998 | val_rmse_log=0.21208 | within_10=0.8461 | best_within_10=0.8718 | lr=8.00e-04
# epoch 0760 | train_loss=0.06675 | val_rmse_log=0.21735 | within_10=0.8527 | best_within_10=0.8718 | lr=8.00e-04
# epoch 0765 | train_loss=0.06560 | val_rmse_log=0.21106 | within_10=0.8547 | best_within_10=0.8718 | lr=8.00e-04
# epoch 0770 | train_loss=0.06505 | val_rmse_log=0.21473 | within_10=0.8559 | best_within_10=0.8718 | lr=7.99e-04
# epoch 0775 | train_loss=0.06433 | val_rmse_log=0.21236 | within_10=0.8602 | best_within_10=0.8718 | lr=7.99e-04
# epoch 0780 | train_loss=0.06834 | val_rmse_log=0.27031 | within_10=0.8533 | best_within_10=0.8718 | lr=7.98e-04
# epoch 0785 | train_loss=0.06382 | val_rmse_log=0.21259 | within_10=0.8596 | best_within_10=0.8718 | lr=7.98e-04
# epoch 0790 | train_loss=0.06458 | val_rmse_log=0.21320 | within_10=0.8572 | best_within_10=0.8718 | lr=7.97e-04
# epoch 0795 | train_loss=0.06306 | val_rmse_log=0.21335 | within_10=0.8646 | best_within_10=0.8718 | lr=7.96e-04
# epoch 0800 | train_loss=0.06230 | val_rmse_log=0.21553 | within_10=0.8592 | best_within_10=0.8718 | lr=7.95e-04
# epoch 0805 | train_loss=0.06288 | val_rmse_log=0.22095 | within_10=0.8610 | best_within_10=0.8718 | lr=7.94e-04
# epoch 0810 | train_loss=0.06342 | val_rmse_log=0.21903 | within_10=0.8609 | best_within_10=0.8718 | lr=7.93e-04
# epoch 0815 | train_loss=0.06094 | val_rmse_log=0.21342 | within_10=0.8657 | best_within_10=0.8718 | lr=7.92e-04
# epoch 0820 | train_loss=0.06350 | val_rmse_log=0.21487 | within_10=0.8606 | best_within_10=0.8718 | lr=7.90e-04
# epoch 0825 | train_loss=0.06177 | val_rmse_log=0.21526 | within_10=0.8543 | best_within_10=0.8718 | lr=7.89e-04
# epoch 0830 | train_loss=0.06089 | val_rmse_log=0.21531 | within_10=0.8563 | best_within_10=0.8718 | lr=7.88e-04
# epoch 0835 | train_loss=0.06291 | val_rmse_log=0.22283 | within_10=0.8623 | best_within_10=0.8718 | lr=7.86e-04
# epoch 0840 | train_loss=0.06078 | val_rmse_log=0.21682 | within_10=0.8664 | best_within_10=0.8718 | lr=7.84e-04
# epoch 0845 | train_loss=0.06205 | val_rmse_log=0.21501 | within_10=0.8637 | best_within_10=0.8718 | lr=7.83e-04
# epoch 0850 | train_loss=0.06200 | val_rmse_log=0.22535 | within_10=0.8569 | best_within_10=0.8718 | lr=7.81e-04
# epoch 0855 | train_loss=0.06014 | val_rmse_log=0.21530 | within_10=0.8633 | best_within_10=0.8718 | lr=7.79e-04
# epoch 0860 | train_loss=0.06113 | val_rmse_log=0.21785 | within_10=0.8665 | best_within_10=0.8718 | lr=7.77e-04
# epoch 0865 | train_loss=0.06121 | val_rmse_log=0.21556 | within_10=0.8618 | best_within_10=0.8718 | lr=7.75e-04
# epoch 0870 | train_loss=0.06258 | val_rmse_log=0.22172 | within_10=0.8654 | best_within_10=0.8718 | lr=7.72e-04
# epoch 0875 | train_loss=0.06173 | val_rmse_log=0.21633 | within_10=0.8603 | best_within_10=0.8718 | lr=7.70e-04
# epoch 0880 | train_loss=0.06322 | val_rmse_log=0.22831 | within_10=0.8643 | best_within_10=0.8718 | lr=7.68e-04
# epoch 0885 | train_loss=0.06125 | val_rmse_log=0.21909 | within_10=0.8669 | best_within_10=0.8718 | lr=7.65e-04
# epoch 0890 | train_loss=0.05950 | val_rmse_log=0.21463 | within_10=0.8644 | best_within_10=0.8718 | lr=7.62e-04
# epoch 0895 | train_loss=0.06302 | val_rmse_log=0.21628 | within_10=0.8588 | best_within_10=0.8718 | lr=7.60e-04
# epoch 0900 | train_loss=0.05908 | val_rmse_log=0.21420 | within_10=0.8664 | best_within_10=0.8718 | lr=7.57e-04
# epoch 0905 | train_loss=0.05866 | val_rmse_log=0.22418 | within_10=0.8622 | best_within_10=0.8718 | lr=7.54e-04
# epoch 0910 | train_loss=0.05966 | val_rmse_log=0.21607 | within_10=0.8569 | best_within_10=0.8718 | lr=7.51e-04
# epoch 0915 | train_loss=0.05884 | val_rmse_log=0.21425 | within_10=0.8657 | best_within_10=0.8718 | lr=7.48e-04
# Early stopping at epoch 919; best epoch 619

# %% [markdown]
# # Evaluation

# %%
import pandas as pd
import matplotlib.pyplot as plt

history_df = pd.DataFrame(history)

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.plot(
    history_df["epoch"],
    history_df["train_loss"],
    label="Train loss",
    color="tab:blue",
)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Train loss", color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

ax2 = ax1.twinx()
ax2.plot(
    history_df["epoch"],
    history_df["within_10pct"],
    label="Within 10%",
    color="tab:orange",
)
ax2.plot(
    history_df["epoch"],
    history_df["rmse_log"],
    label="Val RMSE log",
    color="tab:green",
    alpha=0.6,
)
ax2.set_ylabel("Validation metrics")
ax2.set_ylim(0, max(1.0, history_df["rmse_log"].max() * 1.1))

fig.suptitle("Training Loss, Within-10%, and RMSE Over Time")
fig.tight_layout()
plt.show()

history_df.sort_values(["within_10pct", "rmse_log"], ascending=[False, True]).head(10)
# Out:
#      epoch  train_loss        lr  rmse_log     rmse_ms  rmse_percent  \
# 618    619    0.059740  0.000136  0.213746  169.712820      0.414759
# 654    655    0.058788  0.000078  0.214358  172.078204      0.417452
# 619    620    0.059573  0.000135  0.213875  170.107422      0.416772
# 708    709    0.058098  0.000023  0.214438  175.315853      0.417592
# 687    688    0.058327  0.000040  0.214246  171.823964      0.414550
# 662    663    0.058682  0.000068  0.213926  172.898227      0.413543
# 556    557    0.061546  0.000267  0.212897  163.323443      0.407832
# 639    640    0.059320  0.000101  0.213633  173.150399      0.414223
# 668    669    0.058783  0.000060  0.214318  174.239514      0.415067
# 747    748    0.057931  0.000010  0.214361  176.280433      0.415817
#
#      median_relative_error  p90_relative_error  p95_relative_error  \
# 618               0.019975            0.142765            0.322475
# 654               0.018985            0.144380            0.320627
# 619               0.019549            0.143807            0.319498
# 708               0.018924            0.144946            0.326990
# 687               0.018971            0.144137            0.323471
# 662               0.017788            0.145116            0.319808
# 556               0.021516            0.140672            0.310705
# 639               0.019212            0.144536            0.319547
# 668               0.018119            0.145265            0.323785
# 747               0.017958            0.145206            0.323662
#
#      within_10pct  median_ratio_error  p90_ratio_error  within_25pct  \
# 618      0.871767            1.020182         1.152627      0.937250
# 654      0.871426            1.019203         1.154602      0.937055
# 619      0.871279            1.019657         1.153929      0.937299
# 708      0.871279            1.019034         1.154953      0.936176
# 687      0.871231            1.019170         1.153234      0.936908
# 662      0.871182            1.017974         1.152624      0.937348
# 556      0.871084            1.021795         1.150450      0.938470
# 639      0.871084            1.019411         1.155535      0.937299
# 668      0.870938            1.018248         1.153886      0.936762
# 747      0.870938            1.018097         1.152821      0.936469
#
#      within_50pct  within_2x
# 618      0.967015   0.982190
# 654      0.966673   0.981897
# 619      0.966624   0.982190
# 708      0.966429   0.981946
# 687      0.966820   0.981946
# 662      0.967259   0.982092
# 556      0.967893   0.982385
# 639      0.967210   0.981995
# 668      0.966576   0.981995
# 747      0.966868   0.981995

# %%
model.load_state_dict(best_state["model"])
print("Best epoch:", best_state["epoch"])
print("Best val RMSE:", best_state["val_rmse"])
print("Best val within_10pct:", best_state["val_within_10pct"])
# Out:
# Best epoch: 619
# Best val RMSE: 0.21374586661843026
# Best val within_10pct: 0.8717673465404508

# %%
val_metrics, val_true_log, val_pred_log = evaluate_mlp(model, val_loader)
test_metrics, test_true_log, test_pred_log = evaluate_mlp(model, test_loader)

pd.DataFrame([val_metrics, test_metrics], index=["val", "test"])
# Out:
#       rmse_log     rmse_ms  rmse_percent  median_relative_error  \
# val   0.213746  169.712820      0.414759               0.019975
# test  0.194118  139.257868      0.302364               0.019758
#
#       p90_relative_error  p95_relative_error  within_10pct  \
# val             0.142765            0.322475      0.871767
# test            0.134554            0.314909      0.873977
#
#       median_ratio_error  p90_ratio_error  within_25pct  within_50pct  \
# val             1.020182         1.152627      0.937250      0.967015
# test            1.019939         1.143091      0.938036      0.967410
#
#       within_2x
# val    0.982190
# test   0.983194

# %% [markdown]
# # Save Model

# %%
from pathlib import Path
import torch

model_dir = Path("/content/drive/MyDrive/Models")
model_dir.mkdir(parents=True, exist_ok=True)

save_path = model_dir / "10.pt"

if "best_state" in globals() and best_state is not None:
    model.load_state_dict(best_state["model"])

torch.save(
    {
        "model_state_dict": model.state_dict(),
        "n_model_features": X_model_train.shape[1],
        "n_hw_features": X_hw_train.shape[1],
        "model_feature_cols": model_feature_cols,
        "hardware_feature_cols": hardware_feature_cols,
        "model_scaler": model_scaler,
        "hw_scaler": hw_scaler,
        "target_col": "log_average_ms",
        "best_val_rmse": best_val_rmse if "best_val_rmse" in globals() else None,
        "best_val_within_10pct": best_within_10 if "best_within_10" in globals() else None,
        "seed": SEED,
    },
    save_path,
)

print("Saved to:", save_path)
# Out:
# Saved to: /content/drive/MyDrive/Models/10.pt

# %% [markdown]
# # Analysis

# %%
test_results = test_df.copy()

test_results["pred_log_latency"] = test_pred_log
test_results["true_log_latency"] = test_true_log

test_results["pred_latency_ms"] = np.exp(test_results["pred_log_latency"])
test_results["true_latency_ms"] = np.exp(test_results["true_log_latency"])

test_results["relative_error"] = (
    np.abs(test_results["pred_latency_ms"] - test_results["true_latency_ms"])
    / test_results["true_latency_ms"]
)

# %%
def group_latency_metrics(g):
    y_true = g["true_log_latency"].to_numpy()
    y_pred = g["pred_log_latency"].to_numpy()

    true_ms = np.exp(y_true)
    pred_ms = np.exp(y_pred)

    rel_err = np.abs(pred_ms - true_ms) / true_ms

    return pd.Series({
        "count": len(g),
        "rmse_log": np.sqrt(mean_squared_error(y_true, y_pred)),
        "within_10pct": np.mean(rel_err <= 0.10),
        "within_25pct": np.mean(rel_err <= 0.25),
        "within_50pct": np.mean(rel_err <= 0.50),
    })

# %%
test_results["abs_log_error"] = np.abs(
    test_results["pred_log_latency"] - test_results["true_log_latency"]
)

test_results.groupby(["cpu_provider", "platform", "num_cores"])["relative_error"].agg(
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
    within_10pct=lambda x: (x <= 0.10).mean(),
    within_25pct=lambda x: (x <= 0.25).mean(),
).reset_index()
# Out:
#   cpu_provider  platform  num_cores  count    median       p90  within_10pct  \
# 0          amd    gcloud          1   2621  0.015822  0.068716      0.918733
# 1          amd    gcloud          2   3763  0.034838  0.173733      0.803348
# 2          amd    gcloud          4   2493  0.043421  0.260163      0.749298
# 3        intel  bluehive          1   1347  0.013029  0.067569      0.913140
# 4        intel  bluehive          2   2686  0.013450  0.053959      0.927774
# 5        intel  bluehive          4   3921  0.015797  0.077499      0.909207
# 6        intel  bluehive          8   2347  0.019193  0.085633      0.907968
# 7        intel    gcloud          6   1350  0.016435  0.082757      0.906667
#
#    within_25pct
# 0      0.974819
# 1      0.947382
# 2      0.896510
# 3      0.939866
# 4      0.940060
# 5      0.932670
# 6      0.934810
# 7      0.932593

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"])["cv"].agg(
    within_10pct=lambda x: (x <= 0.10).mean(),
    count="count",
    median="median",
    p90=lambda x: x.quantile(0.9),
).reset_index()

# %%
test_results.groupby(["cpu_provider", "platform", "num_cores"]).apply(
    group_latency_metrics,
    include_groups=False
).reset_index()
